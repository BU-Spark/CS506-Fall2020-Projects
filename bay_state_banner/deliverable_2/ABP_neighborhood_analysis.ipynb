# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import requests
import json

# %%
filepath = "data/abp_data.csv"

data = pd.read_csv(filepath)

# %%
data
# Out:
#        permitnumber worktype           permittypedescr  \
# 0           A100071      COB  Amendment to a Long Form
# 1          A1001012    OTHER  Amendment to a Long Form
# 2          A1001201   INTEXT  Amendment to a Long Form
# 3           A100137   EXTREN  Amendment to a Long Form
# 4          A1001913   INTREN  Amendment to a Long Form
# ...             ...      ...                       ...
# 478014    U49993435    OSEAT           Use of Premises
# 478015    U49993435    OSEAT           Use of Premises
# 478016    U49993492   TEMTRL           Use of Premises
# 478017     U4999352    DRIVE           Use of Premises
# 478018    U49996370   RESPAR           Use of Premises
#
#                        description  \
# 0                   City of Boston
# 1                            Other
# 2           Interior/Exterior Work
# 3           Renovations - Exterior
# 4       Renovations - Interior NSC
# ...                            ...
# 478014             Outside Seating
# 478015             Outside Seating
# 478016          Temporary Trailers
# 478017       Driveway Installation
# 478018         Residential Parking
#
#                                                  comments          applicant  \
# 0       Change connector link layout from attached enc...  Renee Santeusanio
# 1       Amend Alt943748 to erect a roof deck as per pl...   Jusimar Oliveria
# 2       Build steel balcony over garden level with sta...      Andreas Hwang
# 3       Landscaping/stonework - amending permit #2801/...                NaN
# 4       Amendment to issued permit ALT888985. relocate...       Ping Mandawe
# ...                                                   ...                ...
# 478014  Outdoor patio / amenity space for commercial o...  Christine McMahon
# 478015  Outdoor patio / amenity space for commercial o...  Christine McMahon
# 478016  Temporary Construction Trailer at Herb Chamber...   Regina  Olivieri
# 478017  Owners would like to install a curb cut and a ...    Maria Dubrowski
# 478018  use of premises for;1 car parking with new dri...      Cesar DaSilva
#
#         declared_valuation  total_fees          issued_date  \
# 0                 40000.00       429.0  2011-11-04 11:04:58
# 1                  5000.00        70.0  2020-06-01 14:08:47
# 2                 74295.75       803.0  2019-11-13 13:38:56
# 3                 15000.00       206.0  2013-01-03 14:13:09
# 4                     1.00        33.0  2019-10-18 09:21:00
# ...                    ...         ...                  ...
# 478014                0.00        50.0  2019-09-25 11:36:11
# 478015                0.00        50.0  2019-09-25 11:36:11
# 478016             1000.00        53.0  2019-09-12 13:07:00
# 478017             2700.00        53.0  2012-05-30 14:28:59
# 478018             7000.00        62.0  2020-09-17 16:18:18
#
#             expiration_date  ... occupancytype sq_feet  \
# 0       2012-05-04 00:00:00  ...          Comm   170.0
# 1       2020-12-01 00:00:00  ...        1-3FAM     0.0
# 2       2020-05-13 00:00:00  ...         Multi     0.0
# 3       2013-07-03 00:00:00  ...        1-2FAM     0.0
# 4       2020-04-18 00:00:00  ...          Comm     0.0
# ...                     ...  ...           ...     ...
# 478014  2020-03-25 00:00:00  ...         Mixed     0.0
# 478015  2020-03-25 00:00:00  ...         Mixed     0.0
# 478016  2020-03-12 00:00:00  ...          Comm     0.0
# 478017  2012-11-30 00:00:00  ...        1-2FAM     0.0
# 478018  2021-03-17 00:00:00  ...        1-2FAM     0.0
#
#                           address           city state    zip property_id  \
# 0              175  W Boundary RD   West Roxbury    MA  02132       17268
# 1               15    Prospect ST    Charlestown    MA  02129      113443
# 2           211  W Springfield ST        Roxbury    MA  02118      129994
# 3       14    William Jackson AVE       Brighton    MA  02135      149852
# 4          130-140   Brighton AVE        Allston    MA  02134       20073
# ...                           ...            ...   ...    ...         ...
# 478014              3   Center Pz         Boston    MA  02108      154961
# 478015              3   Center Pz         Boston    MA  02108      154961
# 478016     1188   Commonwealth Av        Allston    MA  02134      424193
# 478017         46    Burroughs ST  Jamaica Plain    MA  02130       24047
# 478018             17    Alpha RD     Dorchester    MA  02124        2829
#
#          parcel_id        lat       long
# 0       2012032000  42.260750 -71.149610
# 1       0202837000  42.375243 -71.057585
# 2       0402558000  42.340600 -71.080250
# 3       2204944000  42.344600 -71.154050
# 4       2100846000  42.352760 -71.131850
# ...            ...        ...        ...
# 478014  0302713000  42.359180 -71.060040
# 478015  0302717000  42.359180 -71.060040
# 478016  2101574010        NaN        NaN
# 478017  1901861000  42.313220 -71.117130
# 478018  1701099000  42.296190 -71.067970
#
# [478019 rows x 22 columns]

# %% [markdown]
# Here we have filtered out all the permits we don't care for. We can rerun our analysis from Deliverable 1

# %%
df = data.loc[(data['permittypedescr'] == 'Erect/New Construction') | (data['permittypedescr'] == 'Excavation Permit') | (data['permittypedescr'] == 'Foundation Permit') | (data['description'] == 'Excavation Borings Test Pits') | (data['description'] == 'New construction') | (data['description'] == 'Erect')]
applicants = pd.DataFrame(df['applicant'])
owners = pd.DataFrame(df['owner'])
applicants
# Out:
#               applicant
# 100        Amy Sowersby
# 200         Hugh Meehan
# 275       Joe Hennessey
# 276       Joe Hennessey
# 444     Joshua Swerling
# ...                 ...
# 475958      john mercer
# 477044      David Amato
# 477379    Bruce Fulford
# 477471  Jorge Rodriguez
# 477499    William  Caci
#
# [13386 rows x 1 columns]

# %%
applicants.fillna("na")
applicants = applicants.applymap(str)

owners.fillna("na")
owners = owners.applymap(str)
applicants
# Out:
#               applicant
# 100        Amy Sowersby
# 200         Hugh Meehan
# 275       Joe Hennessey
# 276       Joe Hennessey
# 444     Joshua Swerling
# ...                 ...
# 475958      john mercer
# 477044      David Amato
# 477379    Bruce Fulford
# 477471  Jorge Rodriguez
# 477499    William  Caci
#
# [13386 rows x 1 columns]

# %%
def prep_df_column(col, generate_map=False):
    """
    col: A pandas column-frame of strings
    generate_map: Whether or not to generate a map of the original values to the edited values 

    Outputs the columm with all the entries set to lowercase and with spaces removed
    """
    new_col = col.iloc[:, 0]
    new_col = [name.lower().replace(" ", "") for name in new_col]
    col_map = dict()
    if generate_map:
        for i in range(len(new_col)):
            col_map[new_col[i]] = col.iloc[:, 0][i]
        return new_col, col_map
    else:
        return new_col

# %%
# we split the encoders into two so they can keep track of their inverse transforms
applcants_encoder = LabelEncoder()
owners_encoder = LabelEncoder()

# here we also optionally output the mapping between the preprocessed values and the original, which we can use for display purposes
# however, building the map takes longer than we'd like
# applicants_cleaned, applicants_map = prep_df_column(applicants, generate_map=True)
# owners_cleaned, owners_map = prep_df_column(owners, generate_map=True)

applicants_cleaned = prep_df_column(applicants, generate_map=False)
owners_cleaned = prep_df_column(owners, generate_map=False)

applicants_labels = pd.DataFrame(applcants_encoder.fit_transform(applicants_cleaned))
owners_labels = pd.DataFrame(owners_encoder.fit_transform(owners_cleaned))

# %%
applicants_labels_vals = applicants_labels.value_counts()
index = [tup[0] for tup in applicants_labels_vals.index]
applicants_labels_vals.index = applcants_encoder.inverse_transform(index)
pd.DataFrame(applicants_labels_vals)
# Out:
#                     0
# nan              8408
# timothyjohnson     63
# antonioferrara     61
# antonioruscito     52
# arthurchoo         41
# ...               ...
# lauderlylima        1
# laurenslaven        1
# lawrencemahoney     1
# lawrenceobrien      1
# jonelliott          1
#
# [1718 rows x 1 columns]

# %%
owners_labels_vals = owners_labels.value_counts()
owners_index = [tup[0] for tup in owners_labels_vals.index]
owners_labels_vals.index = owners_encoder.inverse_transform(owners_index)
pd.DataFrame(owners_labels_vals)
# Out:
#                            0
# nan                     2921
# cityofboston             242
# bostonhousingauthority   106
# harvardre/allstoninc      69
# csndcheritagehomesllc     59
# ...                      ...
# martinoma                  1
# martinhermans              1
# martinezsilverioe          1
# martinezpetronila          1
# 0ne-50magnoliallc          1
#
# [5138 rows x 1 columns]

# %% [markdown]
# ## Cencus Tract to Demographic Filtering

# %%
# Function to convert the Lat and Long into a census tract.
# Refer to https://www.census.gov/programs-surveys/geography/guidance/geo-identifiers.html for the FIPS code to census tract conversion
# FCC Census block conversion API link: https://geo.fcc.gov/api/census/#!/block/get_block_find

def Coord_to_census_tract(Lat,Long):
    Converter = requests.get("https://geo.fcc.gov/api/census/block/find?latitude=%20" + str(Lat) + "&longitude=" + str(Long) + "&showall=true&format=json")
    #print(Converter.text)
    Census_data = Converter.text
    json_data = json.loads(Census_data)
    # print(json_data)
    FIPS_code = json_data['Block']['FIPS']
    Census_tract = FIPS_code[5:11]
    #print(type(Census_tract))
    # print("yowza")
    if Census_tract[0] == "0":
        Census_tract.replace(Census_tract[0],'')
        Census_split = Census_tract[ : 4] + '.'+ Census_tract[4 : ]
        return(Census_split)
    else:
        Census_split = Census_tract[ : 4] + '.'+ Census_tract[4 : ]
        return(Census_split)

# %%
df2 = df.copy()
df2 = df2[df2['lat'].notna()]
df2 = df2[df2['long'].notna()]
df2
# Out:
#        permitnumber worktype           permittypedescr       description  \
# 200           A1048    ERECT  Amendment to a Long Form             Erect
# 444         A121115    ERECT  Amendment to a Long Form             Erect
# 445         A121135    ERECT  Amendment to a Long Form             Erect
# 620         A176767   NEWCON  Amendment to a Long Form  New construction
# 637          A18115   NEWCON  Amendment to a Long Form  New construction
# ...             ...      ...                       ...               ...
# 469184      SF93847   NEWCON    Short Form Bldg Permit  New construction
# 471339      SF95509    ERECT    Short Form Bldg Permit             Erect
# 472003      SF96041    ERECT    Short Form Bldg Permit             Erect
# 475958      SF99343    ERECT    Short Form Bldg Permit             Erect
# 477471    U49554804   NEWCON           Use of Premises  New construction
#
#                                                  comments  \
# 200     Revise rear apartment layout. Add roof deck to...
# 444     Slab  Foundation and related Site improvements...
# 445     Amend plans to the existing permit #ERT70819  ...
# 620     Submitting MEP Plans and all Engineering Affid...
# 637     Construct and fit-up of partial 4th floor prac...
# ...                                                   ...
# 469184  Install 6 ft (W) x12 ft (L) garden Storage She...
# 471339  1-24x24x24" stage with 1 set stairs and railin...
# 472003  Annual Erection of Harvard Stadium Air Support...
# 475958    remove rear stairs and replace same as existing
# 477471  Site Plan Proposed 12x16 Storage Shed;installa...
#
#                       applicant  declared_valuation  total_fees  \
# 200                 Hugh Meehan                 0.0        39.0
# 444             Joshua Swerling                 0.0       386.0
# 445                   dren luci             12000.0       158.0
# 620                Anthony Ross                 0.0        86.0
# 637                 Paul Pennie            625000.0      7445.0
# ...                         ...                 ...         ...
# 469184      Kristopher Furlonge              1000.0        30.0
# 471339  Boston Party Rental Inc              1350.0        40.0
# 472003     Christopher  McCann              42000.0       440.0
# 475958              john mercer              5000.0        70.0
# 477471          Jorge Rodriguez              6300.0        50.0
#
#                 issued_date      expiration_date  ... occupancytype   sq_feet  \
# 200     2010-03-30 11:51:01  2010-09-30 00:00:00  ...         Mixed       0.0
# 444     2012-04-18 09:45:56  2012-10-18 00:00:00  ...          Comm       0.0
# 445     2012-04-12 14:59:18  2012-10-12 00:00:00  ...        1-2FAM       0.0
# 620     2017-03-23 15:59:21  2017-09-23 00:00:00  ...         Mixed   18000.0
# 637     2010-09-02 12:07:46  2011-03-02 00:00:00  ...         Other   40910.0
# ...                     ...                  ...  ...           ...       ...
# 469184  2011-09-02 09:23:58  2012-03-02 00:00:00  ...         VacLd      72.0
# 471339  2011-09-14 15:30:35  2012-03-14 00:00:00  ...         VacLd     576.0
# 472003  2011-11-29 13:32:07                       ...         Mixed  192000.0
# 475958  2011-10-06 08:40:56  2012-04-06 00:00:00  ...        1-3FAM    3000.0
# 477471  2016-02-08 14:08:55  2016-08-08 00:00:00  ...        1-2FAM       0.0
#
#                            address           city state    zip property_id  \
# 200          1435-1437  Tremont ST   Mission Hill    MA  02120      172949
# 444              1833    Centre ST   West Roxbury    MA  02132       27732
# 445               109     Tudor ST   South Boston    MA  02127      138503
# 620         337-345   Belgrade AVE     Roslindale    MA  02131       13659
# 637             31     Hemenway ST         Boston    MA  02115       72664
# ...                            ...            ...   ...    ...         ...
# 469184           108     Perham ST   West Roxbury    MA  02132      109223
# 471339  1   Jewish War Veterans DR  Jamaica Plain    MA  02121      163434
# 472003            79  N Harvard ST        Allston    MA  02134      168218
# 475958           174  W Seventh ST   South Boston    MA  02127      125698
# 477471              93   Ormond ST       Mattapan    MA  02126      106019
#
#          parcel_id        lat       long
# 200     0902932002  42.331915 -71.096461
# 444     2006346010  42.286860 -71.154040
# 445     0600695000  42.336341 -71.053275
# 620     2001401000  42.286233 -71.145838
# 637     0401763000  42.345755 -71.089652
# ...            ...        ...        ...
# 469184  2008388000  42.283040 -71.164880
# 471339  1203486000  42.301029 -71.088551
# 472003  2200533000  42.366423 -71.126254
# 475958  0600920000  42.334770 -71.051280
# 477471  1404929010  42.282437 -71.093148
#
# [9173 rows x 22 columns]

# %%
df2['Cencus_Tract'] = df2.apply(lambda row: float(Coord_to_census_tract(row.lat, row.long)), axis=1)
df2
# Out:
#        permitnumber worktype           permittypedescr       description  \
# 200           A1048    ERECT  Amendment to a Long Form             Erect
# 444         A121115    ERECT  Amendment to a Long Form             Erect
# 445         A121135    ERECT  Amendment to a Long Form             Erect
# 620         A176767   NEWCON  Amendment to a Long Form  New construction
# 637          A18115   NEWCON  Amendment to a Long Form  New construction
# ...             ...      ...                       ...               ...
# 469184      SF93847   NEWCON    Short Form Bldg Permit  New construction
# 471339      SF95509    ERECT    Short Form Bldg Permit             Erect
# 472003      SF96041    ERECT    Short Form Bldg Permit             Erect
# 475958      SF99343    ERECT    Short Form Bldg Permit             Erect
# 477471    U49554804   NEWCON           Use of Premises  New construction
#
#                                                  comments  \
# 200     Revise rear apartment layout. Add roof deck to...
# 444     Slab  Foundation and related Site improvements...
# 445     Amend plans to the existing permit #ERT70819  ...
# 620     Submitting MEP Plans and all Engineering Affid...
# 637     Construct and fit-up of partial 4th floor prac...
# ...                                                   ...
# 469184  Install 6 ft (W) x12 ft (L) garden Storage She...
# 471339  1-24x24x24" stage with 1 set stairs and railin...
# 472003  Annual Erection of Harvard Stadium Air Support...
# 475958    remove rear stairs and replace same as existing
# 477471  Site Plan Proposed 12x16 Storage Shed;installa...
#
#                       applicant  declared_valuation  total_fees  \
# 200                 Hugh Meehan                 0.0        39.0
# 444             Joshua Swerling                 0.0       386.0
# 445                   dren luci             12000.0       158.0
# 620                Anthony Ross                 0.0        86.0
# 637                 Paul Pennie            625000.0      7445.0
# ...                         ...                 ...         ...
# 469184      Kristopher Furlonge              1000.0        30.0
# 471339  Boston Party Rental Inc              1350.0        40.0
# 472003     Christopher  McCann              42000.0       440.0
# 475958              john mercer              5000.0        70.0
# 477471          Jorge Rodriguez              6300.0        50.0
#
#                 issued_date      expiration_date  ...   sq_feet  \
# 200     2010-03-30 11:51:01  2010-09-30 00:00:00  ...       0.0
# 444     2012-04-18 09:45:56  2012-10-18 00:00:00  ...       0.0
# 445     2012-04-12 14:59:18  2012-10-12 00:00:00  ...       0.0
# 620     2017-03-23 15:59:21  2017-09-23 00:00:00  ...   18000.0
# 637     2010-09-02 12:07:46  2011-03-02 00:00:00  ...   40910.0
# ...                     ...                  ...  ...       ...
# 469184  2011-09-02 09:23:58  2012-03-02 00:00:00  ...      72.0
# 471339  2011-09-14 15:30:35  2012-03-14 00:00:00  ...     576.0
# 472003  2011-11-29 13:32:07                       ...  192000.0
# 475958  2011-10-06 08:40:56  2012-04-06 00:00:00  ...    3000.0
# 477471  2016-02-08 14:08:55  2016-08-08 00:00:00  ...       0.0
#
#                            address           city  state    zip property_id  \
# 200          1435-1437  Tremont ST   Mission Hill     MA  02120      172949
# 444              1833    Centre ST   West Roxbury     MA  02132       27732
# 445               109     Tudor ST   South Boston     MA  02127      138503
# 620         337-345   Belgrade AVE     Roslindale     MA  02131       13659
# 637             31     Hemenway ST         Boston     MA  02115       72664
# ...                            ...            ...    ...    ...         ...
# 469184           108     Perham ST   West Roxbury     MA  02132      109223
# 471339  1   Jewish War Veterans DR  Jamaica Plain     MA  02121      163434
# 472003            79  N Harvard ST        Allston     MA  02134      168218
# 475958           174  W Seventh ST   South Boston     MA  02127      125698
# 477471              93   Ormond ST       Mattapan     MA  02126      106019
#
#          parcel_id        lat       long Cencus_Tract
# 200     0902932002  42.331915 -71.096461       808.01
# 444     2006346010  42.286860 -71.154040      1302.00
# 445     0600695000  42.336341 -71.053275       608.00
# 620     2001401000  42.286233 -71.145838      1106.07
# 637     0401763000  42.345755 -71.089652       104.05
# ...            ...        ...        ...          ...
# 469184  2008388000  42.283040 -71.164880      1302.00
# 471339  1203486000  42.301029 -71.088551      9803.00
# 472003  2200533000  42.366423 -71.126254         1.00
# 475958  0600920000  42.334770 -71.051280       608.00
# 477471  1404929010  42.282437 -71.093148      1011.01
#
# [9173 rows x 23 columns]

# %%
sub_neigh = pd.read_csv("data/Sub-Neighborhoods.csv")
sub_neigh
# Out:
#      Census Tract#       Zipcode   Neighborhood US Geonames Sub-neigborhood  \
# 0             1.00  02134, 02135       Brighton                         NaN
# 1             2.01         02135       Brighton                         NaN
# 2             2.02         02135       Brighton                         NaN
# 3             3.01         02135       Brighton                         NaN
# 4             3.02         02135       Brighton                         NaN
# ..             ...           ...            ...                         ...
# 176        9815.02         02151    East Boston                         NaN
# 177        9816.00         02128    East Boston                         NaN
# 178        9817.00         02116    Beacon Hill                         NaN
# 179        9818.00  02130, 02215  Jamaica Plain                         NaN
# 180        9901.01         02130            NaN                         NaN
#
#     Total Population  Black Black Proportion  White White Proportion  \
# 0              5,324    311            5.84%  3,315           62.27%
# 1              3,991    237            5.94%  3,164           79.28%
# 2              4,272    263            6.16%  3,031           70.95%
# 3              2,946    216            7.33%  2,203           74.78%
# 4              3,469    359           10.35%  2,346           67.63%
# ..               ...    ...              ...    ...              ...
# 176                0      0            0.00%      0            0.00%
# 177                0      0            0.00%      0            0.00%
# 178                0      0            0.00%      0            0.00%
# 179               26      9           34.62%     17           65.38%
# 180               67     18           26.87%     49           73.13%
#
#      American Indian & Alaska Native  ...  Male  Male Proportion Female   \
# 0                                  0  ...  2,578          48.42%   2,746
# 1                                 17  ...  1,800          45.10%   2,191
# 2                                  0  ...  2,175          50.91%   2,097
# 3                                  0  ...  1,650          56.01%   1,296
# 4                                 25  ...  1,733          49.96%   1,736
# ..                               ...  ...    ...             ...     ...
# 176                                0  ...      0           0.00%       0
# 177                                0  ...      0           0.00%       0
# 178                                0  ...      0           0.00%       0
# 179                                0  ...      4          15.38%      22
# 180                                0  ...     55          82.09%      12
#
#     Female Proportion         Lat       Long Primary Sub-Neighborhood  \
# 0               51.58%  42.361484 -71.138588            Lower Allston
# 1               54.90%  42.354066 -71.161168               Oak Square
# 2               49.09%  42.352605 -71.154344               Oak Square
# 3               43.99%  42.354144 -71.168827            Hunnwell Hill
# 4               50.04%  42.347258 -71.167686                 Brighton
# ..                 ...        ...        ...                      ...
# 176              0.00%  42.396367 -71.004379                Beachmont
# 177              0.00%  42.388621 -70.993442           Orient Heights
# 178              0.00%  42.355087 -71.065743        Downtown Crossing
# 179             84.62%  42.323121 -71.116882         High Street Hill
# 180             17.91%  42.329611 -70.949200                      NaN
#
#      Secondary Sub-Neighborhood  Teritriary Sub-Neighborhood(s)  \
# 0                       Allston                Packard's Corner
# 1                      Brighton                  Hunnewell Hill
# 2                      Brighton                         Allston
# 3                    Oak Square                             NaN
# 4               St. Elizabeth's                             NaN
# ..                          ...                             ...
# 176              Orient Heights                             NaN
# 177                   Beachmont                             NaN
# 178                         NaN                             NaN
# 179                         NaN                             NaN
# 180                         NaN                             NaN
#
#                 T-Stop/Commuter Rail
# 0                     Boston Landing
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 176                        Beachmont
# 177                    Suffolk Downs
# 178                  Boylston Street
# 179  Heath Street / Back of the Hill
# 180                              NaN
#
# [181 rows x 23 columns]

# %%
sub_neigh['Census Tract#']
# Out:
# 0         1.00
# 1         2.01
# 2         2.02
# 3         3.01
# 4         3.02
#         ...
# 176    9815.02
# 177    9816.00
# 178    9817.00
# 179    9818.00
# 180    9901.01
# Name: Census Tract#, Length: 181, dtype: float64

# %%
sub_neigh['Census Tract#'] = sub_neigh.apply(lambda row: float(row['Census Tract#']), axis=1)
sub_neigh
# Out:
#      Census Tract#       Zipcode   Neighborhood US Geonames Sub-neigborhood  \
# 0             1.00  02134, 02135       Brighton                         NaN
# 1             2.01         02135       Brighton                         NaN
# 2             2.02         02135       Brighton                         NaN
# 3             3.01         02135       Brighton                         NaN
# 4             3.02         02135       Brighton                         NaN
# ..             ...           ...            ...                         ...
# 176        9815.02         02151    East Boston                         NaN
# 177        9816.00         02128    East Boston                         NaN
# 178        9817.00         02116    Beacon Hill                         NaN
# 179        9818.00  02130, 02215  Jamaica Plain                         NaN
# 180        9901.01         02130            NaN                         NaN
#
#     Total Population  Black Black Proportion  White White Proportion  \
# 0              5,324    311            5.84%  3,315           62.27%
# 1              3,991    237            5.94%  3,164           79.28%
# 2              4,272    263            6.16%  3,031           70.95%
# 3              2,946    216            7.33%  2,203           74.78%
# 4              3,469    359           10.35%  2,346           67.63%
# ..               ...    ...              ...    ...              ...
# 176                0      0            0.00%      0            0.00%
# 177                0      0            0.00%      0            0.00%
# 178                0      0            0.00%      0            0.00%
# 179               26      9           34.62%     17           65.38%
# 180               67     18           26.87%     49           73.13%
#
#      American Indian & Alaska Native  ...  Male  Male Proportion Female   \
# 0                                  0  ...  2,578          48.42%   2,746
# 1                                 17  ...  1,800          45.10%   2,191
# 2                                  0  ...  2,175          50.91%   2,097
# 3                                  0  ...  1,650          56.01%   1,296
# 4                                 25  ...  1,733          49.96%   1,736
# ..                               ...  ...    ...             ...     ...
# 176                                0  ...      0           0.00%       0
# 177                                0  ...      0           0.00%       0
# 178                                0  ...      0           0.00%       0
# 179                                0  ...      4          15.38%      22
# 180                                0  ...     55          82.09%      12
#
#     Female Proportion         Lat       Long Primary Sub-Neighborhood  \
# 0               51.58%  42.361484 -71.138588            Lower Allston
# 1               54.90%  42.354066 -71.161168               Oak Square
# 2               49.09%  42.352605 -71.154344               Oak Square
# 3               43.99%  42.354144 -71.168827            Hunnwell Hill
# 4               50.04%  42.347258 -71.167686                 Brighton
# ..                 ...        ...        ...                      ...
# 176              0.00%  42.396367 -71.004379                Beachmont
# 177              0.00%  42.388621 -70.993442           Orient Heights
# 178              0.00%  42.355087 -71.065743        Downtown Crossing
# 179             84.62%  42.323121 -71.116882         High Street Hill
# 180             17.91%  42.329611 -70.949200                      NaN
#
#      Secondary Sub-Neighborhood  Teritriary Sub-Neighborhood(s)  \
# 0                       Allston                Packard's Corner
# 1                      Brighton                  Hunnewell Hill
# 2                      Brighton                         Allston
# 3                    Oak Square                             NaN
# 4               St. Elizabeth's                             NaN
# ..                          ...                             ...
# 176              Orient Heights                             NaN
# 177                   Beachmont                             NaN
# 178                         NaN                             NaN
# 179                         NaN                             NaN
# 180                         NaN                             NaN
#
#                 T-Stop/Commuter Rail
# 0                     Boston Landing
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 176                        Beachmont
# 177                    Suffolk Downs
# 178                  Boylston Street
# 179  Heath Street / Back of the Hill
# 180                              NaN
#
# [181 rows x 23 columns]

# %%
sub_neigh['White Proportion'] = sub_neigh.apply(lambda row: float(row['White Proportion'][:-1]), axis=1)
sub_neigh
# Out:
#      Census Tract#       Zipcode   Neighborhood US Geonames Sub-neigborhood  \
# 0             1.00  02134, 02135       Brighton                         NaN
# 1             2.01         02135       Brighton                         NaN
# 2             2.02         02135       Brighton                         NaN
# 3             3.01         02135       Brighton                         NaN
# 4             3.02         02135       Brighton                         NaN
# ..             ...           ...            ...                         ...
# 176        9815.02         02151    East Boston                         NaN
# 177        9816.00         02128    East Boston                         NaN
# 178        9817.00         02116    Beacon Hill                         NaN
# 179        9818.00  02130, 02215  Jamaica Plain                         NaN
# 180        9901.01         02130            NaN                         NaN
#
#     Total Population  Black Black Proportion  White  White Proportion  \
# 0              5,324    311            5.84%  3,315             62.27
# 1              3,991    237            5.94%  3,164             79.28
# 2              4,272    263            6.16%  3,031             70.95
# 3              2,946    216            7.33%  2,203             74.78
# 4              3,469    359           10.35%  2,346             67.63
# ..               ...    ...              ...    ...               ...
# 176                0      0            0.00%      0              0.00
# 177                0      0            0.00%      0              0.00
# 178                0      0            0.00%      0              0.00
# 179               26      9           34.62%     17             65.38
# 180               67     18           26.87%     49             73.13
#
#      American Indian & Alaska Native  ...  Male  Male Proportion Female   \
# 0                                  0  ...  2,578          48.42%   2,746
# 1                                 17  ...  1,800          45.10%   2,191
# 2                                  0  ...  2,175          50.91%   2,097
# 3                                  0  ...  1,650          56.01%   1,296
# 4                                 25  ...  1,733          49.96%   1,736
# ..                               ...  ...    ...             ...     ...
# 176                                0  ...      0           0.00%       0
# 177                                0  ...      0           0.00%       0
# 178                                0  ...      0           0.00%       0
# 179                                0  ...      4          15.38%      22
# 180                                0  ...     55          82.09%      12
#
#     Female Proportion         Lat       Long Primary Sub-Neighborhood  \
# 0               51.58%  42.361484 -71.138588            Lower Allston
# 1               54.90%  42.354066 -71.161168               Oak Square
# 2               49.09%  42.352605 -71.154344               Oak Square
# 3               43.99%  42.354144 -71.168827            Hunnwell Hill
# 4               50.04%  42.347258 -71.167686                 Brighton
# ..                 ...        ...        ...                      ...
# 176              0.00%  42.396367 -71.004379                Beachmont
# 177              0.00%  42.388621 -70.993442           Orient Heights
# 178              0.00%  42.355087 -71.065743        Downtown Crossing
# 179             84.62%  42.323121 -71.116882         High Street Hill
# 180             17.91%  42.329611 -70.949200                      NaN
#
#      Secondary Sub-Neighborhood  Teritriary Sub-Neighborhood(s)  \
# 0                       Allston                Packard's Corner
# 1                      Brighton                  Hunnewell Hill
# 2                      Brighton                         Allston
# 3                    Oak Square                             NaN
# 4               St. Elizabeth's                             NaN
# ..                          ...                             ...
# 176              Orient Heights                             NaN
# 177                   Beachmont                             NaN
# 178                         NaN                             NaN
# 179                         NaN                             NaN
# 180                         NaN                             NaN
#
#                 T-Stop/Commuter Rail
# 0                     Boston Landing
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 176                        Beachmont
# 177                    Suffolk Downs
# 178                  Boylston Street
# 179  Heath Street / Back of the Hill
# 180                              NaN
#
# [181 rows x 23 columns]

# %%
sub_neigh.loc[sub_neigh['White Proportion'] > 75.0]
# Out:
#      Census Tract#       Zipcode             Neighborhood  \
# 1             2.01         02135                 Brighton
# 5             4.01         02135                 Brighton
# 6             4.02         02135                 Brighton
# 7             5.02  02135, 02467                 Brighton
# 8             5.03         02135                 Brighton
# ..             ...           ...                      ...
# 154        1302.00         02132             West Roxbury
# 155        1303.00         02132             West Roxbury
# 156        1304.02         02132             West Roxbury
# 173        9812.02  02127, 02210  South Boston Waterfront
# 174        9813.00         02128              East Boston
#
#     US Geonames Sub-neigborhood Total Population  Black Black Proportion  \
# 1                           NaN            3,991    237            5.94%
# 5                      Aberdeen            5,691    137            2.41%
# 6                      Brighton            3,494    150            4.29%
# 7                           NaN            5,796    155            2.67%
# 8                           NaN            2,007     77            3.84%
# ..                          ...              ...    ...              ...
# 154                    Highland            5,299    255            4.81%
# 155                West Roxbury            4,519    170            3.76%
# 156                         NaN            4,934    204            4.13%
# 173  Fort Winthrop (historical)              215     27           12.56%
# 174                         NaN              400     20            5.00%
#
#      White  White Proportion  American Indian & Alaska Native  ...  Male   \
# 1    3,164             79.28                               17  ...  1,800
# 5    4,404             77.39                               34  ...  2,669
# 6    2,868             82.08                                0  ...  1,806
# 7    4,917             84.83                               12  ...  2,574
# 8    1,633             81.37                              109  ...  1,002
# ..     ...               ...                              ...  ...    ...
# 154  4,812             90.81                               56  ...  2,526
# 155  3,948             87.36                                0  ...  2,094
# 156  4,084             82.77                               95  ...  2,128
# 173    179             83.26                                0  ...    206
# 174    362             90.50                                0  ...    284
#
#     Male Proportion Female  Female Proportion         Lat       Long  \
# 1            45.10%   2,191             54.90%  42.354066 -71.161168
# 5            46.90%   3,022             53.10%  42.343849 -71.149293
# 6            51.69%   1,688             48.31%  42.344174 -71.158829
# 7            44.41%   3,222             55.59%  42.331505 -71.157497
# 8            49.93%   1,005             50.07%  42.339636 -71.150099
# ..              ...     ...                ...        ...        ...
# 154          47.67%   2,773             52.33%  42.287332 -71.157012
# 155          46.34%   2,425             53.66%  42.279129 -71.150710
# 156          43.13%   2,806             56.87%  42.272401 -71.169406
# 173          95.81%       9              4.19%  42.343916 -71.024362
# 174          71.00%     116             29.00%  42.361129 -71.006975
#
#                    Primary Sub-Neighborhood  Secondary Sub-Neighborhood  \
# 1                                Oak Square                    Brighton
# 5                           St. Elizabeth's                  Oak Square
# 6                           St. Elizabeth's                    Brighton
# 7    Chestnut Hill Neighborhood Association                 Fisher Hill
# 8                                  Aberdeen   Salisbury Road-Corey Farm
# ..                                      ...                         ...
# 154                              Brook Farm                         NaN
# 155                           Bellevue Hill                     Roxbury
# 156          Upper Washington/Spring Street                         NaN
# 173                              City Point              Telegraph Hill
# 174                          Jeffries Point                         NaN
#
#      Teritriary Sub-Neighborhood(s)  \
# 1                    Hunnewell Hill
# 5                        Corey Hill
# 6               Aberdeen/Oak Square
# 7                               NaN
# 8                        Corey Hill
# ..                              ...
# 154                             NaN
# 155                             NaN
# 156                             NaN
# 173          D Street/West Broadway
# 174                             NaN
#
#                                   T-Stop/Commuter Rail
# 1                                                  NaN
# 5    Sutherland Road/Chiswick Road/Chestnut Hill Av...
# 6                                         South Street
# 7        Chestnut Hill Ave/ Reservoir/Cleveland Circle
# 8    Sutherland Road/Chiswick Road/Chestnut Hill Av...
# ..                                                 ...
# 154                                           Highland
# 155                                  Woodard Rd @ Wren
# 156                               Spring Street @ Goud
# 173                                                NaN
# 174                                                NaN
#
# [62 rows x 23 columns]

# %%
merged = pd.merge(df2, sub_neigh, left_on="Cencus_Tract", right_on="Census Tract#")
merged
# Out:
#      permitnumber worktype           permittypedescr       description  \
# 0           A1048    ERECT  Amendment to a Long Form             Erect
# 1          A21302   NEWCON  Amendment to a Long Form  New construction
# 2       COO752522    ERECT  Certificate of Occupancy             Erect
# 3       COO752522    ERECT  Certificate of Occupancy             Erect
# 4       COO752522    ERECT  Certificate of Occupancy             Erect
# ...           ...      ...                       ...               ...
# 9164  EXCA-800149     Main         Excavation Permit       Maintenance
# 9165      SF95509    ERECT    Short Form Bldg Permit             Erect
# 9166  EXCA-930860     Main         Excavation Permit       Maintenance
# 9167  EXCA-930864     Main         Excavation Permit       Maintenance
# 9168      SF76652    ERECT    Short Form Bldg Permit             Erect
#
#                                                comments  \
# 0     Revise rear apartment layout. Add roof deck to...
# 1     Add 2 individual roof decks to 2 top floor uni...
# 2     (18) Residential units and;retail space on fir...
# 3     (18) Residential units and;retail space on fir...
# 4     (18) Residential units and;retail space on fir...
# ...                                                 ...
# 9164  install new light base; //; Boston Police Deta...
# 9165  1-24x24x24" stage with 1 set stairs and railin...
# 9166  REPLACE EXIST TEL CONDUIT RDWY-SDWK 88x2 // BO...
# 9167  REPLACE EXIST TEL CONDUIT RDWY-SDWK 95x2 // BO...
# 9168  installation of tents for annual Hot Dog Safar...
#
#                     applicant  declared_valuation  total_fees  \
# 0                 Hugh Meehan                 0.0       39.00
# 1               Philip Hresko             15000.0      246.00
# 2              Ken McLaughlin                 0.0      560.00
# 3              Ken McLaughlin                 0.0      560.00
# 4              Ken McLaughlin                 0.0      560.00
# ...                       ...                 ...         ...
# 9164                      NaN                 0.0      110.00
# 9165  Boston Party Rental Inc              1350.0       40.00
# 9166                      NaN                 0.0     7584.35
# 9167                      NaN                 0.0     3075.70
# 9168          Donald McCarthy              1000.0       30.00
#
#               issued_date      expiration_date  ...  Male  Male Proportion  \
# 0     2010-03-30 11:51:01  2010-09-30 00:00:00  ...  2,274          50.34%
# 1     2010-05-13 13:59:40  2010-11-13 00:00:00  ...  2,274          50.34%
# 2     2018-03-27 00:00:00                       ...  2,274          50.34%
# 3     2018-03-27 00:00:00                       ...  2,274          50.34%
# 4     2018-03-27 00:00:00                       ...  2,274          50.34%
# ...                   ...                  ...  ...    ...             ...
# 9164  2018-02-08 21:02:48  2018-03-09 00:00:00  ...    295          77.63%
# 9165  2011-09-14 15:30:35  2012-03-14 00:00:00  ...    295          77.63%
# 9166  2019-04-11 15:45:39  2019-04-16 00:00:00  ...      0           0.00%
# 9167  2019-04-11 15:46:06  2019-04-16 00:00:00  ...      0           0.00%
# 9168  2011-05-12 13:23:50  2011-11-12 00:00:00  ...      0           0.00%
#
#      Female   Female Proportion         Lat       Long  \
# 0      2,243              49.66%  42.334606 -71.096210
# 1      2,243              49.66%  42.334606 -71.096210
# 2      2,243              49.66%  42.334606 -71.096210
# 3      2,243              49.66%  42.334606 -71.096210
# 4      2,243              49.66%  42.334606 -71.096210
# ...      ...                 ...        ...        ...
# 9164      85              22.37%  42.300613 -71.094613
# 9165      85              22.37%  42.300613 -71.094613
# 9166       0               0.00%  42.388621 -70.993442
# 9167       0               0.00%  42.388621 -70.993442
# 9168       0               0.00%  42.396367 -71.004379
#
#                         Primary Sub-Neighborhood Secondary Sub-Neighborhood  \
# 0     Frederick Douglas Square Historic District              Lower Roxbury
# 1     Frederick Douglas Square Historic District              Lower Roxbury
# 2     Frederick Douglas Square Historic District              Lower Roxbury
# 3     Frederick Douglas Square Historic District              Lower Roxbury
# 4     Frederick Douglas Square Historic District              Lower Roxbury
# ...                                          ...                        ...
# 9164                                     Roxbury                 Dorchester
# 9165                                     Roxbury                 Dorchester
# 9166                              Orient Heights                  Beachmont
# 9167                              Orient Heights                  Beachmont
# 9168                                   Beachmont             Orient Heights
#
#      Teritriary Sub-Neighborhood(s)           T-Stop/Commuter Rail
# 0                    Fenway-Kenmore  Longwood Medical Area/Ruggles
# 1                    Fenway-Kenmore  Longwood Medical Area/Ruggles
# 2                    Fenway-Kenmore  Longwood Medical Area/Ruggles
# 3                    Fenway-Kenmore  Longwood Medical Area/Ruggles
# 4                    Fenway-Kenmore  Longwood Medical Area/Ruggles
# ...                             ...                            ...
# 9164        Forest Hills Woodbourne                            NaN
# 9165        Forest Hills Woodbourne                            NaN
# 9166                            NaN                  Suffolk Downs
# 9167                            NaN                  Suffolk Downs
# 9168                            NaN                      Beachmont
#
# [9169 rows x 46 columns]

# %%
merged.loc[merged['White Proportion'] > 75.0]
# Out:
#      permitnumber worktype           permittypedescr  description  \
# 38        A121115    ERECT  Amendment to a Long Form        Erect
# 39      COO563429    ERECT  Certificate of Occupancy        Erect
# 40      COO706319    ERECT  Certificate of Occupancy        Erect
# 41      COO987899    ERECT  Certificate of Occupancy        Erect
# 42        E106890    ERECT         Electrical Permit        Erect
# ...           ...      ...                       ...          ...
# 9136  EXCA-942441     Main         Excavation Permit  Maintenance
# 9137  EXCA-956817     Main         Excavation Permit  Maintenance
# 9138  EXCA-968921     Main         Excavation Permit  Maintenance
# 9139  EXCA-971221     Main         Excavation Permit  Maintenance
# 9140  EXCA-972278     Main         Excavation Permit  Maintenance
#
#                                                comments  \
# 38    Slab  Foundation and related Site improvements...
# 39    Eight Unit BuildingERT301170  issued: 3/19/15 ...
# 40     Single Family Dwelling Ert 411049 issued 5/21/15
# 41    Sixteen (16);Residential Units ;Commercial;Spa...
# 42    electrical work in conjunction with installati...
# ...                                                 ...
# 9136  REPLACE DEFECTIVE CONDUIT RDWY 5x2 / BOSTON FI...
# 9137  REPAIR EXISTING TELEPHONE CONDUIT IN SDWK 5x5 ...
# 9138  ABANDON; INACTIVE GAS SERVICE; 5 X 4 RDWY;; GU...
# 9139  PERM TRENCH REPAIR;;; SUSI;; 9:30AM-3:30PM; MO...
# 9140  SDWK RECONSTRUCTION;; (SDWK DEP PD);; 7AM-4PM;...
#
#                           applicant  declared_valuation  total_fees  \
# 38                  Joshua Swerling                 0.0      386.00
# 39                     John Omalley            900000.0     3875.00
# 40                     Anthony Ross            300000.0      235.00
# 41    greg ALLSTON STREET GROUP LLC           3362500.0     5420.00
# 42                  DENNIS SULLIVAN                 1.0       26.00
# ...                             ...                 ...         ...
# 9136                            NaN                 0.0      309.70
# 9137                            NaN                 0.0      255.00
# 9138                            NaN                 0.0     3103.78
# 9139                            NaN                 0.0      118.00
# 9140                            NaN                 0.0      118.00
#
#               issued_date      expiration_date  ...  Male  Male Proportion  \
# 38    2012-04-18 09:45:56  2012-10-18 00:00:00  ...  2,526          47.67%
# 39    2016-02-23 11:11:50                       ...  2,526          47.67%
# 40    2017-05-17 14:07:38                       ...  2,526          47.67%
# 41    2019-09-03 10:27:23                       ...  2,526          47.67%
# 42    2011-11-22 08:48:36  2012-05-22 00:00:00  ...  2,526          47.67%
# ...                   ...                  ...  ...    ...             ...
# 9136  2019-09-20 15:05:45  2019-05-21 00:00:00  ...  1,095          44.01%
# 9137  2019-09-23 08:26:58  2019-06-17 00:00:00  ...  1,095          44.01%
# 9138  2019-06-26 10:15:26  2019-07-28 00:00:00  ...  1,095          44.01%
# 9139  2019-07-03 15:57:41  2019-08-06 00:00:00  ...  1,095          44.01%
# 9140  2019-07-03 12:03:44  2019-07-21 00:00:00  ...  1,095          44.01%
#
#      Female   Female Proportion         Lat       Long  \
# 38     2,773              52.33%  42.287332 -71.157012
# 39     2,773              52.33%  42.287332 -71.157012
# 40     2,773              52.33%  42.287332 -71.157012
# 41     2,773              52.33%  42.287332 -71.157012
# 42     2,773              52.33%  42.287332 -71.157012
# ...      ...                 ...        ...        ...
# 9136   1,393              55.99%  42.367537 -71.051959
# 9137   1,393              55.99%  42.367537 -71.051959
# 9138   1,393              55.99%  42.367537 -71.051959
# 9139   1,393              55.99%  42.367537 -71.051959
# 9140   1,393              55.99%  42.367537 -71.051959
#
#      Primary Sub-Neighborhood Secondary Sub-Neighborhood  \
# 38                 Brook Farm                        NaN
# 39                 Brook Farm                        NaN
# 40                 Brook Farm                        NaN
# 41                 Brook Farm                        NaN
# 42                 Brook Farm                        NaN
# ...                       ...                        ...
# 9136              East Boston                 Waterfront
# 9137              East Boston                 Waterfront
# 9138              East Boston                 Waterfront
# 9139              East Boston                 Waterfront
# 9140              East Boston                 Waterfront
#
#      Teritriary Sub-Neighborhood(s) T-Stop/Commuter Rail
# 38                              NaN             Highland
# 39                              NaN             Highland
# 40                              NaN             Highland
# 41                              NaN             Highland
# 42                              NaN             Highland
# ...                             ...                  ...
# 9136                            NaN                  NaN
# 9137                            NaN                  NaN
# 9138                            NaN                  NaN
# 9139                            NaN                  NaN
# 9140                            NaN                  NaN
#
# [4042 rows x 46 columns]

# %%
len(sub_neigh.loc[sub_neigh['White Proportion'] > 50.0].index)/len(sub_neigh.index)
# Out:
# 0.6408839779005525

# %%
len(merged.loc[merged['White Proportion'] > 50.0].index)/len(merged.index)
# Out:
# 0.7069473224997274

# %%
len(sub_neigh.loc[sub_neigh['White Proportion'] > 75.0].index)/len(sub_neigh.index)
# Out:
# 0.3425414364640884

# %%
len(merged.loc[merged['White Proportion'] > 75.0].index)/len(merged.index)
# Out:
# 0.44083324244737704

# %%
counts = merged.groupby('Neighborhood').agg('size')
percents = (counts/len(merged.index))*100
percents.sort_values(ascending=False)
# Out:
# Neighborhood
# Dorchester                 15.356091
# South Boston               10.415531
# Roxbury                     8.561457
# Downtown                    7.481732
# East Boston                 6.936416
# Brighton                    5.693096
# Jamaica Plain               5.474970
# South End                   5.398626
# West Roxbury                4.929654
# Hyde Park                   4.231650
# Roslindale                  3.740866
# Charlestown                 3.141019
# Back Bay                    3.064674
# Fenway                      2.759298
# Mattapan                    2.377577
# Mission Hill                2.028575
# South Boston Waterfront     1.854074
# North End                   1.821355
# Allston                     1.766823
# Beacon Hill                 1.352383
# West End                    0.981568
# Longwood Medical Area       0.632566
# dtype: float64

# %%
pd.set_option('display.max_rows', 100)
counts = merged.groupby('Primary Sub-Neighborhood').agg('size')
percents = (counts/len(merged.index))*100
percents.sort_values(ascending=False)
# Out:
# Primary Sub-Neighborhood
# Back Bay                                      4.820591
# Boston                                        4.046243
# Telegraph Hill                                3.871742
# Downtown Crossing                             3.326426
# Franklin Field South                          3.304613
# D Street / West Broadway                      3.097393
# Nubian Square                                 2.257607
# Allston                                       2.094012
# Bunker Hill                                   1.984949
# Frederick Douglas Square Historic District    1.963137
# Hyde Park                                     1.908605
# Brook Farm                                    1.843167
# South Boston                                  1.777729
# Seaport District                              1.690479
# Columbus Park/Andrew Square                   1.646854
# Upper Washington/Spring Street                1.559603
# West End                                      1.515978
# Lower Roxbury                                 1.505071
# East Boston                                   1.494165
# Roslindale                                    1.483259
# Central Maverick Square/Paris Square          1.472352
# West Street/River Street                      1.461446
# Oak Square                                    1.428727
# Charlestown                                   1.374196
# Upham's Corner                                1.352383
# Lower Allston                                 1.352383
# China Town                                    1.341477
# Shawmut                                       1.319664
# Dudley/Brunswick King                         1.308758
# Mission Hill                                  1.308758
# City Point                                    1.254226
# Forest Hills/Woodbourne                       1.177882
# Metropolitan Hill/Beech Street                1.145163
# Codman Square                                 1.123350
# Roxbury                                       1.101538
# Medford Street/The Neck                       1.057913
# Clam Point                                    1.047006
# Egleston Square                               1.047006
# South End                                     1.036100
# Roxbury                                       0.992475
# Harbor View/Orient Heights                    0.992475
# Jones Hill                                    0.981568
# Georgetown                                    0.970662
# Columbus                                      0.970662
# West Codman Hill/ West Lower Mills            0.970662
# Stonybrook                                    0.959756
# Fenway-Kenmore                                0.927037
# Fort Hill                                     0.916130
# Jeffries Point                                0.916130
# Eagle Hill                                    0.894318
# St. Elizabeth's                               0.883411
# Jamaica Plain                                 0.850693
# Bellevue Hill                                 0.763442
# Orient Heights                                0.752536
# Washington Park                               0.752536
# Ashmount                                      0.730723
# Neponset/Port Norfolk                         0.698004
# Bay Village                                   0.698004
# Washington Park                               0.687098
# Central Village                               0.687098
# Dorchester                                    0.676192
# West Fens                                     0.643473
# Salisbury Road-Corey Farm                     0.621660
# Back Bay West / Back Bay                      0.578035
# Washington Hill                               0.545316
# Bowdoin North/Mount Bodoin                    0.545316
# Adams Village                                 0.523503
# Southern Mattapan                             0.512597
# Fields Corner Wester                          0.479878
# Centre South                                  0.458065
# Chestnut Hill Neighborhood Association        0.436253
# Milton Hill                                   0.436253
# St. Marks                                     0.414440
# Wellington Hill                               0.392627
# Mattapan                                      0.381721
# Dorcehster Center                             0.381721
# Meeting House Hill                            0.359908
# Roslindale                                    0.327189
# Brighton                                      0.305377
# Washington /Mount Hope                        0.294470
# Grove Hall                                    0.283564
# Hunnwell Hill                                 0.272658
# Jamaica Hills                                 0.229033
# High Street Hill                              0.196314
# Ashcroft                                      0.196314
# Aberdeen                                      0.065438
# Beachmont                                     0.010906
# dtype: float64

# %%
counts = merged[['Neighborhood', 'White Proportion']]
counts = counts.groupby('Neighborhood').agg(['size', np.mean])
counts['Percents'] = counts['White Proportion']['size']/len(merged.index)*100
counts['Mean White Proportion'] = counts['White Proportion']['mean']
counts = counts.drop(columns=['White Proportion'])
counts.sort_values('Percents', ascending=False)
# Out:
#                           Percents Mean White Proportion
#
# Neighborhood
# Dorchester               15.356091             34.231591
# South Boston             10.415531             90.813581
# Roxbury                   8.561457             21.117885
# Downtown                  7.481732             64.754052
# East Boston               6.936416             87.095425
# Brighton                  5.693096             71.774425
# Jamaica Plain             5.474970             70.008147
# South End                 5.398626             64.634525
# West Roxbury              4.929654             82.058628
# Hyde Park                 4.231650             37.317655
# Roslindale                3.740866             68.509825
# Charlestown               3.141019             85.672951
# Back Bay                  3.064674             83.662740
# Fenway                    2.759298             69.923636
# Mattapan                  2.377577             12.923899
# Mission Hill              2.028575             50.786882
# South Boston Waterfront   1.854074             85.803824
# North End                 1.821355             95.040359
# Allston                   1.766823             61.368519
# Beacon Hill               1.352383             87.569435
# West End                  0.981568             71.904444
# Longwood Medical Area     0.632566             77.980000

# %%
counts = merged[['Primary Sub-Neighborhood', 'White Proportion']]
counts = counts.groupby('Primary Sub-Neighborhood').agg(['size', np.mean])
counts['Percents'] = counts['White Proportion']['size']/len(merged.index)*100
counts['Mean White Proportion'] = counts['White Proportion']['mean']
counts = counts.drop(columns=['White Proportion'])
counts.sort_values('Percents', ascending=False)
# Out:
#                                             Percents Mean White Proportion
#
# Primary Sub-Neighborhood
# Back Bay                                    4.820591             79.789140
# Boston                                      4.046243             84.698302
# Telegraph Hill                              3.871742             95.792282
# Downtown Crossing                           3.326426             60.186230
# Franklin Field South                        3.304613             13.902607
# D Street / West Broadway                    3.097393             92.436761
# Nubian Square                               2.257607             12.907053
# Allston                                     2.094012             59.559063
# Bunker Hill                                 1.984949             82.873571
# Frederick Douglas Square Historic District  1.963137             51.908389
# Hyde Park                                   1.908605             39.812171
# Brook Farm                                  1.843167             88.310592
# South Boston                                1.777729             86.820000
# Seaport District                            1.690479             86.050000
# Columbus Park/Andrew Square                 1.646854             69.579801
# Upper Washington/Spring Street              1.559603             78.370280
# West End                                    1.515978             90.803525
# Lower Roxbury                               1.505071             21.064203
# East Boston                                 1.494165             85.712628
# Roslindale                                  1.483259             82.688676
# Central Maverick Square/Paris Square        1.472352             91.837778
# West Street/River Street                    1.461446             26.594403
# Oak Square                                  1.428727             73.978626
# Charlestown                                 1.374196             85.742143
# Lower Allston                               1.352383             62.935806
# Upham's Corner                              1.352383             47.395242
# China Town                                  1.341477             39.010000
# Shawmut                                     1.319664             58.824628
# Mission Hill                                1.308758             61.357083
# Dudley/Brunswick King                       1.308758             14.358333
# City Point                                  1.254226             92.092696
# Forest Hills/Woodbourne                     1.177882             55.584074
# Metropolitan Hill/Beech Street              1.145163             70.343810
# Codman Square                               1.123350             22.780000
# Roxbury                                     1.101538             19.340594
# Medford Street/The Neck                     1.057913             91.320000
# Egleston Square                             1.047006             82.402292
# Clam Point                                  1.047006             29.970000
# South End                                   1.036100             66.799263
# Roxbury                                     0.992475             56.660000
# Harbor View/Orient Heights                  0.992475             85.620000
# Jones Hill                                  0.981568             45.060667
# Columbus                                    0.970662             75.858876
# West Codman Hill/ West Lower Mills          0.970662             12.125843
# Georgetown                                  0.970662             46.090000
# Stonybrook                                  0.959756             72.520000
# Fenway-Kenmore                              0.927037             74.990941
# Fort Hill                                   0.916130             41.790476
# Jeffries Point                              0.916130             92.617500
# Eagle Hill                                  0.894318             81.979024
# St. Elizabeth's                             0.883411             80.111358
# Jamaica Plain                               0.850693             86.508718
# Bellevue Hill                               0.763442             87.360000
# Orient Heights                              0.752536             79.982464
# Washington Park                             0.752536             16.250000
# Ashmount                                    0.730723             61.580000
# Neponset/Port Norfolk                       0.698004             81.040000
# Bay Village                                 0.698004             35.950000
# Washington Park                             0.687098             22.170000
# Central Village                             0.687098             33.260000
# Dorchester                                  0.676192             15.251613
# West Fens                                   0.643473             70.497797
# Salisbury Road-Corey Farm                   0.621660             76.206842
# Back Bay West / Back Bay                    0.578035             84.159623
# Bowdoin North/Mount Bodoin                  0.545316             13.552000
# Washington Hill                             0.545316              7.400000
# Adams Village                               0.523503             94.670000
# Southern Mattapan                           0.512597              8.950000
# Fields Corner Wester                        0.479878             30.060000
# Centre South                                0.458065             88.750000
# Milton Hill                                 0.436253             28.620000
# Chestnut Hill Neighborhood Association      0.436253             84.830000
# St. Marks                                   0.414440             35.850000
# Wellington Hill                             0.392627              2.360000
# Mattapan                                    0.381721             12.560000
# Dorcehster Center                           0.381721             12.740000
# Meeting House Hill                          0.359908             20.153333
# Roslindale                                  0.327189             50.730000
# Brighton                                    0.305377             67.630000
# Washington /Mount Hope                      0.294470             33.030000
# Grove Hall                                  0.283564             17.970000
# Hunnwell Hill                               0.272658             74.780000
# Jamaica Hills                               0.229033             88.920000
# High Street Hill                            0.196314             69.080000
# Ashcroft                                    0.196314             53.490000
# Aberdeen                                    0.065438             81.370000
# Beachmont                                   0.010906              0.000000
