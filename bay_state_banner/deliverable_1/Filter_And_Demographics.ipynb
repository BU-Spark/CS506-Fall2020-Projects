# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import requests
import json

# %%
filepath = "data/abp_data.csv"

data = pd.read_csv(filepath)

# %%
data
# Out:
#        permitnumber worktype           permittypedescr  \
# 0           A100071      COB  Amendment to a Long Form
# 1          A1001012    OTHER  Amendment to a Long Form
# 2          A1001201   INTEXT  Amendment to a Long Form
# 3           A100137   EXTREN  Amendment to a Long Form
# 4          A1001913   INTREN  Amendment to a Long Form
# ...             ...      ...                       ...
# 478014    U49993435    OSEAT           Use of Premises
# 478015    U49993435    OSEAT           Use of Premises
# 478016    U49993492   TEMTRL           Use of Premises
# 478017     U4999352    DRIVE           Use of Premises
# 478018    U49996370   RESPAR           Use of Premises
#
#                        description  \
# 0                   City of Boston
# 1                            Other
# 2           Interior/Exterior Work
# 3           Renovations - Exterior
# 4       Renovations - Interior NSC
# ...                            ...
# 478014             Outside Seating
# 478015             Outside Seating
# 478016          Temporary Trailers
# 478017       Driveway Installation
# 478018         Residential Parking
#
#                                                  comments          applicant  \
# 0       Change connector link layout from attached enc...  Renee Santeusanio
# 1       Amend Alt943748 to erect a roof deck as per pl...   Jusimar Oliveria
# 2       Build steel balcony over garden level with sta...      Andreas Hwang
# 3       Landscaping/stonework - amending permit #2801/...                NaN
# 4       Amendment to issued permit ALT888985. relocate...       Ping Mandawe
# ...                                                   ...                ...
# 478014  Outdoor patio / amenity space for commercial o...  Christine McMahon
# 478015  Outdoor patio / amenity space for commercial o...  Christine McMahon
# 478016  Temporary Construction Trailer at Herb Chamber...   Regina  Olivieri
# 478017  Owners would like to install a curb cut and a ...    Maria Dubrowski
# 478018  use of premises for;1 car parking with new dri...      Cesar DaSilva
#
#         declared_valuation  total_fees          issued_date  \
# 0                 40000.00       429.0  2011-11-04 11:04:58
# 1                  5000.00        70.0  2020-06-01 14:08:47
# 2                 74295.75       803.0  2019-11-13 13:38:56
# 3                 15000.00       206.0  2013-01-03 14:13:09
# 4                     1.00        33.0  2019-10-18 09:21:00
# ...                    ...         ...                  ...
# 478014                0.00        50.0  2019-09-25 11:36:11
# 478015                0.00        50.0  2019-09-25 11:36:11
# 478016             1000.00        53.0  2019-09-12 13:07:00
# 478017             2700.00        53.0  2012-05-30 14:28:59
# 478018             7000.00        62.0  2020-09-17 16:18:18
#
#             expiration_date  ... occupancytype sq_feet  \
# 0       2012-05-04 00:00:00  ...          Comm   170.0
# 1       2020-12-01 00:00:00  ...        1-3FAM     0.0
# 2       2020-05-13 00:00:00  ...         Multi     0.0
# 3       2013-07-03 00:00:00  ...        1-2FAM     0.0
# 4       2020-04-18 00:00:00  ...          Comm     0.0
# ...                     ...  ...           ...     ...
# 478014  2020-03-25 00:00:00  ...         Mixed     0.0
# 478015  2020-03-25 00:00:00  ...         Mixed     0.0
# 478016  2020-03-12 00:00:00  ...          Comm     0.0
# 478017  2012-11-30 00:00:00  ...        1-2FAM     0.0
# 478018  2021-03-17 00:00:00  ...        1-2FAM     0.0
#
#                           address           city state    zip property_id  \
# 0              175  W Boundary RD   West Roxbury    MA  02132       17268
# 1               15    Prospect ST    Charlestown    MA  02129      113443
# 2           211  W Springfield ST        Roxbury    MA  02118      129994
# 3       14    William Jackson AVE       Brighton    MA  02135      149852
# 4          130-140   Brighton AVE        Allston    MA  02134       20073
# ...                           ...            ...   ...    ...         ...
# 478014              3   Center Pz         Boston    MA  02108      154961
# 478015              3   Center Pz         Boston    MA  02108      154961
# 478016     1188   Commonwealth Av        Allston    MA  02134      424193
# 478017         46    Burroughs ST  Jamaica Plain    MA  02130       24047
# 478018             17    Alpha RD     Dorchester    MA  02124        2829
#
#          parcel_id        lat       long
# 0       2012032000  42.260750 -71.149610
# 1       0202837000  42.375243 -71.057585
# 2       0402558000  42.340600 -71.080250
# 3       2204944000  42.344600 -71.154050
# 4       2100846000  42.352760 -71.131850
# ...            ...        ...        ...
# 478014  0302713000  42.359180 -71.060040
# 478015  0302717000  42.359180 -71.060040
# 478016  2101574010        NaN        NaN
# 478017  1901861000  42.313220 -71.117130
# 478018  1701099000  42.296190 -71.067970
#
# [478019 rows x 22 columns]

# %%
data['permittypedescr'].unique()
# Out:
# array(['Amendment to a Long Form', 'Certificate of Occupancy',
#        'Long Form/Alteration Permit', 'Electrical Permit',
#        'Short Form Bldg Permit', 'Electrical Fire Alarms',
#        'Electrical Low Voltage', 'Gas Permit',
#        'Electrical Temporary Service', 'Erect/New Construction',
#        'Excavation Permit', 'Foundation Permit', 'Plumbing Permit',
#        'Use of Premises'], dtype=object)

# %%
data['worktype'].unique()
# Out:
# array(['COB', 'OTHER', 'INTEXT', 'EXTREN', 'INTREN', 'VIOL', 'ADDITION',
#        'EXTDEM', 'FA', 'SPRINK', 'SIGNES', 'CELL', 'NEWCON', ' ', 'ERECT',
#        'SPRNK9', 'SITE', 'SOL', 'FSTTRK', 'CHGOCC', 'SPCEVE', 'INTDEM',
#        'General', 'CANP', 'AWNING', 'TCOO', 'ROOF', 'INSUL', 'GEN',
#        'GARAGE', 'NROCC', 'SD', 'ELECTRICAL', 'PLUMBING', 'LVOLT',
#        'FENCE2', 'SIDE', 'SIGNS', 'RESPAR', 'DRIVE', 'MAINT', 'TEMTRL',
#        'INDBLR', 'SPFT', 'RNWSIG', 'COMPAR', 'AWNRNW', 'AWNRET', 'CANPRN',
#        'RAZE', 'TMPSER', 'HOLVEN', 'OSEAT', 'FENCE', 'TMPUSOC', 'FLAM',
#        'CONVRT', 'SRVCHG', 'Repair', 'TVTRK', 'BFCHMDECMA', 'Service',
#        'Main', 'TRENCH', 'GAS', 'Capital', 'PVTEMER', 'New', 'INDFUR',
#        'BFCHMTENT', 'BFCHMFLOOR', 'BFCHMINFIN', 'BFCHMTEMPE', 'Fencing',
#        'SpecEvent', 'Dumpsters', 'BFCHMMATTR', 'Staging', 'SpeEvents'],
#       dtype=object)

# %%
data.loc[data['worktype'] == 'ERECT']
# Out:
#        permitnumber worktype           permittypedescr description  \
# 200           A1048    ERECT  Amendment to a Long Form       Erect
# 275         A107405    ERECT  Amendment to a Long Form       Erect
# 276         A107407    ERECT  Amendment to a Long Form       Erect
# 444         A121115    ERECT  Amendment to a Long Form       Erect
# 445         A121135    ERECT  Amendment to a Long Form       Erect
# ...             ...      ...                       ...         ...
# 471339      SF95509    ERECT    Short Form Bldg Permit       Erect
# 472003      SF96041    ERECT    Short Form Bldg Permit       Erect
# 475958      SF99343    ERECT    Short Form Bldg Permit       Erect
# 477044    U49228758    ERECT           Use of Premises       Erect
# 477499    U49584707    ERECT           Use of Premises       Erect
#
#                                                  comments  \
# 200     Revise rear apartment layout. Add roof deck to...
# 275     Adding 1 bedroom to top floor unit per approve...
# 276     Adding 1 bedroom to top floor unit per approve...
# 444     Slab  Foundation and related Site improvements...
# 445     Amend plans to the existing permit #ERT70819  ...
# ...                                                   ...
# 471339  1-24x24x24" stage with 1 set stairs and railin...
# 472003  Annual Erection of Harvard Stadium Air Support...
# 475958    remove rear stairs and replace same as existing
# 477044  Installing a "Shelter Logic" Shelter 35'x75'. ...
# 477499  Permit for an office trailer to be used for th...
#
#                       applicant  declared_valuation  total_fees  \
# 200                 Hugh Meehan                 0.0        39.0
# 275               Joe Hennessey                 0.0       390.0
# 276               Joe Hennessey                 0.0       270.0
# 444             Joshua Swerling                 0.0       386.0
# 445                   dren luci             12000.0       158.0
# ...                         ...                 ...         ...
# 471339  Boston Party Rental Inc              1350.0        40.0
# 472003     Christopher  McCann              42000.0       440.0
# 475958              john mercer              5000.0        70.0
# 477044              David Amato             60000.0        86.0
# 477499            William  Caci              2000.0        50.0
#
#                 issued_date      expiration_date  ... occupancytype   sq_feet  \
# 200     2010-03-30 11:51:01  2010-09-30 00:00:00  ...         Mixed       0.0
# 275     2012-02-28 15:46:37  2012-08-28 00:00:00  ...         Multi       0.0
# 276     2011-11-28 10:00:58  2012-08-28 00:00:00  ...         Multi       0.0
# 444     2012-04-18 09:45:56  2012-10-18 00:00:00  ...          Comm       0.0
# 445     2012-04-12 14:59:18  2012-10-12 00:00:00  ...        1-2FAM       0.0
# ...                     ...                  ...  ...           ...       ...
# 471339  2011-09-14 15:30:35  2012-03-14 00:00:00  ...         VacLd     576.0
# 472003  2011-11-29 13:32:07                       ...         Mixed  192000.0
# 475958  2011-10-06 08:40:56  2012-04-06 00:00:00  ...        1-3FAM    3000.0
# 477044  2013-12-18 09:05:42  2014-06-18 00:00:00  ...          Comm    2625.0
# 477499  2016-11-18 09:40:43  2017-05-18 00:00:00  ...         VacLd     225.0
#
#                                address           city state    zip  \
# 200              1435-1437  Tremont ST   Mission Hill    MA  02120
# 275                39-47  Sandpiper LN     Dorchester    MA  02124
# 276                  74-76  Osprey WAY     Dorchester    MA  02124
# 444                  1833    Centre ST   West Roxbury    MA  02132
# 445                   109     Tudor ST   South Boston    MA  02127
# ...                                ...            ...   ...    ...
# 471339      1   Jewish War Veterans DR  Jamaica Plain    MA  02121
# 472003                79  N Harvard ST        Allston    MA  02134
# 475958               174  W Seventh ST   South Boston    MA  02127
# 477044  450     William F Mcclellan HW    East Boston    MA  02128
# 477499                  88   Hudson ST         Boston    MA  02111
#
#        property_id   parcel_id        lat       long
# 200         172949  0902932002  42.331915 -71.096461
# 275         343074  1405196010        NaN        NaN
# 276         343076  1405196010        NaN        NaN
# 444          27732  2006346010  42.286860 -71.154040
# 445         138503  0600695000  42.336341 -71.053275
# ...            ...         ...        ...        ...
# 471339      163434  1203486000  42.301029 -71.088551
# 472003      168218  2200533000  42.366423 -71.126254
# 475958      125698  0600920000  42.334770 -71.051280
# 477044           0                    NaN        NaN
# 477499      354247  0304980000        NaN        NaN
#
# [3719 rows x 22 columns]

# %%
data.loc[data['worktype'] == 'NEWCON']
# Out:
#        permitnumber worktype           permittypedescr       description  \
# 100         A102296   NEWCON  Amendment to a Long Form  New construction
# 497          A13598   NEWCON  Amendment to a Long Form  New construction
# 501          A13611   NEWCON  Amendment to a Long Form  New construction
# 620         A176767   NEWCON  Amendment to a Long Form  New construction
# 637          A18115   NEWCON  Amendment to a Long Form  New construction
# ...             ...      ...                       ...               ...
# 469184      SF93847   NEWCON    Short Form Bldg Permit  New construction
# 470114      SF94544   NEWCON    Short Form Bldg Permit  New construction
# 470115      SF94544   NEWCON    Short Form Bldg Permit  New construction
# 477379    U49478253   NEWCON           Use of Premises  New construction
# 477471    U49554804   NEWCON           Use of Premises  New construction
#
#                                                  comments  \
# 100     Design change to the structural foundation of ...
# 497     1)Change 1st. fl.rear entrance from back of bu...
# 501     1)Change kitchen window location right and lef...
# 620     Submitting MEP Plans and all Engineering Affid...
# 637     Construct and fit-up of partial 4th floor prac...
# ...                                                   ...
# 469184  Install 6 ft (W) x12 ft (L) garden Storage She...
# 470114  sand and refinish floors.  paint all walls and...
# 470115  sand and refinish floors.  paint all walls and...
# 477379  A temporary (two years);greenhouse will be ere...
# 477471  Site Plan Proposed 12x16 Storage Shed;installa...
#
#                   applicant  declared_valuation  total_fees  \
# 100            Amy Sowersby                 0.0        38.0
# 497         Howard Robinson                 0.0        48.0
# 501         Howard Robinson              2000.0        83.0
# 620            Anthony Ross                 0.0        86.0
# 637             Paul Pennie            625000.0      7445.0
# ...                     ...                 ...         ...
# 469184  Kristopher Furlonge              1000.0        30.0
# 470114           Paul quinn             25000.0       270.0
# 470115           Paul quinn             25000.0       270.0
# 477379        Bruce Fulford             15000.0        53.0
# 477471      Jorge Rodriguez              6300.0        50.0
#
#                 issued_date      expiration_date  ... occupancytype  sq_feet  \
# 100     2011-11-25 11:10:19  2012-05-25 00:00:00  ...          Comm      0.0
# 497     2010-02-12 10:46:43  2010-08-12 00:00:00  ...        1-2FAM   2300.0
# 501     2013-07-29 23:13:32  2014-01-29 00:00:00  ...         7More  10000.0
# 620     2017-03-23 15:59:21  2017-09-23 00:00:00  ...         Mixed  18000.0
# 637     2010-09-02 12:07:46  2011-03-02 00:00:00  ...         Other  40910.0
# ...                     ...                  ...  ...           ...      ...
# 469184  2011-09-02 09:23:58  2012-03-02 00:00:00  ...         VacLd     72.0
# 470114  2011-09-07 14:50:42  2012-03-07 00:00:00  ...          Comm      0.0
# 470115  2011-09-07 14:50:42  2012-03-07 00:00:00  ...          Comm      0.0
# 477379  2015-06-22 11:15:29  2015-12-22 00:00:00  ...         Mixed      0.0
# 477471  2016-02-08 14:08:55  2016-08-08 00:00:00  ...        1-2FAM      0.0
#
#                           address          city state    zip property_id  \
# 100           175     Berkeley ST        Boston    MA  02116
# 497               53   Circuit ST       Roxbury    MA  02119      341300
# 501             55-59  Circuit ST       Roxbury    MA  02119      341301
# 620        337-345   Belgrade AVE    Roslindale    MA  02131       13659
# 637            31     Hemenway ST        Boston    MA  02115       72664
# ...                           ...           ...   ...    ...         ...
# 469184          108     Perham ST  West Roxbury    MA  02132      109223
# 470114             319-321   A ST        BOSTON    MA  02210
# 470115             319-321   A ST        BOSTON    MA  02210
# 477379  416   American Legion HWY    Dorchester    MA  02124      355859
# 477471             93   Ormond ST      Mattapan    MA  02126      106019
#
#          parcel_id        lat       long
# 100                       NaN        NaN
# 497     1201414000        NaN        NaN
# 501     1201414000        NaN        NaN
# 620     2001401000  42.286233 -71.145838
# 637     0401763000  42.345755 -71.089652
# ...            ...        ...        ...
# 469184  2008388000  42.283040 -71.164880
# 470114  0602761000        NaN        NaN
# 470115  0602765010        NaN        NaN
# 477379  1405198010        NaN        NaN
# 477471  1404929010  42.282437 -71.093148
#
# [1131 rows x 22 columns]

# %%
data.loc[data['permittypedescr'] == 'Erect/New Construction']
# Out:
#        permitnumber worktype         permittypedescr       description  \
# 218892    ERT100078    ERECT  Erect/New Construction             Erect
# 218893   ERT1005194      COB  Erect/New Construction    City of Boston
# 218894    ERT100591    ERECT  Erect/New Construction             Erect
# 218895     ERT10090   NEWCON  Erect/New Construction  New construction
# 218896    ERT100941    ERECT  Erect/New Construction             Erect
# ...             ...      ...                     ...               ...
# 221253    ERT996638    ERECT  Erect/New Construction             Erect
# 221254    ERT998795    ERECT  Erect/New Construction             Erect
# 221255    ERT999689    ERECT  Erect/New Construction             Erect
# 221256    ERT999690    ERECT  Erect/New Construction             Erect
# 221257    ERT999690    ERECT  Erect/New Construction             Erect
#
#                                                  comments           applicant  \
# 218892  Lift the existing building to relocate within ...  George Haroutunian
# 218893  Engine # 42 -; Abatement and demolition of exi...      Brett E Watman
# 218894  On Parcel 1803649000 containing 7800 square fe...    Joseph  Vozzella
# 218895  Demolish and remove existing Building &;;slab;...       Richard Lynds
# 218896  take down existing 1 family structure and;erec...     ANTONIO RUSCITO
# ...                                                   ...                 ...
# 221253  Construct a new Two ( 2 ) Family Dwelling.; Ea...         Joe DiSipio
# 221254  New construction consisting of 230 apartments ...    christopher wade
# 221255  Combine 6 existing parcels into 1 lot and subd...     ANTONIO RUSCITO
# 221256  COMBINE 6 EXISTING PARCELS INTO 1 LOT AND SUBD...     ANTONIO RUSCITO
# 221257  COMBINE 6 EXISTING PARCELS INTO 1 LOT AND SUBD...     ANTONIO RUSCITO
#
#         declared_valuation  total_fees          issued_date  \
# 218892            100000.0      1586.0  2012-07-20 09:37:53
# 218893          17000000.0    340486.0  2019-10-24 10:45:55
# 218894            200000.0      2350.0  2013-02-25 13:45:35
# 218895            400000.0      8435.0  2010-09-23 13:59:52
# 218896            225000.0      2342.0  2011-12-22 12:29:13
# ...                    ...         ...                  ...
# 221253            435000.0      4466.0  2020-03-03 08:56:57
# 221254          49650704.0    506779.0  2020-06-05 12:11:35
# 221255            350000.0      3631.0  2019-10-28 12:39:56
# 221256            350000.0      3631.0  2019-11-07 15:04:59
# 221257            350000.0      3631.0  2019-11-07 15:04:59
#
#             expiration_date  ... occupancytype   sq_feet  \
# 218892  2013-01-20 00:00:00  ...         1Unit       0.0
# 218893  2020-04-24 00:00:00  ...          Comm       0.0
# 218894  2013-08-25 00:00:00  ...        1-2FAM    1672.0
# 218895  2011-03-23 00:00:00  ...         VacLd    3000.0
# 218896  2012-06-22 00:00:00  ...        1-2FAM    2400.0
# ...                     ...  ...           ...       ...
# 221253  2020-09-03 00:00:00  ...        1-2FAM    3031.0
# 221254  2020-12-05 00:00:00  ...         Multi  215862.0
# 221255  2020-04-28 00:00:00  ...        1-2FAM    2583.0
# 221256  2020-05-07 00:00:00  ...        1-2FAM    2484.0
# 221257  2020-05-07 00:00:00  ...        1-2FAM    2484.0
#
#                      address          city state    zip property_id  \
# 218892     39-45  Selkirk RD      Brighton    MA  02135      347861
# 218893  1870    Columbus AVE       Roxbury    MA  02119       35505
# 218894        15     Rock RD     Hyde Park    MA  02136
# 218895       391   Market ST      Brighton    MA  02135       90279
# 218896        31    Knoll ST    Roslindale    MA  02131       82348
# ...                      ...           ...   ...    ...         ...
# 221253       55-57  Meyer St    Roslindale    MA  02131      438948
# 221254      144   Addison St   East Boston    MA  02128        1127
# 221255     22   Northdale Rd  West Roxbury    MA  02132      438992
# 221256     30   Northdale Rd  West Roxbury    MA  02132      438991
# 221257     30   Northdale Rd  West Roxbury    MA  02132      438991
#
#          parcel_id        lat       long
# 218892  2102228000        NaN        NaN
# 218893  1100946001  42.318403 -71.097757
# 218894  1803649000        NaN        NaN
# 218895  2202416010  42.350250 -71.153170
# 218896  2005092000  42.291690 -71.133430
# ...            ...        ...        ...
# 221253  1904337009        NaN        NaN
# 221254  0100548100  42.386660 -71.018400
# 221255  2009932000        NaN        NaN
# 221256  2009929000        NaN        NaN
# 221257  2009930000        NaN        NaN
#
# [2347 rows x 22 columns]

# %% [markdown]
# Here we have filtered out all the permits we don't care for. We can rerun our analysis from Deliverable 1

# %%
df = data.loc[data['permittypedescr'] == 'Erect/New Construction']
applicants = pd.DataFrame(df['applicant'])
owners = pd.DataFrame(df['owner'])
applicants
# Out:
#                  applicant
# 218892  George Haroutunian
# 218893      Brett E Watman
# 218894    Joseph  Vozzella
# 218895       Richard Lynds
# 218896     ANTONIO RUSCITO
# ...                    ...
# 221253         Joe DiSipio
# 221254    christopher wade
# 221255     ANTONIO RUSCITO
# 221256     ANTONIO RUSCITO
# 221257     ANTONIO RUSCITO
#
# [2347 rows x 1 columns]

# %%
applicants.fillna("na")
applicants = applicants.applymap(str)

owners.fillna("na")
owners = owners.applymap(str)
applicants
# Out:
#                  applicant
# 218892  George Haroutunian
# 218893      Brett E Watman
# 218894    Joseph  Vozzella
# 218895       Richard Lynds
# 218896     ANTONIO RUSCITO
# ...                    ...
# 221253         Joe DiSipio
# 221254    christopher wade
# 221255     ANTONIO RUSCITO
# 221256     ANTONIO RUSCITO
# 221257     ANTONIO RUSCITO
#
# [2347 rows x 1 columns]

# %%
def prep_df_column(col, generate_map=False):
    """
    col: A pandas column-frame of strings
    generate_map: Whether or not to generate a map of the original values to the edited values 

    Outputs the columm with all the entries set to lowercase and with spaces removed
    """
    new_col = col.iloc[:, 0]
    new_col = [name.lower().replace(" ", "") for name in new_col]
    col_map = dict()
    if generate_map:
        for i in range(len(new_col)):
            col_map[new_col[i]] = col.iloc[:, 0][i]
        return new_col, col_map
    else:
        return new_col

# %%
# we split the encoders into two so they can keep track of their inverse transforms
applcants_encoder = LabelEncoder()
owners_encoder = LabelEncoder()

# here we also optionally output the mapping between the preprocessed values and the original, which we can use for display purposes
# however, building the map takes longer than we'd like
# applicants_cleaned, applicants_map = prep_df_column(applicants, generate_map=True)
# owners_cleaned, owners_map = prep_df_column(owners, generate_map=True)

applicants_cleaned = prep_df_column(applicants, generate_map=False)
owners_cleaned = prep_df_column(owners, generate_map=False)

applicants_labels = pd.DataFrame(applcants_encoder.fit_transform(applicants_cleaned))
owners_labels = pd.DataFrame(owners_encoder.fit_transform(owners_cleaned))

# %%
applicants_labels_vals = applicants_labels.value_counts()
index = [tup[0] for tup in applicants_labels_vals.index]
applicants_labels_vals.index = applcants_encoder.inverse_transform(index)
pd.DataFrame(applicants_labels_vals)
# Out:
#                    0
# timothyjohnson    61
# nan               51
# arthurchoo        34
# antonioferrara    33
# antonioruscito    33
# ...               ..
# lisaevans          1
# lindseyhiroko      1
# leroycumberbatch   1
# leonormesquita     1
# jonjgansenberg     1
#
# [970 rows x 1 columns]

# %%
owners_labels_vals = owners_labels.value_counts()
owners_index = [tup[0] for tup in owners_labels_vals.index]
owners_labels_vals.index = owners_encoder.inverse_transform(owners_index)
pd.DataFrame(owners_labels_vals)
# Out:
#                             0
# nan                        65
# bostonhousingauthority     38
# cityofboston               36
# harvardre/allstoninc       31
# ogwestcampuslandllc        27
# ...                        ..
# lakhanshaheene              1
# lakkiseddiee                1
# lancastercondominiumtrust   1
# lariviereandrew             1
# 0walnutlanellc              1
#
# [1627 rows x 1 columns]

# %% [markdown]
# ## Cencus Tract to Demographic Filtering

# %%
# Function to convert the Lat and Long into a census tract.
# Refer to https://www.census.gov/programs-surveys/geography/guidance/geo-identifiers.html for the FIPS code to census tract conversion
# FCC Census block conversion API link: https://geo.fcc.gov/api/census/#!/block/get_block_find

def Coord_to_census_tract(Lat,Long):
    Converter = requests.get("https://geo.fcc.gov/api/census/block/find?latitude=%20" + str(Lat) + "&longitude=" + str(Long) + "&showall=true&format=json")
    #print(Converter.text)
    Census_data = Converter.text
    json_data = json.loads(Census_data)
    # print(json_data)
    FIPS_code = json_data['Block']['FIPS']
    Census_tract = FIPS_code[5:11]
    #print(type(Census_tract))
    if Census_tract[0] == "0":
        Census_tract.replace(Census_tract[0],'')
        Census_split = Census_tract[ : 4] + '.'+ Census_tract[4 : ]
        return(Census_split)
    else:
        Census_split = Census_tract[ : 4] + '.'+ Census_tract[4 : ]
        return(Census_split)

# %%
df2 = df.copy()
df2 = df2[df2['lat'].notna()]
df2 = df2[df2['long'].notna()]
df2
# Out:
#        permitnumber worktype         permittypedescr       description  \
# 218893   ERT1005194      COB  Erect/New Construction    City of Boston
# 218895     ERT10090   NEWCON  Erect/New Construction  New construction
# 218896    ERT100941    ERECT  Erect/New Construction             Erect
# 218898   ERT1014515    ERECT  Erect/New Construction             Erect
# 218901   ERT1017644    ERECT  Erect/New Construction             Erect
# ...             ...      ...                     ...               ...
# 221240     ERT98131    ERECT  Erect/New Construction             Erect
# 221243     ERT98520   NEWCON  Erect/New Construction  New construction
# 221245    ERT987106    ERECT  Erect/New Construction             Erect
# 221250     ERT99288   NEWCON  Erect/New Construction  New construction
# 221254    ERT998795    ERECT  Erect/New Construction             Erect
#
#                                                  comments  \
# 218893  Engine # 42 -; Abatement and demolition of exi...
# 218895  Demolish and remove existing Building &;;slab;...
# 218896  take down existing 1 family structure and;erec...
# 218898  Demolish existing House.; Erect a new 21/2 sto...
# 218901  Build new metal building on existing site This...
# ...                                                   ...
# 221240  Under previously issued BZC #18640 as part of ...
# 221243  Demolition of existing single family dwelling ...
# 221245             3 townhouses  8 total units FP and FA;
# 221250  Erect;two family house after demolition(per;De...
# 221254  New construction consisting of 230 apartments ...
#
#                   applicant  declared_valuation  total_fees  \
# 218893       Brett E Watman          17000000.0    340486.0
# 218895        Richard Lynds            400000.0      8435.0
# 218896      ANTONIO RUSCITO            225000.0      2342.0
# 218898        Michael Moran            380000.0      7350.0
# 218901      Michael Sheehan            500000.0      5258.0
# ...                     ...                 ...         ...
# 221240        David Raftery            155000.0      1642.0
# 221243  Anthony  Di Letizia            170000.0      1795.0
# 221245          Lee Goodman           1600000.0     18525.0
# 221250                Sy Vo            200000.0      2071.0
# 221254     christopher wade          49650704.0    506779.0
#
#                 issued_date      expiration_date  ... occupancytype   sq_feet  \
# 218893  2019-10-24 10:45:55  2020-04-24 00:00:00  ...          Comm       0.0
# 218895  2010-09-23 13:59:52  2011-03-23 00:00:00  ...         VacLd    3000.0
# 218896  2011-12-22 12:29:13  2012-06-22 00:00:00  ...        1-2FAM    2400.0
# 218898  2020-06-01 09:07:49  2020-12-01 00:00:00  ...        1-2FAM    2696.0
# 218901  2019-12-12 11:05:49  2020-06-12 00:00:00  ...          Comm    9900.0
# ...                     ...                  ...  ...           ...       ...
# 221240  2012-03-26 09:29:13  2012-09-26 00:00:00  ...        1-2FAM    2000.0
# 221243  2011-11-30 13:18:13  2012-05-30 00:00:00  ...        1-2FAM    2700.0
# 221245  2020-06-04 09:20:49  2020-12-04 00:00:00  ...        1-3FAM   11500.0
# 221250  2013-09-26 11:48:28  2014-03-26 00:00:00  ...        1-2FAM       0.0
# 221254  2020-06-05 12:11:35  2020-12-05 00:00:00  ...         Multi  215862.0
#
#                      address           city state    zip property_id  \
# 218893  1870    Columbus AVE        Roxbury    MA  02119       35505
# 218895       391   Market ST       Brighton    MA  02135       90279
# 218896        31    Knoll ST     Roslindale    MA  02131       82348
# 218898      19   Blueview Ci   West Roxbury    MA  02132       16640
# 218901       69    Tenean ST     Dorchester    MA  02122      134378
# ...                      ...            ...   ...    ...         ...
# 221240    4     Pine Tree LN      Hyde Park    MA  02136      110833
# 221243     6     Bellaire RD   West Roxbury    MA  02132       13769
# 221245      73   Sheridan St  Jamaica Plain    MA  02130      126855
# 221250  13A-13B   Parkman ST     Dorchester    MA  02122      344593
# 221254      144   Addison St    East Boston    MA  02128        1127
#
#          parcel_id        lat       long
# 218893  1100946001  42.318403 -71.097757
# 218895  2202416010  42.350250 -71.153170
# 218896  2005092000  42.291690 -71.133430
# 218898  2012057005  42.263350 -71.148570
# 218901  1602560001  42.292460 -71.045830
# ...            ...        ...        ...
# 221240  1812256180  42.249738 -71.140809
# 221243  2004366000  42.291330 -71.143300
# 221245  1900219000  42.320250 -71.107080
# 221250  1600883000  42.296271 -71.059982
# 221254  0100548100  42.386660 -71.018400
#
# [970 rows x 22 columns]

# %%
df2['Cencus_Tract'] = df2.apply(lambda row: float(Coord_to_census_tract(row.lat, row.long)), axis=1)
df2
# Out:
#        permitnumber worktype         permittypedescr       description  \
# 218893   ERT1005194      COB  Erect/New Construction    City of Boston
# 218895     ERT10090   NEWCON  Erect/New Construction  New construction
# 218896    ERT100941    ERECT  Erect/New Construction             Erect
# 218898   ERT1014515    ERECT  Erect/New Construction             Erect
# 218901   ERT1017644    ERECT  Erect/New Construction             Erect
# ...             ...      ...                     ...               ...
# 221240     ERT98131    ERECT  Erect/New Construction             Erect
# 221243     ERT98520   NEWCON  Erect/New Construction  New construction
# 221245    ERT987106    ERECT  Erect/New Construction             Erect
# 221250     ERT99288   NEWCON  Erect/New Construction  New construction
# 221254    ERT998795    ERECT  Erect/New Construction             Erect
#
#                                                  comments  \
# 218893  Engine # 42 -; Abatement and demolition of exi...
# 218895  Demolish and remove existing Building &;;slab;...
# 218896  take down existing 1 family structure and;erec...
# 218898  Demolish existing House.; Erect a new 21/2 sto...
# 218901  Build new metal building on existing site This...
# ...                                                   ...
# 221240  Under previously issued BZC #18640 as part of ...
# 221243  Demolition of existing single family dwelling ...
# 221245             3 townhouses  8 total units FP and FA;
# 221250  Erect;two family house after demolition(per;De...
# 221254  New construction consisting of 230 apartments ...
#
#                   applicant  declared_valuation  total_fees  \
# 218893       Brett E Watman          17000000.0    340486.0
# 218895        Richard Lynds            400000.0      8435.0
# 218896      ANTONIO RUSCITO            225000.0      2342.0
# 218898        Michael Moran            380000.0      7350.0
# 218901      Michael Sheehan            500000.0      5258.0
# ...                     ...                 ...         ...
# 221240        David Raftery            155000.0      1642.0
# 221243  Anthony  Di Letizia            170000.0      1795.0
# 221245          Lee Goodman           1600000.0     18525.0
# 221250                Sy Vo            200000.0      2071.0
# 221254     christopher wade          49650704.0    506779.0
#
#                 issued_date      expiration_date  ...   sq_feet  \
# 218893  2019-10-24 10:45:55  2020-04-24 00:00:00  ...       0.0
# 218895  2010-09-23 13:59:52  2011-03-23 00:00:00  ...    3000.0
# 218896  2011-12-22 12:29:13  2012-06-22 00:00:00  ...    2400.0
# 218898  2020-06-01 09:07:49  2020-12-01 00:00:00  ...    2696.0
# 218901  2019-12-12 11:05:49  2020-06-12 00:00:00  ...    9900.0
# ...                     ...                  ...  ...       ...
# 221240  2012-03-26 09:29:13  2012-09-26 00:00:00  ...    2000.0
# 221243  2011-11-30 13:18:13  2012-05-30 00:00:00  ...    2700.0
# 221245  2020-06-04 09:20:49  2020-12-04 00:00:00  ...   11500.0
# 221250  2013-09-26 11:48:28  2014-03-26 00:00:00  ...       0.0
# 221254  2020-06-05 12:11:35  2020-12-05 00:00:00  ...  215862.0
#
#                      address           city  state    zip property_id  \
# 218893  1870    Columbus AVE        Roxbury     MA  02119       35505
# 218895       391   Market ST       Brighton     MA  02135       90279
# 218896        31    Knoll ST     Roslindale     MA  02131       82348
# 218898      19   Blueview Ci   West Roxbury     MA  02132       16640
# 218901       69    Tenean ST     Dorchester     MA  02122      134378
# ...                      ...            ...    ...    ...         ...
# 221240    4     Pine Tree LN      Hyde Park     MA  02136      110833
# 221243     6     Bellaire RD   West Roxbury     MA  02132       13769
# 221245      73   Sheridan St  Jamaica Plain     MA  02130      126855
# 221250  13A-13B   Parkman ST     Dorchester     MA  02122      344593
# 221254      144   Addison St    East Boston     MA  02128        1127
#
#          parcel_id        lat       long Cencus_Tract
# 218893  1100946001  42.318403 -71.097757       813.00
# 218895  2202416010  42.350250 -71.153170         2.02
# 218896  2005092000  42.291690 -71.133430      1106.07
# 218898  2012057005  42.263350 -71.148570      1304.06
# 218901  1602560001  42.292460 -71.045830      1006.03
# ...            ...        ...        ...          ...
# 221240  1812256180  42.249738 -71.140809      1401.02
# 221243  2004366000  42.291330 -71.143300      1106.01
# 221245  1900219000  42.320250 -71.107080      1206.00
# 221250  1600883000  42.296271 -71.059982       921.01
# 221254  0100548100  42.386660 -71.018400       510.00
#
# [970 rows x 23 columns]

# %%
sub_neigh = pd.read_csv("data/Sub-Neighborhoods.csv")
sub_neigh
# Out:
#      Census Tract#       Zipcode   Neighborhood US Geonames Sub-neigborhood  \
# 0             1.00  02134, 02135       Brighton                         NaN
# 1             2.01         02135       Brighton                         NaN
# 2             2.02         02135       Brighton                         NaN
# 3             3.01         02135       Brighton                         NaN
# 4             3.02         02135       Brighton                         NaN
# ..             ...           ...            ...                         ...
# 176        9815.02         02151    East Boston                         NaN
# 177        9816.00         02128    East Boston                         NaN
# 178        9817.00         02116    Beacon Hill                         NaN
# 179        9818.00  02130, 02215  Jamaica Plain                         NaN
# 180        9901.01         02130            NaN                         NaN
#
#     Total Population  Black Black Proportion  White White Proportion  \
# 0              5,324    311            5.84%  3,315           62.27%
# 1              3,991    237            5.94%  3,164           79.28%
# 2              4,272    263            6.16%  3,031           70.95%
# 3              2,946    216            7.33%  2,203           74.78%
# 4              3,469    359           10.35%  2,346           67.63%
# ..               ...    ...              ...    ...              ...
# 176                0      0            0.00%      0            0.00%
# 177                0      0            0.00%      0            0.00%
# 178                0      0            0.00%      0            0.00%
# 179               26      9           34.62%     17           65.38%
# 180               67     18           26.87%     49           73.13%
#
#      American Indian & Alaska Native  ...  Male  Male Proportion Female   \
# 0                                  0  ...  2,578          48.42%   2,746
# 1                                 17  ...  1,800          45.10%   2,191
# 2                                  0  ...  2,175          50.91%   2,097
# 3                                  0  ...  1,650          56.01%   1,296
# 4                                 25  ...  1,733          49.96%   1,736
# ..                               ...  ...    ...             ...     ...
# 176                                0  ...      0           0.00%       0
# 177                                0  ...      0           0.00%       0
# 178                                0  ...      0           0.00%       0
# 179                                0  ...      4          15.38%      22
# 180                                0  ...     55          82.09%      12
#
#     Female Proportion         Lat       Long Primary Sub-Neighborhood  \
# 0               51.58%  42.361484 -71.138588            Lower Allston
# 1               54.90%  42.354066 -71.161168               Oak Square
# 2               49.09%  42.352605 -71.154344               Oak Square
# 3               43.99%  42.354144 -71.168827            Hunnwell Hill
# 4               50.04%  42.347258 -71.167686                 Brighton
# ..                 ...        ...        ...                      ...
# 176              0.00%  42.396367 -71.004379                Beachmont
# 177              0.00%  42.388621 -70.993442           Orient Heights
# 178              0.00%  42.355087 -71.065743        Downtown Crossing
# 179             84.62%  42.323121 -71.116882         High Street Hill
# 180             17.91%  42.329611 -70.949200                      NaN
#
#      Secondary Sub-Neighborhood  Teritriary Sub-Neighborhood(s)  \
# 0                       Allston                Packard's Corner
# 1                      Brighton                  Hunnewell Hill
# 2                      Brighton                         Allston
# 3                    Oak Square                             NaN
# 4               St. Elizabeth's                             NaN
# ..                          ...                             ...
# 176              Orient Heights                             NaN
# 177                   Beachmont                             NaN
# 178                         NaN                             NaN
# 179                         NaN                             NaN
# 180                         NaN                             NaN
#
#                 T-Stop/Commuter Rail
# 0                     Boston Landing
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 176                        Beachmont
# 177                    Suffolk Downs
# 178                  Boylston Street
# 179  Heath Street / Back of the Hill
# 180                              NaN
#
# [181 rows x 23 columns]

# %%
sub_neigh['Census Tract#']
# Out:
# 0         1.00
# 1         2.01
# 2         2.02
# 3         3.01
# 4         3.02
#         ...
# 176    9815.02
# 177    9816.00
# 178    9817.00
# 179    9818.00
# 180    9901.01
# Name: Census Tract#, Length: 181, dtype: float64

# %%
sub_neigh['Census Tract#'] = sub_neigh.apply(lambda row: float(row['Census Tract#']), axis=1)
sub_neigh
# Out:
#      Census Tract#       Zipcode   Neighborhood US Geonames Sub-neigborhood  \
# 0             1.00  02134, 02135       Brighton                         NaN
# 1             2.01         02135       Brighton                         NaN
# 2             2.02         02135       Brighton                         NaN
# 3             3.01         02135       Brighton                         NaN
# 4             3.02         02135       Brighton                         NaN
# ..             ...           ...            ...                         ...
# 176        9815.02         02151    East Boston                         NaN
# 177        9816.00         02128    East Boston                         NaN
# 178        9817.00         02116    Beacon Hill                         NaN
# 179        9818.00  02130, 02215  Jamaica Plain                         NaN
# 180        9901.01         02130            NaN                         NaN
#
#     Total Population  Black Black Proportion  White White Proportion  \
# 0              5,324    311            5.84%  3,315           62.27%
# 1              3,991    237            5.94%  3,164           79.28%
# 2              4,272    263            6.16%  3,031           70.95%
# 3              2,946    216            7.33%  2,203           74.78%
# 4              3,469    359           10.35%  2,346           67.63%
# ..               ...    ...              ...    ...              ...
# 176                0      0            0.00%      0            0.00%
# 177                0      0            0.00%      0            0.00%
# 178                0      0            0.00%      0            0.00%
# 179               26      9           34.62%     17           65.38%
# 180               67     18           26.87%     49           73.13%
#
#      American Indian & Alaska Native  ...  Male  Male Proportion Female   \
# 0                                  0  ...  2,578          48.42%   2,746
# 1                                 17  ...  1,800          45.10%   2,191
# 2                                  0  ...  2,175          50.91%   2,097
# 3                                  0  ...  1,650          56.01%   1,296
# 4                                 25  ...  1,733          49.96%   1,736
# ..                               ...  ...    ...             ...     ...
# 176                                0  ...      0           0.00%       0
# 177                                0  ...      0           0.00%       0
# 178                                0  ...      0           0.00%       0
# 179                                0  ...      4          15.38%      22
# 180                                0  ...     55          82.09%      12
#
#     Female Proportion         Lat       Long Primary Sub-Neighborhood  \
# 0               51.58%  42.361484 -71.138588            Lower Allston
# 1               54.90%  42.354066 -71.161168               Oak Square
# 2               49.09%  42.352605 -71.154344               Oak Square
# 3               43.99%  42.354144 -71.168827            Hunnwell Hill
# 4               50.04%  42.347258 -71.167686                 Brighton
# ..                 ...        ...        ...                      ...
# 176              0.00%  42.396367 -71.004379                Beachmont
# 177              0.00%  42.388621 -70.993442           Orient Heights
# 178              0.00%  42.355087 -71.065743        Downtown Crossing
# 179             84.62%  42.323121 -71.116882         High Street Hill
# 180             17.91%  42.329611 -70.949200                      NaN
#
#      Secondary Sub-Neighborhood  Teritriary Sub-Neighborhood(s)  \
# 0                       Allston                Packard's Corner
# 1                      Brighton                  Hunnewell Hill
# 2                      Brighton                         Allston
# 3                    Oak Square                             NaN
# 4               St. Elizabeth's                             NaN
# ..                          ...                             ...
# 176              Orient Heights                             NaN
# 177                   Beachmont                             NaN
# 178                         NaN                             NaN
# 179                         NaN                             NaN
# 180                         NaN                             NaN
#
#                 T-Stop/Commuter Rail
# 0                     Boston Landing
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 176                        Beachmont
# 177                    Suffolk Downs
# 178                  Boylston Street
# 179  Heath Street / Back of the Hill
# 180                              NaN
#
# [181 rows x 23 columns]

# %%
sub_neigh['White Proportion'] = sub_neigh.apply(lambda row: float(row['White Proportion'][:-1]), axis=1)
sub_neigh
# Out:
#      Census Tract#       Zipcode   Neighborhood US Geonames Sub-neigborhood  \
# 0             1.00  02134, 02135       Brighton                         NaN
# 1             2.01         02135       Brighton                         NaN
# 2             2.02         02135       Brighton                         NaN
# 3             3.01         02135       Brighton                         NaN
# 4             3.02         02135       Brighton                         NaN
# ..             ...           ...            ...                         ...
# 176        9815.02         02151    East Boston                         NaN
# 177        9816.00         02128    East Boston                         NaN
# 178        9817.00         02116    Beacon Hill                         NaN
# 179        9818.00  02130, 02215  Jamaica Plain                         NaN
# 180        9901.01         02130            NaN                         NaN
#
#     Total Population  Black Black Proportion  White  White Proportion  \
# 0              5,324    311            5.84%  3,315             62.27
# 1              3,991    237            5.94%  3,164             79.28
# 2              4,272    263            6.16%  3,031             70.95
# 3              2,946    216            7.33%  2,203             74.78
# 4              3,469    359           10.35%  2,346             67.63
# ..               ...    ...              ...    ...               ...
# 176                0      0            0.00%      0              0.00
# 177                0      0            0.00%      0              0.00
# 178                0      0            0.00%      0              0.00
# 179               26      9           34.62%     17             65.38
# 180               67     18           26.87%     49             73.13
#
#      American Indian & Alaska Native  ...  Male  Male Proportion Female   \
# 0                                  0  ...  2,578          48.42%   2,746
# 1                                 17  ...  1,800          45.10%   2,191
# 2                                  0  ...  2,175          50.91%   2,097
# 3                                  0  ...  1,650          56.01%   1,296
# 4                                 25  ...  1,733          49.96%   1,736
# ..                               ...  ...    ...             ...     ...
# 176                                0  ...      0           0.00%       0
# 177                                0  ...      0           0.00%       0
# 178                                0  ...      0           0.00%       0
# 179                                0  ...      4          15.38%      22
# 180                                0  ...     55          82.09%      12
#
#     Female Proportion         Lat       Long Primary Sub-Neighborhood  \
# 0               51.58%  42.361484 -71.138588            Lower Allston
# 1               54.90%  42.354066 -71.161168               Oak Square
# 2               49.09%  42.352605 -71.154344               Oak Square
# 3               43.99%  42.354144 -71.168827            Hunnwell Hill
# 4               50.04%  42.347258 -71.167686                 Brighton
# ..                 ...        ...        ...                      ...
# 176              0.00%  42.396367 -71.004379                Beachmont
# 177              0.00%  42.388621 -70.993442           Orient Heights
# 178              0.00%  42.355087 -71.065743        Downtown Crossing
# 179             84.62%  42.323121 -71.116882         High Street Hill
# 180             17.91%  42.329611 -70.949200                      NaN
#
#      Secondary Sub-Neighborhood  Teritriary Sub-Neighborhood(s)  \
# 0                       Allston                Packard's Corner
# 1                      Brighton                  Hunnewell Hill
# 2                      Brighton                         Allston
# 3                    Oak Square                             NaN
# 4               St. Elizabeth's                             NaN
# ..                          ...                             ...
# 176              Orient Heights                             NaN
# 177                   Beachmont                             NaN
# 178                         NaN                             NaN
# 179                         NaN                             NaN
# 180                         NaN                             NaN
#
#                 T-Stop/Commuter Rail
# 0                     Boston Landing
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 176                        Beachmont
# 177                    Suffolk Downs
# 178                  Boylston Street
# 179  Heath Street / Back of the Hill
# 180                              NaN
#
# [181 rows x 23 columns]

# %%
sub_neigh.loc[sub_neigh['White Proportion'] > 75.0]
# Out:
#      Census Tract#       Zipcode             Neighborhood  \
# 1             2.01         02135                 Brighton
# 5             4.01         02135                 Brighton
# 6             4.02         02135                 Brighton
# 7             5.02  02135, 02467                 Brighton
# 8             5.03         02135                 Brighton
# ..             ...           ...                      ...
# 154        1302.00         02132             West Roxbury
# 155        1303.00         02132             West Roxbury
# 156        1304.02         02132             West Roxbury
# 173        9812.02  02127, 02210  South Boston Waterfront
# 174        9813.00         02128              East Boston
#
#     US Geonames Sub-neigborhood Total Population  Black Black Proportion  \
# 1                           NaN            3,991    237            5.94%
# 5                      Aberdeen            5,691    137            2.41%
# 6                      Brighton            3,494    150            4.29%
# 7                           NaN            5,796    155            2.67%
# 8                           NaN            2,007     77            3.84%
# ..                          ...              ...    ...              ...
# 154                    Highland            5,299    255            4.81%
# 155                West Roxbury            4,519    170            3.76%
# 156                         NaN            4,934    204            4.13%
# 173  Fort Winthrop (historical)              215     27           12.56%
# 174                         NaN              400     20            5.00%
#
#      White  White Proportion  American Indian & Alaska Native  ...  Male   \
# 1    3,164             79.28                               17  ...  1,800
# 5    4,404             77.39                               34  ...  2,669
# 6    2,868             82.08                                0  ...  1,806
# 7    4,917             84.83                               12  ...  2,574
# 8    1,633             81.37                              109  ...  1,002
# ..     ...               ...                              ...  ...    ...
# 154  4,812             90.81                               56  ...  2,526
# 155  3,948             87.36                                0  ...  2,094
# 156  4,084             82.77                               95  ...  2,128
# 173    179             83.26                                0  ...    206
# 174    362             90.50                                0  ...    284
#
#     Male Proportion Female  Female Proportion         Lat       Long  \
# 1            45.10%   2,191             54.90%  42.354066 -71.161168
# 5            46.90%   3,022             53.10%  42.343849 -71.149293
# 6            51.69%   1,688             48.31%  42.344174 -71.158829
# 7            44.41%   3,222             55.59%  42.331505 -71.157497
# 8            49.93%   1,005             50.07%  42.339636 -71.150099
# ..              ...     ...                ...        ...        ...
# 154          47.67%   2,773             52.33%  42.287332 -71.157012
# 155          46.34%   2,425             53.66%  42.279129 -71.150710
# 156          43.13%   2,806             56.87%  42.272401 -71.169406
# 173          95.81%       9              4.19%  42.343916 -71.024362
# 174          71.00%     116             29.00%  42.361129 -71.006975
#
#                    Primary Sub-Neighborhood  Secondary Sub-Neighborhood  \
# 1                                Oak Square                    Brighton
# 5                           St. Elizabeth's                  Oak Square
# 6                           St. Elizabeth's                    Brighton
# 7    Chestnut Hill Neighborhood Association                 Fisher Hill
# 8                                  Aberdeen   Salisbury Road-Corey Farm
# ..                                      ...                         ...
# 154                              Brook Farm                         NaN
# 155                           Bellevue Hill                     Roxbury
# 156          Upper Washington/Spring Street                         NaN
# 173                              City Point              Telegraph Hill
# 174                          Jeffries Point                         NaN
#
#      Teritriary Sub-Neighborhood(s)  \
# 1                    Hunnewell Hill
# 5                        Corey Hill
# 6               Aberdeen/Oak Square
# 7                               NaN
# 8                        Corey Hill
# ..                              ...
# 154                             NaN
# 155                             NaN
# 156                             NaN
# 173          D Street/West Broadway
# 174                             NaN
#
#                                   T-Stop/Commuter Rail
# 1                                                  NaN
# 5    Sutherland Road/Chiswick Road/Chestnut Hill Av...
# 6                                         South Street
# 7        Chestnut Hill Ave/ Reservoir/Cleveland Circle
# 8    Sutherland Road/Chiswick Road/Chestnut Hill Av...
# ..                                                 ...
# 154                                           Highland
# 155                                  Woodard Rd @ Wren
# 156                               Spring Street @ Goud
# 173                                                NaN
# 174                                                NaN
#
# [62 rows x 23 columns]

# %%
merged = pd.merge(df2, sub_neigh, left_on="Cencus_Tract", right_on="Census Tract#")
merged
# Out:
#     permitnumber worktype         permittypedescr  \
# 0     ERT1005194      COB  Erect/New Construction
# 1      ERT220708   NEWCON  Erect/New Construction
# 2      ERT463276    ERECT  Erect/New Construction
# 3      ERT463278    ERECT  Erect/New Construction
# 4      ERT686227    ERECT  Erect/New Construction
# ..           ...      ...                     ...
# 965    ERT833960    ERECT  Erect/New Construction
# 966    ERT917537           Erect/New Construction
# 967      ERT9605   CONVRT  Erect/New Construction
# 968      ERT9605   CONVRT  Erect/New Construction
# 969    ERT987106    ERECT  Erect/New Construction
#
#                         description  \
# 0                    City of Boston
# 1                  New construction
# 2                             Erect
# 3                             Erect
# 4                             Erect
# ..                              ...
# 965                           Erect
# 966                             NaN
# 967  From TimeMatters-PZ Conversion
# 968  From TimeMatters-PZ Conversion
# 969                           Erect
#
#                                               comments  \
# 0    Engine # 42 -; Abatement and demolition of exi...
# 1    Erect new building in place of building that b...
# 2    Demolition of existing building and Erect a ne...
# 3    New construction of 17 residential units. affo...
# 4    -Combine 3 parcels into one site with the Addr...
# ..                                                 ...
# 965  Erect new two-family dwelling. Propose (4) off...
# 966  Erect new two family dwelling per attached dra...
# 967  Proposed Work: Construct ten unit condo buildi...
# 968  Proposed Work: Construct ten unit condo buildi...
# 969             3 townhouses  8 total units FP and FA;
#
#                                  applicant  declared_valuation  total_fees  \
# 0                           Brett E Watman          17000000.0    340486.0
# 1                             Joe Consalvo           1222100.0     13457.0
# 2                                      NaN           7100000.0    143439.0
# 3                                      NaN           3791000.0     76018.0
# 4                         david macpherson          30000000.0    302100.0
# ..                                     ...                 ...         ...
# 965                             Juan Rojas            300000.0      5682.0
# 966                             Sean Smith            230000.0      2374.0
# 967                                                        0.0         0.0
# 968   Church Square Community Partners LLC                 0.0         0.0
# 969                            Lee Goodman           1600000.0     18525.0
#
#              issued_date      expiration_date  ...  Male  Male Proportion  \
# 0    2019-10-24 10:45:55  2020-04-24 00:00:00  ...  2,668          50.09%
# 1    2013-04-17 09:15:02  2013-10-17 00:00:00  ...  2,668          50.09%
# 2    2017-06-21 11:16:26  2017-12-21 00:00:00  ...  2,668          50.09%
# 3    2017-06-21 11:16:28  2017-12-21 00:00:00  ...  2,668          50.09%
# 4    2018-10-17 08:53:50  2019-04-17 00:00:00  ...  2,668          50.09%
# ..                   ...                  ...  ...    ...             ...
# 965  2019-06-24 11:22:54  2019-12-24 00:00:00  ...  1,085          42.92%
# 966  2020-03-10 12:45:29  2020-09-10 00:00:00  ...  1,085          42.92%
# 967  2013-07-22 23:06:18  2014-01-22 00:00:00  ...  1,621          44.24%
# 968  2013-07-22 23:06:18  2014-01-22 00:00:00  ...  1,621          44.24%
# 969  2020-06-04 09:20:49  2020-12-04 00:00:00  ...  1,323          54.07%
#
#     Female   Female Proportion         Lat       Long  \
# 0     2,658              49.91%  42.319327 -71.097690
# 1     2,658              49.91%  42.319327 -71.097690
# 2     2,658              49.91%  42.319327 -71.097690
# 3     2,658              49.91%  42.319327 -71.097690
# 4     2,658              49.91%  42.319327 -71.097690
# ..      ...                 ...        ...        ...
# 965   1,443              57.08%  42.280496 -71.117051
# 966   1,443              57.08%  42.280496 -71.117051
# 967   2,043              55.76%  42.324432 -71.103863
# 968   2,043              55.76%  42.324432 -71.103863
# 969   1,124              45.93%  42.319110 -71.108841
#
#     Primary Sub-Neighborhood Secondary Sub-Neighborhood  \
# 0           Washington Park                     Roxbury
# 1           Washington Park                     Roxbury
# 2           Washington Park                     Roxbury
# 3           Washington Park                     Roxbury
# 4           Washington Park                     Roxbury
# ..                       ...                        ...
# 965   Washington /Mount Hope                 Roslindale
# 966   Washington /Mount Hope                 Roslindale
# 967                Fort Hill                    Roxbury
# 968                Fort Hill                    Roxbury
# 969          Egleston Square                        NaN
#
#     Teritriary Sub-Neighborhood(s)                       T-Stop/Commuter Rail
# 0                  Egleston Square  Colubmus Ave @ Dimock St / Jackson Square
# 1                  Egleston Square  Colubmus Ave @ Dimock St / Jackson Square
# 2                  Egleston Square  Colubmus Ave @ Dimock St / Jackson Square
# 3                  Egleston Square  Colubmus Ave @ Dimock St / Jackson Square
# 4                  Egleston Square  Colubmus Ave @ Dimock St / Jackson Square
# ..                             ...                                        ...
# 965                            NaN           American Legion Highway @ Stella
# 966                            NaN           American Legion Highway @ Stella
# 967                            NaN                            Jackson Square
# 968                            NaN                            Jackson Square
# 969                            NaN                                Stony Brook
#
# [970 rows x 46 columns]

# %%
merged.loc[merged['White Proportion'] > 75.0]
# Out:
#     permitnumber worktype         permittypedescr       description  \
# 11     ERT100941    ERECT  Erect/New Construction             Erect
# 12     ERT131468    ERECT  Erect/New Construction             Erect
# 13     ERT283555   NEWCON  Erect/New Construction  New construction
# 14     ERT452036   NEWCON  Erect/New Construction  New construction
# 15     ERT485570    ERECT  Erect/New Construction             Erect
# ..           ...      ...                     ...               ...
# 957     ERT94894   NEWCON  Erect/New Construction  New construction
# 960    ERT782631    ERECT  Erect/New Construction             Erect
# 961    ERT840663    ERECT  Erect/New Construction             Erect
# 962    ERT924772    ERECT  Erect/New Construction             Erect
# 969    ERT987106    ERECT  Erect/New Construction             Erect
#
#                                               comments         applicant  \
# 11   take down existing 1 family structure and;erec...   ANTONIO RUSCITO
# 12   To erect new one family dwelling on lot: Bill ...               NaN
# 13   Construct a new two family dwelling on lot con...        Colm Oshea
# 14   Erect multifamily residential building with 13...   Jonathan Parkes
# 15   On existing;12 737 sq.ft. parcel  ;demolish ex...     john sullivan
# ..                                                 ...               ...
# 957  Demolition of the existing parking structure a...   James Grossmann
# 960  Erect a new 5 story multi-family (16 units) re...      Jeremy Henry
# 961  Erect a 4 story  Eighteen ( 18 ) Unit Resident...   Carlos Ferreira
# 962  Demolish existing structure and Erect new 4 st...  FERNANDO DALFIOR
# 969             3 townhouses  8 total units FP and FA;       Lee Goodman
#
#      declared_valuation  total_fees          issued_date      expiration_date  \
# 11             225000.0      2342.0  2011-12-22 12:29:13  2012-06-22 00:00:00
# 12             443000.0      4578.0  2012-06-08 15:36:44
# 13             340000.0      3492.0  2014-03-10 11:27:30  2014-09-10 00:00:00
# 14            2100000.0     23326.0  2017-01-24 12:34:45  2017-07-24 00:00:00
# 15            2500000.0     38249.0  2016-10-14 13:19:58  2017-04-14 00:00:00
# ..                  ...         ...                  ...                  ...
# 957          12000000.0    120050.0  2011-12-14 14:51:58  2012-06-14 00:00:00
# 960           4700000.0     48710.0  2020-08-06 10:03:37  2021-02-06 00:00:00
# 961           4453780.0    101293.0  2020-07-31 09:42:17  2021-01-31 00:00:00
# 962           1195950.0     24362.0  2020-06-09 11:35:47  2020-12-09 00:00:00
# 969           1600000.0     18525.0  2020-06-04 09:20:49  2020-12-04 00:00:00
#
#      ...  Male  Male Proportion Female   Female Proportion         Lat  \
# 11   ...  2,505          46.22%   2,915              53.78%  42.290287
# 12   ...  2,505          46.22%   2,915              53.78%  42.290287
# 13   ...  2,505          46.22%   2,915              53.78%  42.290287
# 14   ...  2,505          46.22%   2,915              53.78%  42.290287
# 15   ...  2,505          46.22%   2,915              53.78%  42.290287
# ..   ...    ...             ...     ...                 ...        ...
# 957  ...  1,210          46.36%   1,400              53.64%  42.351835
# 960  ...  2,851          51.24%   2,713              48.76%  42.381666
# 961  ...  2,851          51.24%   2,713              48.76%  42.381666
# 962  ...  2,851          51.24%   2,713              48.76%  42.381666
# 969  ...  1,323          54.07%   1,124              45.93%  42.319110
#
#           Long Primary Sub-Neighborhood Secondary Sub-Neighborhood  \
# 11  -71.134640               Roslindale                        NaN
# 12  -71.134640               Roslindale                        NaN
# 13  -71.134640               Roslindale                        NaN
# 14  -71.134640               Roslindale                        NaN
# 15  -71.134640               Roslindale                        NaN
# ..         ...                      ...                        ...
# 957 -71.075516                 Back Bay                        NaN
# 960 -71.039791               Eagle Hill              Admirals Hill
# 961 -71.039791               Eagle Hill              Admirals Hill
# 962 -71.039791               Eagle Hill              Admirals Hill
# 969 -71.108841          Egleston Square                        NaN
#
#     Teritriary Sub-Neighborhood(s) T-Stop/Commuter Rail
# 11                             NaN                  NaN
# 12                             NaN                  NaN
# 13                             NaN                  NaN
# 14                             NaN                  NaN
# 15                             NaN                  NaN
# ..                             ...                  ...
# 957                            NaN     Copley/Arlington
# 960                        Chelsea                  NaN
# 961                        Chelsea                  NaN
# 962                        Chelsea                  NaN
# 969                            NaN          Stony Brook
#
# [437 rows x 46 columns]

# %%
len(sub_neigh.loc[sub_neigh['White Proportion'] > 50.0].index)/len(sub_neigh.index)
# Out:
# 0.6408839779005525

# %%
len(merged.loc[merged['White Proportion'] > 50.0].index)/len(merged.index)
# Out:
# 0.6484536082474227

# %%
len(sub_neigh.loc[sub_neigh['White Proportion'] > 75.0].index)/len(sub_neigh.index)
# Out:
# 0.3425414364640884

# %%
len(merged.loc[merged['White Proportion'] > 75.0].index)/len(merged.index)
# Out:
# 0.4505154639175258
