# %%
import pandas as pd
import numpy as np

X = pd.read_csv('new_data.csv', parse_dates = True, low_memory = False)
print(X.shape)
# Out:
# (1926480, 15)

# %%
X.head()
# Out:
#   [2020-10-25 14:40:25] production_jobs.INFO: Customer Id User Id  \
# 0      [2020-10-25 14:40:25] production_jobs.INFO: 8          147
# 1      [2020-10-25 14:40:25] production_jobs.INFO: 9          139
# 2      [2020-10-25 14:40:25] production_jobs.INFO: 9          139
# 3     [2020-10-25 14:40:25] production_jobs.INFO: 10          200
# 4     [2020-10-25 14:40:25] production_jobs.INFO: 10          200
#
#        User Created At      Activation Date        Activity Date  \
# 0  2018-09-26 12:19:32  2018-09-25 21:05:24  2018-09-27 09:30:53
# 1  2018-09-21 17:14:07  2018-09-22 10:00:02  2018-10-01 11:18:20
# 2  2018-09-21 17:14:07  2018-09-23 10:00:59  2018-10-01 11:19:18
# 3  2018-10-03 09:36:25  2018-10-01 08:00:36  2018-10-03 09:48:55
# 4  2018-10-03 09:36:25  2018-10-01 09:00:52  2018-10-03 10:38:28
#
#                                                 Name      Content Type  \
# 0                                 Welcome to Journey    INTERNAL_VIDEO
# ...

# %%
X = X.values

# %%
res_list = X.T.tolist()
b = list(set(res_list[10]))

device = X[:,11]
for i in range(len(device)):
    if device[i] == 'Device':
        print(i)
        
content_type = X[:,6]
for i in range(len(content_type)):
    if content_type[i] == 'Content Type':
        print(i)
#print(b)

# %%
device = X[:,11]
#print(device)
channel = X[:,12]
#print(channel)
content_type = X[:,6]
#print(content_type)
for i in range(len(device)):
    if device[i] == 'Android':
        device[i] = 4
    elif device[i] == 'iOS':
        device[i] = 3    
    elif device[i] == 'Web':
        device[i] = 2 
    elif device[i] == 'Mobile Web (Tablet)':
        device[i] = 1
    elif device[i] == 'Mobile Web':
        device[i] = 5
    else:
        device[i] = 0
print(device)

for i in range(len(channel)):
    if channel[i] == 'Mobile Notification':
        channel[i] = 2
    elif channel[i] == 'From Email':
        channel[i] = 1
    elif channel[i] == 'Direct Connection':
        channel[i] = 3
    else:
        channel[i] = 0
#print(channel)

content_type_list = ['KEY_CONTACT_NEWHIRE', 'EXTERNAL_ARTICLE', 'CHECKLIST', 'KNOWLEDGE_REQUIREMENT_NEWHIRE', 'BOOK_SUGGESTION', 'QUIZ', 'KEY_CONTACT_MANAGER', 'EXTERNAL_VIDEO', 'SURVEY', 'MEETING', 'LIVE_EVENT', 'INTERNAL_ARTICLE', 'FLIPBOOK', 'KNOWLEDGE_REQUIREMENT_MANAGER', 'INFOGRAPHIC', 'Content Type', 'INTERNAL_VIDEO', 'QUOTES']

for i in range(len(content_type)):
    if content_type[i] == content_type_list[0]:
        content_type[i] = 17
    elif content_type[i] == content_type_list[1]:
        content_type[i] = 1
    elif content_type[i] == content_type_list[2]:
        content_type[i] = 2
    elif content_type[i] == content_type_list[3]:
        content_type[i] = 3
    elif content_type[i] == content_type_list[4]:
        content_type[i] = 4
    elif content_type[i] == content_type_list[5]:
        content_type[i] = 5
    elif content_type[i] == content_type_list[6]:
        content_type[i] = 6
    elif content_type[i] == content_type_list[7]:
        content_type[i] = 7
    elif content_type[i] == content_type_list[8]:
        content_type[i] = 8
    elif content_type[i] == content_type_list[9]:
        content_type[i] = 9
    elif content_type[i] == content_type_list[10]:
        content_type[i] = 10
    elif content_type[i] == content_type_list[11]:
        content_type[i] = 11
    elif content_type[i] == content_type_list[12]:
        content_type[i] = 12
    elif content_type[i] == content_type_list[13]:
        content_type[i] = 13
    elif content_type[i] == content_type_list[14]:
        content_type[i] = 14
    elif content_type[i] == content_type_list[15]:
        content_type[i] = 15
    elif content_type[i] == content_type_list[16]:
        content_type[i] = 16
    else:
        content_type[i] = 0
#print(content_type)
# Out:
# [2 2 2 ... 4 4 5]

# %%
clean_data = pd.DataFrame(X)
print(clean_data.head())
c = clean_data.values
#print(c)
# Out:
#                                                 0    1                    2  \
# 0   [2020-10-25 14:40:25] production_jobs.INFO: 8  147  2018-09-26 12:19:32
# 1   [2020-10-25 14:40:25] production_jobs.INFO: 9  139  2018-09-21 17:14:07
# 2   [2020-10-25 14:40:25] production_jobs.INFO: 9  139  2018-09-21 17:14:07
# 3  [2020-10-25 14:40:25] production_jobs.INFO: 10  200  2018-10-03 09:36:25
# 4  [2020-10-25 14:40:25] production_jobs.INFO: 10  200  2018-10-03 09:36:25
#
#                      3                    4  \
# 0  2018-09-25 21:05:24  2018-09-27 09:30:53
# 1  2018-09-22 10:00:02  2018-10-01 11:18:20
# 2  2018-09-23 10:00:59  2018-10-01 11:19:18
# 3  2018-10-01 08:00:36  2018-10-03 09:48:55
# 4  2018-10-01 09:00:52  2018-10-03 10:38:28
#
#                                                    5   6    7  \
# 0                                 Welcome to Journey  16   86
# 1                     İnovasyoncunun Beş Alışkanlığı  14   94
# ...

# %%
max_value = clean_data[11].mode()
clean_data[11] = clean_data[11].replace([0],max_value)
print(clean_data[11].value_counts())
# Out:
# 3    924046
# 4    858524
# 5     90275
# 2     52909
# 1       726
# Name: 11, dtype: int64

# %%
content_max = clean_data[6].mode()
#print(content_max)
print(clean_data[6].value_counts())


clean_data[6] = clean_data[6].replace([0],content_max)
#print('after: ',clean_data[6].value_counts())
# Out:
# 16    591044
# 7     439583
# 12    310766
# 11    152680
# 14    149485
# 1     106079
# 5      43586
# 4      37358
# 2      34263
# 0      33266
# 8      24462
# 10      3126
# 9        710
# 3         32
# 17        20
# 6         18
# 13         2
# Name: 6, dtype: int64

# %%
max_value = clean_data[12].mode()
clean_data[12] = clean_data[12].replace([0],max_value)
print(clean_data[12].value_counts())
# Out:
# 3    1846348
# 2      52037
# 1      28095
# Name: 12, dtype: int64

# %%
clean_data.drop(clean_data[clean_data[1] == 'FLIPBOOK'].index, inplace = True)

# %%
clean_data.dropna(how = 'any', axis = 0, inplace = True)

# %%
clean_data.reset_index(inplace=True, drop=True)

# %%
clean_data[1] = clean_data[1].fillna(0.0).astype('int')

# %%
clean_data[9] = clean_data[9].replace(['nan'],'0')
clean_data[9] = clean_data[9].fillna(0.0).astype('int')

# %%
#clean_data.drop(index = 1789049, axis = 0)
clean_data[5] = clean_data[5].replace(['nan'],"")
clean_data[5] = clean_data[5].astype('str')

# %%
clean_data.columns = ['Customer Id','User Id', 'User Created At', 'Activation Date', 'Activity Date','Name', 'Content Type', 'Content ID','Journey Name', 'Action', 'Duration','Device', 'Channel', 'Session Id', 'Rating']

# %%
clean_data.head()
# Out:
#                                      Customer Id  User Id  \
# 0  [2020-10-25 14:40:25] production_jobs.INFO: 9      217
# 1  [2020-10-25 14:40:25] production_jobs.INFO: 9      217
# 2  [2020-10-25 14:40:25] production_jobs.INFO: 9      217
# 3  [2020-10-25 14:40:25] production_jobs.INFO: 9      217
# 4  [2020-10-25 14:40:25] production_jobs.INFO: 9      217
#
#        User Created At      Activation Date        Activity Date  \
# 0  2018-10-09 13:37:22  2018-10-11 16:15:13  2018-10-13 23:06:41
# 1  2018-10-09 13:37:22  2018-10-11 11:52:48  2018-10-13 23:06:46
# 2  2018-10-09 13:37:22  2018-10-06 10:00:06  2018-10-13 23:06:58
# 3  2018-10-09 13:37:22  2018-10-05 08:00:34  2018-10-15 14:30:20
# 4  2018-10-09 13:37:22  2018-10-05 08:00:34  2018-10-15 14:30:49
#
#                                                 Name  Content Type Content ID  \
# 0  LMS tarihe karışıyor: LXP dünyasına hoş geldiniz!            11        280
# ...

# %%
#clean_data = clean_data[:300].groupby(['User Id'],axis=1)
#print(Grouped.size())

clean_data.groupby(['User Id'])

#print(clean_data.groupby(['User Id']).count())

group_label = clean_data.groupby(['User Id']).groups
print(group_label)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
open_time = pd.DataFrame()
open_time = clean_data.loc[:, ('User Id','Activation Date','Activity Date','Name','Action','User Created At')]
#diff = pd.Timestamp(open_time['Activity Date'])- pd.Timestamp(open_time['Activation Date'])
#diff = pd.to_datetime(open_time['Activity Date'])- pd.to_datetime(open_time['Activation Date'])
#print(diff)
#open_time.insert(5, "Time lag", diff)
print(open_time)
#open_time.dropna(how = "any")
# Out:
#          User Id      Activation Date        Activity Date  \
# 0            217  2018-10-11 16:15:13  2018-10-13 23:06:41
# 1            217  2018-10-11 11:52:48  2018-10-13 23:06:46
# 2            217  2018-10-06 10:00:06  2018-10-13 23:06:58
# 3            217  2018-10-05 08:00:34  2018-10-15 14:30:20
# 4            217  2018-10-05 08:00:34  2018-10-15 14:30:49
# ...          ...                  ...                  ...
# 1904923    37948  2020-09-16 09:30:00  2020-10-25 22:16:58
# 1904924    37948  2020-09-16 09:30:00  2020-10-25 22:17:25
# 1904925    49199  2020-10-23 09:00:00  2020-10-25 22:17:47
# 1904926    49060  2020-10-22 09:00:00  2020-10-25 22:17:47
# 1904927    37948  2020-09-17 09:30:00  2020-10-25 22:17:50
#
#                                                       Name  Action  \
# 0        LMS tarihe karışıyor: LXP dünyasına hoş geldiniz!     100
# 1         Silikon Vadisinden en son İK ve Eğitim Trendleri     100
# ...

# %%
date = open_time['Activity Date'].map(lambda x: str(x)[0:10])

# %%
date = pd.to_datetime(date)

# %%
open_time['Activity Day'] = date.dt.day_name()

# %%
hr = open_time['Activity Date'].map(lambda x: str(x)[11:13])

# %%
open_time['hour'] = hr

# %%
open_time.head()
# Out:
#    User Id      Activation Date        Activity Date  \
# 0      217  2018-10-11 16:15:13  2018-10-13 23:06:41
# 1      217  2018-10-11 11:52:48  2018-10-13 23:06:46
# 2      217  2018-10-06 10:00:06  2018-10-13 23:06:58
# 3      217  2018-10-05 08:00:34  2018-10-15 14:30:20
# 4      217  2018-10-05 08:00:34  2018-10-15 14:30:49
#
#                                                 Name  Action  \
# 0  LMS tarihe karışıyor: LXP dünyasına hoş geldiniz!     100
# 1   Silikon Vadisinden en son İK ve Eğitim Trendleri     100
# 2  Drucker’a göre İnovasyon Fırsatı Sağlayan Yedi...     100
# 3                         8 maddede yıkıcı inovasyon     100
# 4                         8 maddede yıkıcı inovasyon     100
#
#        User Created At Activity Day hour
# 0  2018-10-09 13:37:22     Saturday   23
# 1  2018-10-09 13:37:22     Saturday   23
# 2  2018-10-09 13:37:22     Saturday   23
# 3  2018-10-09 13:37:22       Monday   14
# 4  2018-10-09 13:37:22       Monday   14

# %% [markdown]
# # Action Distribution

# %%
actiondis = open_time["Action"].values.tolist()

# %%
import collections
collections.Counter(actiondis).most_common()
# Out:
# [(100, 820423),
#  (0, 471496),
#  (85, 186487),
#  (86, 142780),
#  (99, 74953),
#  (80, 37345),
#  (87, 13779),
#  (88, 9472),
#  (81, 8215),
#  (90, 8085),
#  (97, 7056),
#  (98, 6015),
#  (92, 4990),
#  (91, 4015),
#  (33, 3491),
#  (95, 3361),
#  (50, 3065),
#  (89, 2951),
#  (96, 2608),
#  (67, 2437),
#  (94, 2414),
#  (93, 2378),
#  (12, 2315),
#  (1, 2208),
#  (11, 2100),
#  (25, 2032),
#  (2, 2024),
#  (28, 1887),
#  (5, 1839),
#  (7, 1799),
#  (34, 1765),
#  (27, 1762),
#  (9, 1754),
#  (14, 1720),
#  (10, 1687),
#  (20, 1682),
#  (3, 1663),
#  (4, 1642),
#  (22, 1624),
#  (8, 1599),
#  (16, 1588),
#  (66, 1564),
#  (6, 1501),
#  (40, 1457),
#  (55, 1430),
#  (75, 1305),
#  (37, 1254),
#  (61, 1247),
#  (13, 1207),
#  (23, 1197),
#  (42, 1194),
#  (15, 1186),
#  (60, 1110),
#  (18, 1075),
#  (30, 1028),
#  (62, 1023),
#  (44, 1018),
#  (41, 995),
#  (71, 917),
#  (29, 899),
#  (26, 883),
#  (57, 870),
#  (19, 866),
#  (45, 855),
#  (36, 845),
#  (38, 830),
#  (17, 830),
# ...

# %% [markdown]
# # Action == 100

# %%
Action100 = open_time[open_time.loc[:,("Action")] == 100]

# %%
Action = clean_data[["Content Type","Content ID","Device","Channel","Action"]]

# %%
Action.isna().sum()
# Out:
# Content Type    0
# Content ID      0
# Device          0
# Channel         0
# Action          0
# dtype: int64

# %%
Action["Content ID"] = Action["Content ID"].astype("int")
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Action.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1904928 entries, 0 to 1904927
# Data columns (total 5 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Content Type  int64
#  1   Content ID    int64
#  2   Device        int64
#  3   Channel       int64
#  4   Action        int64
# dtypes: int64(5)
# memory usage: 72.7 MB

# %%
Action.to_csv("./action.csv", index=False)

# %%
type(open_time['Activity Day'][0])
# Out:
# str

# %%
def tonum(x):
    """
    take x, activity day as input
    return int Mon -> 100, Tue -> , etc
    """
    if x == "Monday":
        #print("1")
        return 100
    elif x == "Tuesday":
        return 200
    elif x == "Wednesday":
        return 300
    elif x == "Thursday":
        return 400
    elif x == "Friday":
        return 500
    elif x == "Saturday":
        return 600
    else:
        return 700

# %%
day_num = open_time.loc[:,('Activity Day')].map(lambda x: tonum(x))

# %%
#day_num = day_num.to_frame()

# %%
Action100["day_num"] = day_num
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hr_num = Action100['hour'].map(lambda x: int(x))

# %%
Action100["hour"] = hr_num
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
total_num = Action100['hour'].add(Action100['day_num'])

# %%
Action100['total_num'] = total_num
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Action100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820423 entries, 0 to 1904924
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   User Id          820423 non-null  int64
#  1   Activation Date  820423 non-null  object
#  2   Activity Date    820423 non-null  object
#  3   Name             820423 non-null  object
#  4   Action           820423 non-null  int64
#  5   User Created At  820423 non-null  object
#  6   Activity Day     820423 non-null  object
#  7   hour             820423 non-null  int64
#  8   day_num          820423 non-null  int64
#  9   total_num        820423 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 68.9+ MB

# %%
Action100.head()
# Out:
#    User Id      Activation Date        Activity Date  \
# 0      217  2018-10-11 16:15:13  2018-10-13 23:06:41
# 1      217  2018-10-11 11:52:48  2018-10-13 23:06:46
# 2      217  2018-10-06 10:00:06  2018-10-13 23:06:58
# 3      217  2018-10-05 08:00:34  2018-10-15 14:30:20
# 4      217  2018-10-05 08:00:34  2018-10-15 14:30:49
#
#                                                 Name  Action  \
# 0  LMS tarihe karışıyor: LXP dünyasına hoş geldiniz!     100
# 1   Silikon Vadisinden en son İK ve Eğitim Trendleri     100
# 2  Drucker’a göre İnovasyon Fırsatı Sağlayan Yedi...     100
# 3                         8 maddede yıkıcı inovasyon     100
# 4                         8 maddede yıkıcı inovasyon     100
#
#        User Created At Activity Day  hour  day_num  total_num
# 0  2018-10-09 13:37:22     Saturday    23      600        623
# 1  2018-10-09 13:37:22     Saturday    23      600        623
# 2  2018-10-09 13:37:22     Saturday    23      600        623
# ...

# %%
df100 = pd.DataFrame({'User Id':Action100["User Id"].unique()})

# %%
df100['total_num'] = [list(set(Action100['total_num'].loc[Action100['User Id'] == x['User Id']])) for _, x in df100.iterrows()]

# %%
df100.head()
# Out:
#    User Id                                          total_num
# 0      217  [512, 312, 611, 408, 423, 617, 618, 623, 208, ...
# 1      242  [512, 320, 708, 109, 208, 114, 309, 214, 215, ...
# 2       69                               [312, 313, 512, 111]
# 3      308                                    [602, 419, 415]
# 4      304                          [416, 321, 610, 422, 221]

# %%
df = Action100.groupby('User Id').agg(lambda x: x.tolist())

# %%
df.head()
# Out:
#                                            Activation Date  \
# User Id
# 21       [2018-10-31 13:32:19, 2018-11-01 08:30:57, 201...
# 38              [2019-10-03 08:00:00, 2019-10-03 09:00:00]
# 41       [2019-02-21 16:00:00, 2019-02-21 16:39:00, 201...
# 47       [2020-10-07 12:45:00, 2020-10-07 12:45:00, 202...
# 53       [2018-11-01 08:30:57, 2018-11-08 08:30:00, 201...
#
#                                              Activity Date  \
# User Id
# 21       [2018-10-31 14:08:53, 2018-11-01 08:33:27, 201...
# 38              [2019-10-04 03:12:57, 2019-10-04 03:13:10]
# 41       [2019-02-22 08:16:24, 2019-02-22 08:17:25, 201...
# 47       [2020-10-07 14:27:21, 2020-10-07 14:27:22, 202...
# 53       [2018-11-17 13:04:53, 2018-11-17 13:06:15, 201...
#
#                                                       Name  \
# User Id
# 21       [Çalışan Bağlılığı 3.0: Kişiye Özel “Nudge (Dü...
# 38                                     [demo flip, safety]
# ...

# %%
index_df = df.index.values

# %%
df["count_total"] = ''

# %%
from collections import Counter
def count(x):
    Counter(df["total_num"][21]).most_common()

# %%
for i in range(len(index_df)):
    df['count_total'][index_df[i]] = Counter(df['total_num'][index_df[i]]).most_common()

# %%
df.head()
# Out:
#                                            Activation Date  \
# User Id
# 21       [2018-10-31 13:32:19, 2018-11-01 08:30:57, 201...
# 38              [2019-10-03 08:00:00, 2019-10-03 09:00:00]
# 41       [2019-02-21 16:00:00, 2019-02-21 16:39:00, 201...
# 47       [2020-10-07 12:45:00, 2020-10-07 12:45:00, 202...
# 53       [2018-11-01 08:30:57, 2018-11-08 08:30:00, 201...
#
#                                              Activity Date  \
# User Id
# 21       [2018-10-31 14:08:53, 2018-11-01 08:33:27, 201...
# 38              [2019-10-04 03:12:57, 2019-10-04 03:13:10]
# 41       [2019-02-22 08:16:24, 2019-02-22 08:17:25, 201...
# 47       [2020-10-07 14:27:21, 2020-10-07 14:27:22, 202...
# 53       [2018-11-17 13:04:53, 2018-11-17 13:06:15, 201...
#
#                                                       Name  \
# User Id
# 21       [Çalışan Bağlılığı 3.0: Kişiye Özel “Nudge (Dü...
# 38                                     [demo flip, safety]
# ...

# %%
def sort_arr(arr):
    res = [[],[],[],[],[],[],[]]
    for i in range(len(arr)):
        item = str(arr[i][0])
        if item[0] == "1":
            res[0].append(arr[i])
            #return res
        elif item[0] == "2":
            res[1].append(arr[i])
            #return res
        elif item[0] == "3":
            res[2].append(arr[i])
            #return res
        elif item[0] == "4":
            res[3].append(arr[i])
            #return res
        elif item[0] == "5":
            res[4].append(arr[i])
            #return res
        elif item[0] == "6":
            res[5].append(arr[i])
            #return res
        else:
            res[6].append(arr[i])
            #return res
    return res
def get_max(arr):
    l = []
    for i in range(len(arr)):
        l.append(arr[i][-1])
    return max(l)
def find_freq(arr):
    res = []
    sorted_arr = sort_arr(arr)
    for i in range(len(sorted_arr)):
        if len(sorted_arr[i]) == 0:
            res.append([])
        else:
            if len(sorted_arr[i]) == 1:
                res.append(sorted_arr[i])
            else:
                subarr = sorted_arr[i]
                l = []
                m = get_max(subarr)
                for j in range(len(subarr)):
                    if subarr[j][-1] == m:
                        l.append(subarr[j])
                res.append(l)
    return res

# %%
df["every_day_freq"] = ''

# %%
for i in range(len(index_df)):
    arr = df["count_total"][index_df[i]]
    df["every_day_freq"][index_df[i]] = find_freq(arr)

# %%
df.head()
# Out:
#                                            Activation Date  \
# User Id
# 21       [2018-10-31 13:32:19, 2018-11-01 08:30:57, 201...
# 38              [2019-10-03 08:00:00, 2019-10-03 09:00:00]
# 41       [2019-02-21 16:00:00, 2019-02-21 16:39:00, 201...
# 47       [2020-10-07 12:45:00, 2020-10-07 12:45:00, 202...
# 53       [2018-11-01 08:30:57, 2018-11-08 08:30:00, 201...
#
#                                              Activity Date  \
# User Id
# 21       [2018-10-31 14:08:53, 2018-11-01 08:33:27, 201...
# 38              [2019-10-04 03:12:57, 2019-10-04 03:13:10]
# 41       [2019-02-22 08:16:24, 2019-02-22 08:17:25, 201...
# 47       [2020-10-07 14:27:21, 2020-10-07 14:27:22, 202...
# 53       [2018-11-17 13:04:53, 2018-11-17 13:06:15, 201...
#
#                                                       Name  \
# User Id
# 21       [Çalışan Bağlılığı 3.0: Kişiye Özel “Nudge (Dü...
# 38                                     [demo flip, safety]
# ...

# %%
df['Mon'] = ''
df['Tue'] = ''
df['Wed'] = ''
df['Thu'] = ''
df['Fri'] = ''
df['Sat'] = ''
df['Sun'] = ''

# %%
for i in range(len(index_df)):
    arr = df["every_day_freq"][index_df[i]]
    temp = []
    ### Monday
    if len(arr[0]) == 0:
        df['Mon'][index_df[i]] = [np.nan]
    else:
        if len(arr[0]) == 1:
            df['Mon'][index_df[i]] = [arr[0][0][0]%100]
        else:
            for j in range(len(arr[0])):
                temp.append(arr[0][j][0]%100)
                df['Mon'][index_df[i]] = temp
    ### Tuesday
    if len(arr[1]) == 0:
        df['Tue'][index_df[i]] = [np.nan]
    else:
        if len(arr[1]) == 1:
            df['Tue'][index_df[i]] = [arr[1][0][0]%100]
        else:
            for j in range(len(arr[1])):
                temp.append(arr[1][j][0]%100)
                df['Tue'][index_df[i]] = temp
    ### Wednesday
    if len(arr[2]) == 0:
        df['Wed'][index_df[i]] = [np.nan]
    else:
        if len(arr[2]) == 1:
            df['Wed'][index_df[i]] = [arr[2][0][0]%100]
        else:
            for j in range(len(arr[2])):
                temp.append(arr[2][j][0]%100)
                df['Wed'][index_df[i]] = temp
    ### Thursday
    if len(arr[3]) == 0:
        df['Thu'][index_df[i]] = [np.nan]
    else:
        if len(arr[3]) == 1:
            df['Thu'][index_df[i]] = [arr[3][0][0]%100]
        else:
            for j in range(len(arr[3])):
                temp.append(arr[3][j][0]%100)
                df['Thu'][index_df[i]] = temp
    ### Friday
    if len(arr[4]) == 0:
        df['Fri'][index_df[i]] = [np.nan]
    else:
        if len(arr[4]) == 1:
            df['Fri'][index_df[i]] = [arr[4][0][0]%100]
        else:
            for j in range(len(arr[4])):
                temp.append(arr[4][j][0]%100)
                df['Fri'][index_df[i]] = temp
    ### Saturday
    if len(arr[5]) == 0:
        df['Sat'][index_df[i]] = [np.nan]
    else:
        if len(arr[5]) == 1:
            df['Sat'][index_df[i]] = [arr[5][0][0]%100]
        else:
            for j in range(len(arr[5])):
                temp.append(arr[5][j][0]%100)
                df['Sat'][index_df[i]] = temp
    ### Sunday
    if len(arr[6]) == 0:
        df['Sun'][index_df[i]] = [np.nan]
    else:
        if len(arr[6]) == 1:
            df['Sun'][index_df[i]] = [arr[6][0][0]%100]
        else:
            for j in range(len(arr[6])):
                temp.append(arr[6][j][0]%100)
                df['Sun'][index_df[i]] = temp

# %%
df.head()
# Out:
#                                            Activation Date  \
# User Id
# 21       [2018-10-31 13:32:19, 2018-11-01 08:30:57, 201...
# 38              [2019-10-03 08:00:00, 2019-10-03 09:00:00]
# 41       [2019-02-21 16:00:00, 2019-02-21 16:39:00, 201...
# 47       [2020-10-07 12:45:00, 2020-10-07 12:45:00, 202...
# 53       [2018-11-01 08:30:57, 2018-11-08 08:30:00, 201...
#
#                                              Activity Date  \
# User Id
# 21       [2018-10-31 14:08:53, 2018-11-01 08:33:27, 201...
# 38              [2019-10-04 03:12:57, 2019-10-04 03:13:10]
# 41       [2019-02-22 08:16:24, 2019-02-22 08:17:25, 201...
# 47       [2020-10-07 14:27:21, 2020-10-07 14:27:22, 202...
# 53       [2018-11-17 13:04:53, 2018-11-17 13:06:15, 201...
#
#                                                       Name  \
# User Id
# 21       [Çalışan Bağlılığı 3.0: Kişiye Özel “Nudge (Dü...
# 38                                     [demo flip, safety]
# ...

# %%
customer100 = pd.DataFrame()
customer100 = df.loc[:,('Mon','Tue','Wed','Thu','Fri','Sat','Sun')]

# %%
customer100.head()
# Out:
#            Mon       Tue    Wed    Thu    Fri    Sat    Sun
# User Id
# 21        [16]       [8]   [15]    [8]  [nan]  [nan]  [nan]
# 38       [nan]     [nan]  [nan]  [nan]    [3]  [nan]  [nan]
# 41        [11]  [10, 15]    [9]   [10]    [9]   [17]   [12]
# 47       [nan]     [nan]   [14]  [nan]  [nan]  [nan]  [nan]
# 53       [nan]     [nan]  [nan]  [nan]  [nan]   [13]  [nan]

# %% [markdown]
# # Action <100 AND Action>=90

# %%
Action90_100 = open_time[(open_time.loc[:,("Action")] < 100) & (open_time.loc[:,("Action")] >= 90)]

# %%
Action90_100
# Out:
#          User Id      Activation Date        Activity Date  \
# 1800         632  2018-11-27 08:00:00  2018-12-11 12:16:38
# 1813          78  2018-11-19 08:03:00  2018-12-11 15:36:53
# 2179          78  2018-11-25 08:00:00  2018-12-12 12:14:47
# 2329         632  2018-12-07 08:00:00  2018-12-14 10:32:50
# 2457         632  2018-12-08 10:00:00  2018-12-18 14:31:31
# ...          ...                  ...                  ...
# 1904868     6860  2020-06-08 11:00:00  2020-10-25 22:04:11
# 1904897    49199  2020-10-23 09:00:00  2020-10-25 22:07:17
# 1904908    49601  2020-10-20 08:00:00  2020-10-25 22:10:43
# 1904911    49199  2020-10-23 09:00:00  2020-10-25 22:11:53
# 1904918    49199  2020-10-23 09:00:00  2020-10-25 22:14:47
#
#                                                       Name  Action  \
# 1800                                  SWOT-Strateji Metodu      97
# 1813     Sessiz Müşteri Şikayetleri Sizi Nasıl Geliştirir?      99
# ...

# %%
Action = clean_data[["Content Type","Content ID","Device","Channel","Action"]]

# %%
Action.isna().sum()
# Out:
# Content Type    0
# Content ID      0
# Device          0
# Channel         0
# Action          0
# dtype: int64

# %%
Action["Content ID"] = Action["Content ID"].astype("int")
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
day_num = open_time.loc[:,('Activity Day')].map(lambda x: tonum(x))

# %%
Action90_100["day_num"] = day_num
hr_num = Action90_100['hour'].map(lambda x: int(x))
Action90_100["hour"] = hr_num
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
total_num = Action90_100['hour'].add(Action90_100['day_num'])
Action90_100['total_num'] = total_num
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Action90_100.head()
# Out:
#       User Id      Activation Date        Activity Date  \
# 1800      632  2018-11-27 08:00:00  2018-12-11 12:16:38
# 1813       78  2018-11-19 08:03:00  2018-12-11 15:36:53
# 2179       78  2018-11-25 08:00:00  2018-12-12 12:14:47
# 2329      632  2018-12-07 08:00:00  2018-12-14 10:32:50
# 2457      632  2018-12-08 10:00:00  2018-12-18 14:31:31
#
#                                                    Name  Action  \
# 1800                               SWOT-Strateji Metodu      97
# 1813  Sessiz Müşteri Şikayetleri Sizi Nasıl Geliştirir?      99
# 2179  Ne Kadar Müşteri Odaklı Bir Şirket Kültürünüz ...      92
# 2329                            Mavi Okyanus Stratejisi      93
# 2457  Değişim Karşısında Başarılı Olmak İçin Öğrendi...      90
#
#           User Created At Activity Day  hour  day_num  total_num
# 1800  2018-12-10 21:38:55      Tuesday    12      200        212
# 1813  2018-08-01 15:08:31      Tuesday    15      200        215
# ...

# %%
df90_100 = pd.DataFrame({'User Id':Action90_100["User Id"].unique()})

# %%
df90_100['total_num'] = [list(set(Action90_100['total_num'].loc[Action90_100['User Id'] == x['User Id']])) for _, x in df90_100.iterrows()]

# %%
df90_100.head()
# Out:
#    User Id                            total_num
# 0      632                      [212, 214, 510]
# 1       78  [418, 423, 615, 215, 312, 315, 511]
# 2      707                           [509, 110]
# 3      658                                [509]
# 4      669                                [113]

# %%
df90_100_res = Action90_100.groupby('User Id').agg(lambda x: x.tolist())

# %%
df90_100_res.head()
# Out:
#                                            Activation Date  \
# User Id
# 41       [2019-03-01 16:15:00, 2019-04-15 12:15:00, 201...
# 61                                   [2020-06-15 11:34:00]
# 62              [2020-06-15 11:35:00, 2020-06-15 11:35:00]
# 78       [2018-11-19 08:03:00, 2018-11-25 08:00:00, 201...
# 79       [2019-01-03 07:00:00, 2019-01-03 08:00:00, 201...
#
#                                              Activity Date  \
# User Id
# 41       [2019-03-04 15:23:23, 2019-04-24 11:50:48, 201...
# 61                                   [2020-06-15 12:34:39]
# 62              [2020-06-15 11:40:22, 2020-06-15 11:40:26]
# 78       [2018-12-11 15:36:53, 2018-12-12 12:14:47, 201...
# 79       [2019-01-03 23:10:19, 2019-01-04 13:16:51, 201...
#
#                                                       Name  \
# User Id
# 41       [İnsan Kaynakları Çevikleşiyor, Potansiyel Mev...
# 61                   [Etkili Geri-bildirim Nasıl Verilir?]
# ...

# %%
index_df90_100_res = df90_100_res.index.values

# %%
df90_100_res["count_total"] = ''

# %%
for i in range(len(index_df90_100_res)):
    df90_100_res['count_total'][index_df90_100_res[i]] = Counter(df90_100_res['total_num'][index_df90_100_res[i]]).most_common()

# %%
df90_100_res.head()
# Out:
#                                            Activation Date  \
# User Id
# 41       [2019-03-01 16:15:00, 2019-04-15 12:15:00, 201...
# 61                                   [2020-06-15 11:34:00]
# 62              [2020-06-15 11:35:00, 2020-06-15 11:35:00]
# 78       [2018-11-19 08:03:00, 2018-11-25 08:00:00, 201...
# 79       [2019-01-03 07:00:00, 2019-01-03 08:00:00, 201...
#
#                                              Activity Date  \
# User Id
# 41       [2019-03-04 15:23:23, 2019-04-24 11:50:48, 201...
# 61                                   [2020-06-15 12:34:39]
# 62              [2020-06-15 11:40:22, 2020-06-15 11:40:26]
# 78       [2018-12-11 15:36:53, 2018-12-12 12:14:47, 201...
# 79       [2019-01-03 23:10:19, 2019-01-04 13:16:51, 201...
#
#                                                       Name  \
# User Id
# 41       [İnsan Kaynakları Çevikleşiyor, Potansiyel Mev...
# 61                   [Etkili Geri-bildirim Nasıl Verilir?]
# ...

# %%
df90_100_res["every_day_freq"] = ''

# %%
for i in range(len(index_df90_100_res)):
    arr = df90_100_res["count_total"][index_df90_100_res[i]]
    df90_100_res["every_day_freq"][index_df90_100_res[i]] = find_freq(arr)
df90_100_res.head()
df90_100_res['Mon'] = ''
df90_100_res['Tue'] = ''
df90_100_res['Wed'] = ''
df90_100_res['Thu'] = ''
df90_100_res['Fri'] = ''
df90_100_res['Sat'] = ''
df90_100_res['Sun'] = ''

# %%
def total_to_hr(index_df, df):
    for i in range(len(index_df)):
        arr = df["every_day_freq"][index_df[i]]
        temp = []
        ### Monday
        if len(arr[0]) == 0:
            df['Mon'][index_df[i]] = [np.nan]
        else:
            if len(arr[0]) == 1:
                df['Mon'][index_df[i]] = [arr[0][0][0]%100]
            else:
                for j in range(len(arr[0])):
                    temp.append(arr[0][j][0]%100)
                    df['Mon'][index_df[i]] = temp
        ### Tuesday
        if len(arr[1]) == 0:
            df['Tue'][index_df[i]] = [np.nan]
        else:
            if len(arr[1]) == 1:
                df['Tue'][index_df[i]] = [arr[1][0][0]%100]
            else:
                for j in range(len(arr[1])):
                    temp.append(arr[1][j][0]%100)
                    df['Tue'][index_df[i]] = temp
        ### Wednesday
        if len(arr[2]) == 0:
            df['Wed'][index_df[i]] = [np.nan]
        else:
            if len(arr[2]) == 1:
                df['Wed'][index_df[i]] = [arr[2][0][0]%100]
            else:
                for j in range(len(arr[2])):
                    temp.append(arr[2][j][0]%100)
                    df['Wed'][index_df[i]] = temp
        ### Thursday
        if len(arr[3]) == 0:
            df['Thu'][index_df[i]] = [np.nan]
        else:
            if len(arr[3]) == 1:
                df['Thu'][index_df[i]] = [arr[3][0][0]%100]
            else:
                for j in range(len(arr[3])):
                    temp.append(arr[3][j][0]%100)
                    df['Thu'][index_df[i]] = temp
        ### Friday
        if len(arr[4]) == 0:
            df['Fri'][index_df[i]] = [np.nan]
        else:
            if len(arr[4]) == 1:
                df['Fri'][index_df[i]] = [arr[4][0][0]%100]
            else:
                for j in range(len(arr[4])):
                    temp.append(arr[4][j][0]%100)
                    df['Fri'][index_df[i]] = temp
        ### Saturday
        if len(arr[5]) == 0:
            df['Sat'][index_df[i]] = [np.nan]
        else:
            if len(arr[5]) == 1:
                df['Sat'][index_df[i]] = [arr[5][0][0]%100]
            else:
                for j in range(len(arr[5])):
                    temp.append(arr[5][j][0]%100)
                    df['Sat'][index_df[i]] = temp
        ### Sunday
        if len(arr[6]) == 0:
            df['Sun'][index_df[i]] = [np.nan]
        else:
            if len(arr[6]) == 1:
                df['Sun'][index_df[i]] = [arr[6][0][0]%100]
            else:
                for j in range(len(arr[6])):
                    temp.append(arr[6][j][0]%100)
                    df['Sun'][index_df[i]] = temp
    return(df)

# %%
res_90_100 = total_to_hr(index_df90_100_res,df90_100_res)

# %%
res_90_100.head()
# Out:
#                                            Activation Date  \
# User Id
# 41       [2019-03-01 16:15:00, 2019-04-15 12:15:00, 201...
# 61                                   [2020-06-15 11:34:00]
# 62              [2020-06-15 11:35:00, 2020-06-15 11:35:00]
# 78       [2018-11-19 08:03:00, 2018-11-25 08:00:00, 201...
# 79       [2019-01-03 07:00:00, 2019-01-03 08:00:00, 201...
#
#                                              Activity Date  \
# User Id
# 41       [2019-03-04 15:23:23, 2019-04-24 11:50:48, 201...
# 61                                   [2020-06-15 12:34:39]
# 62              [2020-06-15 11:40:22, 2020-06-15 11:40:26]
# 78       [2018-12-11 15:36:53, 2018-12-12 12:14:47, 201...
# 79       [2019-01-03 23:10:19, 2019-01-04 13:16:51, 201...
#
#                                                       Name  \
# User Id
# 41       [İnsan Kaynakları Çevikleşiyor, Potansiyel Mev...
# 61                   [Etkili Geri-bildirim Nasıl Verilir?]
# ...

# %%
customer90_100 = pd.DataFrame()
customer90_100 = df90_100_res.loc[:,('Mon','Tue','Wed','Thu','Fri','Sat','Sun')]
customer90_100.head()
# Out:
#                       Mon    Tue               Wed    Thu    Fri    Sat    Sun
# User Id
# 41       [15, 16, 11, 18]   [15]  [15, 16, 11, 18]  [nan]  [nan]  [nan]  [nan]
# 61                   [12]  [nan]             [nan]  [nan]  [nan]  [nan]  [nan]
# 62                   [11]  [nan]             [nan]  [nan]  [nan]  [nan]  [nan]
# 78                  [nan]   [15]          [12, 15]   [23]   [11]   [15]  [nan]
# 79                   [23]   [19]          [13, 14]   [23]   [13]  [nan]  [nan]

# %% [markdown]
# # Action >=80 and Action < 90

# %%
Action80_90 = open_time[(open_time.loc[:,("Action")] < 90) & (open_time.loc[:,("Action")] >= 80)]
Action = clean_data[["Content Type","Content ID","Device","Channel","Action"]]
Action.isna().sum()
Action["Content ID"] = Action["Content ID"].astype("int")
day_num = open_time.loc[:,('Activity Day')].map(lambda x: tonum(x))
Action80_90["day_num"] = day_num
hr_num = Action80_90['hour'].map(lambda x: int(x))
Action80_90["hour"] = hr_num
total_num = Action80_90['hour'].add(Action80_90['day_num'])
Action80_90['total_num'] = total_num
df80_90 = pd.DataFrame({'User Id':Action80_90["User Id"].unique()})
df80_90['total_num'] = [list(set(Action80_90['total_num'].loc[Action80_90['User Id'] == x['User Id']])) for _, x in df80_90.iterrows()]
df80_90_res = Action80_90.groupby('User Id').agg(lambda x: x.tolist())
index_df80_90_res = df80_90_res.index.values
df80_90_res["count_total"] = ''
for i in range(len(index_df80_90_res)):
    df80_90_res['count_total'][index_df80_90_res[i]] = Counter(df80_90_res['total_num'][index_df80_90_res[i]]).most_common()
df80_90_res["every_day_freq"] = ''
for i in range(len(index_df80_90_res)):
    arr = df80_90_res["count_total"][index_df80_90_res[i]]
    df80_90_res["every_day_freq"][index_df80_90_res[i]] = find_freq(arr)
df80_90_res.head()
df80_90_res['Mon'] = ''
df80_90_res['Tue'] = ''
df80_90_res['Wed'] = ''
df80_90_res['Thu'] = ''
df80_90_res['Fri'] = ''
df80_90_res['Sat'] = ''
df80_90_res['Sun'] = ''
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df80_90_res.head()
# Out:
#                                            Activation Date  \
# User Id
# 41       [2019-02-22 15:00:00, 2019-04-04 15:00:00, 201...
# 47                                   [2020-10-06 12:45:00]
# 61       [2020-06-15 08:00:00, 2020-06-15 11:35:00, 202...
# 62       [2020-06-15 11:32:00, 2020-06-15 11:31:00, 202...
# 63              [2020-06-15 11:31:00, 2020-06-15 11:32:00]
#
#                                              Activity Date  \
# User Id
# 41       [2019-02-22 16:18:37, 2019-04-24 11:53:28, 201...
# 47                                   [2020-10-07 14:27:47]
# 61       [2020-06-15 11:37:16, 2020-06-15 12:30:42, 202...
# 62       [2020-06-15 11:32:44, 2020-06-15 11:33:09, 202...
# 63              [2020-06-15 11:31:48, 2020-10-15 11:12:39]
#
#                                                       Name  \
# User Id
# 41       [Kontrol Listesi: Potansiyel Mevduat Müşterisi...
# 47             [Odaklanma Becerinizi 6 Adımda Güçlendirin]
# ...

# %%
res_80_90 = total_to_hr(index_df80_90_res,df80_90_res)
customer80_90 = pd.DataFrame()
customer80_90 = df80_90_res.loc[:,('Mon','Tue','Wed','Thu','Fri','Sat','Sun')]
customer80_90.head()
# Out:
#               Mon                  Tue    Wed    Thu    Fri  \
# User Id
# 41           [15]  [9, 11, 18, 17, 11]   [11]   [21]   [16]
# 47          [nan]                [nan]   [14]  [nan]  [nan]
# 61           [15]                 [16]  [nan]   [15]   [16]
# 62       [11, 20]                [nan]  [nan]  [nan]   [18]
# 63           [11]                [nan]  [nan]   [11]  [nan]
#
#                          Sat    Sun
# User Id
# 41       [9, 11, 18, 17, 11]   [12]
# 47                     [nan]  [nan]
# 61                     [nan]  [nan]
# 62                     [nan]  [nan]
# 63                     [nan]  [nan]

# %% [markdown]
# # Action >=50 and Action < 80

# %%
Action50_80 = open_time[(open_time.loc[:,("Action")] < 80) & (open_time.loc[:,("Action")] >= 50)]
Action = clean_data[["Content Type","Content ID","Device","Channel","Action"]]
Action.isna().sum()
Action["Content ID"] = Action["Content ID"].astype("int")
day_num = open_time.loc[:,('Activity Day')].map(lambda x: tonum(x))
Action50_80["day_num"] = day_num
hr_num = Action50_80['hour'].map(lambda x: int(x))
Action50_80["hour"] = hr_num
total_num = Action50_80['hour'].add(Action50_80['day_num'])
Action50_80['total_num'] = total_num
df50_80 = pd.DataFrame({'User Id':Action50_80["User Id"].unique()})
df50_80['total_num'] = [list(set(Action50_80['total_num'].loc[Action50_80['User Id'] == x['User Id']])) for _, x in df50_80.iterrows()]
df50_80_res = Action50_80.groupby('User Id').agg(lambda x: x.tolist())
index_df50_80_res = df50_80_res.index.values
df50_80_res["count_total"] = ''
for i in range(len(index_df50_80_res)):
    df50_80_res['count_total'][index_df50_80_res[i]] = Counter(df50_80_res['total_num'][index_df50_80_res[i]]).most_common()
df50_80_res["every_day_freq"] = ''
for i in range(len(index_df50_80_res)):
    arr = df50_80_res["count_total"][index_df50_80_res[i]]
    df50_80_res["every_day_freq"][index_df50_80_res[i]] = find_freq(arr)
df50_80_res.head()
df50_80_res['Mon'] = ''
df50_80_res['Tue'] = ''
df50_80_res['Wed'] = ''
df50_80_res['Thu'] = ''
df50_80_res['Fri'] = ''
df50_80_res['Sat'] = ''
df50_80_res['Sun'] = ''
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df50_80_res.head()
# Out:
#                                            Activation Date  \
# User Id
# 41       [2019-02-22 11:45:00, 2019-02-22 11:45:00, 201...
# 47                                   [2020-10-06 12:45:00]
# 61                                   [2020-06-15 11:32:00]
# 66       [2019-06-28 12:44:00, 2019-06-28 12:41:00, 201...
# 69                                   [2018-10-03 09:54:46]
#
#                                              Activity Date  \
# User Id
# 41       [2019-02-25 14:21:50, 2019-02-25 14:22:55, 201...
# 47                                   [2020-10-07 14:28:01]
# 61                                   [2020-06-18 15:07:37]
# 66       [2019-07-08 14:22:50, 2019-07-08 14:33:15, 201...
# 69                                   [2018-11-28 12:23:31]
#
#                                                       Name  \
# User Id
# 41       [Potansiyel Müşteri Bulma Yöntemleri, Potansiy...
# 47             [Odaklanma Becerinizi 6 Adımda Güçlendirin]
# ...

# %%
res_50_80 = total_to_hr(index_df50_80_res,df50_80_res)
customer50_80 = pd.DataFrame()
customer50_80 = df50_80_res.loc[:,('Mon','Tue','Wed','Thu','Fri','Sat','Sun')]
customer50_80.head()
# Out:
#            Mon    Tue    Wed       Thu    Fri    Sat    Sun
# User Id
# 41        [10]    [9]   [11]  [14, 11]   [10]   [23]  [nan]
# 47       [nan]  [nan]   [14]     [nan]  [nan]  [nan]  [nan]
# 61       [nan]  [nan]  [nan]      [15]  [nan]  [nan]  [nan]
# 66        [14]  [nan]  [nan]      [15]  [nan]  [nan]  [nan]
# 69       [nan]  [nan]   [12]     [nan]  [nan]  [nan]  [nan]

# %% [markdown]
# # Action > 0 and Action < 50

# %%
Action0_50 = open_time[(open_time.loc[:,("Action")] < 50) & (open_time.loc[:,("Action")] > 0)]
Action = clean_data[["Content Type","Content ID","Device","Channel","Action"]]
Action.isna().sum()
Action["Content ID"] = Action["Content ID"].astype("int")
day_num = open_time.loc[:,('Activity Day')].map(lambda x: tonum(x))
Action0_50["day_num"] = day_num
hr_num = Action0_50['hour'].map(lambda x: int(x))
Action0_50["hour"] = hr_num
total_num = Action0_50['hour'].add(Action0_50['day_num'])
Action0_50['total_num'] = total_num
df0_50 = pd.DataFrame({'User Id':Action0_50["User Id"].unique()})
df0_50['total_num'] = [list(set(Action0_50['total_num'].loc[Action0_50['User Id'] == x['User Id']])) for _, x in df0_50.iterrows()]
df0_50_res = Action0_50.groupby('User Id').agg(lambda x: x.tolist())
index_df0_50_res = df0_50_res.index.values
df0_50_res["count_total"] = ''
for i in range(len(index_df0_50_res)):
    df0_50_res['count_total'][index_df0_50_res[i]] = Counter(df0_50_res['total_num'][index_df0_50_res[i]]).most_common()
df0_50_res["every_day_freq"] = ''
for i in range(len(index_df0_50_res)):
    arr = df0_50_res["count_total"][index_df0_50_res[i]]
    df0_50_res["every_day_freq"][index_df0_50_res[i]] = find_freq(arr)
df0_50_res.head()
df0_50_res['Mon'] = ''
df0_50_res['Tue'] = ''
df0_50_res['Wed'] = ''
df0_50_res['Thu'] = ''
df0_50_res['Fri'] = ''
df0_50_res['Sat'] = ''
df0_50_res['Sun'] = ''
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df0_50_res.head()
# Out:
#                                            Activation Date  \
# User Id
# 41       [2019-02-22 16:00:00, 2019-02-22 16:30:00, 201...
# 47                                   [2020-10-02 13:30:00]
# 61       [2020-06-15 11:35:00, 2020-06-15 11:34:00, 202...
# 62       [2020-06-15 11:32:00, 2020-06-15 11:34:00, 202...
# 63              [2020-06-15 11:31:00, 2020-06-15 11:35:00]
#
#                                              Activity Date  \
# User Id
# 41       [2019-02-22 16:00:47, 2019-02-25 14:21:59, 201...
# 47                                   [2020-10-07 14:30:41]
# 61       [2020-06-15 12:31:04, 2020-06-22 15:11:19, 202...
# 62       [2020-06-15 11:33:04, 2020-06-15 11:39:47, 202...
# 63              [2020-06-15 11:32:16, 2020-10-15 11:12:23]
#
#                                                       Name  \
# User Id
# 41       [Potansiyel Mevduat Müşterisi Kazanma Yöntemle...
# 47                        [Mavi Okyanus Stratejisi Nedir?]
# ...

# %%
res_0_50 = total_to_hr(index_df0_50_res,df0_50_res)
customer0_50 = pd.DataFrame()
customer0_50 = df0_50_res.loc[:,('Mon','Tue','Wed','Thu','Fri','Sat','Sun')]
customer0_50.head()
# Out:
#                                          Mon  \
# User Id
# 41       [14, 10, 13, 16, 9, 15, 18, 11, 16]
# 47                                     [nan]
# 61                                  [12, 15]
# 62                                      [11]
# 63                                      [11]
#
#                                          Tue  \
# User Id
# 41       [14, 10, 13, 16, 9, 15, 18, 11, 16]
# 47                                     [nan]
# 61                                      [16]
# 62                                     [nan]
# 63                                     [nan]
#
#                                          Wed    Thu    Fri    Sat    Sun
# User Id
# 41       [14, 10, 13, 16, 9, 15, 18, 11, 16]   [14]   [16]   [17]   [15]
# 47                                      [14]  [nan]  [nan]  [nan]  [nan]
# 61                                     [nan]  [nan]  [nan]  [nan]  [nan]
# 62                                     [nan]  [nan]   [18]  [nan]  [nan]
# ...

# %% [markdown]
# # Action == 0

# %%
Action0 = open_time[(open_time.loc[:,("Action")] == 0)]
Action = clean_data[["Content Type","Content ID","Device","Channel","Action"]]
Action.isna().sum()
Action["Content ID"] = Action["Content ID"].astype("int")
day_num = open_time.loc[:,('Activity Day')].map(lambda x: tonum(x))
Action0["day_num"] = day_num
hr_num = Action0['hour'].map(lambda x: int(x))
Action0["hour"] = hr_num
total_num = Action0['hour'].add(Action0['day_num'])
Action0['total_num'] = total_num
df0 = pd.DataFrame({'User Id':Action0["User Id"].unique()})
df0['total_num'] = [list(set(Action0['total_num'].loc[Action0['User Id'] == x['User Id']])) for _, x in df0.iterrows()]
df0_res = Action0.groupby('User Id').agg(lambda x: x.tolist())
index_df0_res = df0_res.index.values
df0_res["count_total"] = ''
for i in range(len(index_df0_res)):
    df0_res['count_total'][index_df0_res[i]] = Counter(df0_res['total_num'][index_df0_res[i]]).most_common()
df0_res["every_day_freq"] = ''
for i in range(len(index_df0_res)):
    arr = df0_res["count_total"][index_df0_res[i]]
    df0_res["every_day_freq"][index_df0_res[i]] = find_freq(arr)
df0_res.head()
df0_res['Mon'] = ''
df0_res['Tue'] = ''
df0_res['Wed'] = ''
df0_res['Thu'] = ''
df0_res['Fri'] = ''
df0_res['Sat'] = ''
df0_res['Sun'] = ''
# Out:
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/rqshi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df0_res.head()
# Out:
#                                            Activation Date  \
# User Id
# 38              [2019-10-02 08:00:00, 2019-10-02 08:00:00]
# 41       [2019-04-10 16:20:00, 2019-02-12 14:18:00, 201...
# 47       [2020-10-07 12:45:00, 2020-10-06 12:45:00, 202...
# 61       [2020-06-15 11:32:00, 2020-06-15 11:32:00, 202...
# 62       [2020-06-15 11:32:00, 2020-06-15 11:32:00, 202...
#
#                                              Activity Date  \
# User Id
# 38              [2019-10-04 03:12:03, 2019-10-04 03:12:32]
# 41       [2020-01-16 14:33:14, 2020-01-16 14:33:24, 202...
# 47       [2020-10-07 14:25:53, 2020-10-07 14:27:37, 202...
# 61       [2020-06-15 11:32:18, 2020-06-15 11:32:26, 202...
# 62       [2020-06-15 11:32:37, 2020-06-15 11:32:38, 202...
#
#                                                       Name  \
# User Id
# 38                  [First day at work, First day at work]
# 41       [Şerif Kaynar-İş Dünyasında Başarı, 2. Haftanı...
# ...

# %%
res_0 = total_to_hr(index_df0_res,df0_res)
customer0 = pd.DataFrame()
customer0 = df0_res.loc[:,('Mon','Tue','Wed','Thu','Fri','Sat','Sun')]
customer0.head()
# Out:
#            Mon    Tue    Wed    Thu    Fri    Sat    Sun
# User Id
# 38       [nan]  [nan]  [nan]  [nan]    [3]  [nan]  [nan]
# 41        [15]   [15]   [18]   [16]   [12]  [nan]  [nan]
# 47       [nan]  [nan]   [14]  [nan]  [nan]  [nan]  [nan]
# 61        [12]   [16]  [nan]   [15]  [nan]  [nan]  [nan]
# 62        [11]  [nan]  [nan]  [nan]   [18]  [nan]  [nan]

# %% [markdown]
# # Merge res 90_100 and 100

# %%
index_customer100 = customer100.index.values
index_customer90_100 = customer90_100.index.values
res_hr = pd.DataFrame(columns = ['User Id','Mon', 'Tue','Wed','Thu','Fri','Sat','Sun'])
res_hr['User Id'] = open_time['User Id']
res_hr = res_hr.groupby('User Id').agg(lambda x: x.tolist())
print(res_hr)
# Out:
#                                                        Mon  \
# User Id
# 21       [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 38                                    [nan, nan, nan, nan]
# 41       [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 47       [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53                                         [nan, nan, nan]
# ...                                                    ...
# 49653    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 49655             [nan, nan, nan, nan, nan, nan, nan, nan]
# 49656    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 49657                                                [nan]
# 49659    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                                        Tue  \
# User Id
# 21       [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 38                                    [nan, nan, nan, nan]
# ...

# %%
for i in range(len(index_customer100)):
    if index_customer100[i] in index_customer90_100:
        for n in range(7):
            if customer100.loc[index_customer100[i]][n][0] == 'nan':
                res_hr.loc[index_customer100[i]][n]= customer90_100.loc[index_customer100[i]][n]
            else:
                res_hr.loc[index_customer100[i]][n] = customer100.loc[index_customer100[i]][n]  
    else:
        for n in range(7):
            res_hr.loc[index_customer100[i]][n] = customer100.loc[index_customer100[i]][n]
for m in range(len(index_customer90_100)):
    if index_customer90_100[m] not in index_customer100:
        for n in range(7):
            res_hr.loc[index_customer90_100[m]][n] = customer90_100.loc[index_customer90_100[m]][n]

# %% [markdown]
# # Merge res 80_90 and res_hr

# %%
index_res_hr = res_hr.index.values
index_customer80_90 = customer80_90.index.values

# %%
for i in range(len(index_res_hr)):
    if index_res_hr[i] in index_customer80_90:
        for n in range(7):
            if np.isnan(res_hr.loc[index_res_hr[i]][n][0]):
                res_hr.loc[index_res_hr[i]][n]= customer80_90.loc[index_res_hr[i]][n]
    
for m in range(len(index_customer80_90)):
    if index_customer80_90[m] not in index_res_hr:
        for n in range(7):
            res_hr.loc[index_customer80_90[m]][n] = customer80_90.loc[index_customer80_90[m]][n]

# %% [markdown]
# # Merge res 50_80 and res_hr

# %%
index_res_hr = res_hr.index.values
index_customer50_80 = customer50_80.index.values

# %%
for i in range(len(index_res_hr)):
    if index_res_hr[i] in index_customer50_80:
        for n in range(7):
            if np.isnan(res_hr.loc[index_res_hr[i]][n][0]):
                res_hr.loc[index_res_hr[i]][n]= customer50_80.loc[index_res_hr[i]][n]
for m in range(len(index_customer50_80)):
    if index_customer50_80[m] not in index_res_hr:
        for n in range(7):
            res_hr.loc[index_customer50_80[m]][n] = customer50_80.loc[index_customer50_80[m]][n]

# %% [markdown]
# # Merge res 0_50 and res_hr

# %%
index_res_hr = res_hr.index.values
index_customer0_50 = customer0_50.index.values

# %%
for i in range(len(index_res_hr)):
    if index_res_hr[i] in index_customer0_50:
        for n in range(7):
            if np.isnan(res_hr.loc[index_res_hr[i]][n][0]):
                res_hr.loc[index_res_hr[i]][n]= customer0_50.loc[index_res_hr[i]][n]
for m in range(len(index_customer0_50)):
    if index_customer0_50[m] not in index_res_hr:
        for n in range(7):
            res_hr.loc[index_customer0_50[m]][n] = customer0_50.loc[index_customer0_50[m]][n]

# %%
res_hr.to_csv('res_hr_without0.csv')

# %% [markdown]
# # Merge res 0 and res_hr

# %%
index_res_hr = res_hr.index.values
index_customer0 = customer0.index.values

# %%
for i in range(len(index_res_hr)):
    if index_res_hr[i] in index_customer0:
        for n in range(7):
            if np.isnan(res_hr.loc[index_res_hr[i]][n][0]):
                res_hr.loc[index_res_hr[i]][n]= -1 * (customer0.loc[index_res_hr[i]][n])
for m in range(len(index_customer0)):
    if index_customer0[m] not in index_res_hr:
        for n in range(7):
            res_hr.loc[index_customer0[m]][n] = -1 * (customer0.loc[index_customer0[m]][n])

# %%
res_hr
# Out:
#            Mon       Tue    Wed    Thu    Fri    Sat       Sun
# User Id
# 21        [16]       [8]   [15]    [8]  [nan]  [nan]     [nan]
# 38          []        []     []     []    [3]     []        []
# 41        [11]  [10, 15]    [9]   [10]    [9]   [17]      [12]
# 47          []        []   [14]     []     []     []        []
# 53       [nan]     [nan]  [nan]  [nan]  [nan]   [13]     [nan]
# ...        ...       ...    ...    ...    ...    ...       ...
# 49653       []        []     []     []     []   [14]        []
# 49655       []        []     []     []     []     []      [15]
# 49656       []        []     []     []     []     []  [15, 16]
# 49657       []        []     []     []     []     []        []
# 49659       []        []     []     []     []     []      [18]
#
# [23358 rows x 7 columns]

# %%
res_hr.to_csv('res_hr_with0.csv')
