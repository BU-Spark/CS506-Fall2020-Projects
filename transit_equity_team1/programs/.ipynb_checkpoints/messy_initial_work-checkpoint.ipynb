# %%
import pandas as pd
import numpy as np

# %%
stops_df = pd.read_csv('./output/stops.csv')

# %%
stops_df
# Out:
#       STOP_ID                     STOP_NAME     TOWN  TOWN_ID  TRACT_ID  \
# 0        3077  Gallivan Blvd @ opp Marsh St   BOSTON       35    100700
# 1         841       Lagrange St @ Virgil Rd   BOSTON       35    130200
# 2         446        Norfolk St @ Nelson St   BOSTON       35    100300
# 3         847     Lagrange St opp Virgil St   BOSTON       35    130200
# 4        3079           Adams St @ Minot St   BOSTON       35    100800
# ...       ...                           ...      ...      ...       ...
# 7805     9097         Grove St @ Lebanon St  MELROSE      178    336300
# 7806     5911         Grove St @ Lebanon St  MELROSE      178    336300
# 7807     5975  Wyoming Ave opp Cleveland St  MELROSE      178    336402
# 7808    15976    Wyoming Ave @ Cleveland St  MELROSE      178    336402
# 7809     5912           Grove St @ Faxon St  MELROSE      178    336300
#
#       income  income_level route_ids    ridership      revenues  \
# ...

# %%
stops_df.route_ids.unique()
# Out:
# array(['201', '37,38', '26', '201,19', '19,202', '35,37,36,38,27', '230',
#        '238,240', '217,211,245', nan, '245', '40,50', '211,210,212',
#        '221', '217,215,245', '217,211,212,210,245', '215,245', '33,32',
#        '216,214', '35,70A,34E,34', '40', '50', '33,24', '220', '217,211',
#        '35,70A,34E,52', '245,240', '33,40', '33', '240', '217', '217,245',
#        '202,211,210,212', '217,211,212,202,210,000,000', '215',
#        '40,34E,70A,34', '202', '40,70A,34E,34,50', '201,202,210', '52',
#        '21', '27,14,30', '211', '38', '24,217,215,21,27,240', '28,31,29',
#        '14', '59', '202,215', '201,202', '19', '238', '34E,70A', '225',
#        '28,29', '15,22,24,26,217,215,21,18,45,23,27,240', '31,21', '70A',
#        '16', '18', '32,37,36,21,38,34,39', '15,17', '35,38', '42',
#        '16,32,36,34', '32,36,38,16,34', '23', '19,16', '23,19', '51',
#        '22,32,36,29,34', '28,66,22,10,45,23,14', '28,14,45',
# ...

# %%
stops_df.loc[(stops_df['route_ids'] == '66,57,57A,501,503')]
# Out:
#       STOP_ID                          STOP_NAME    TOWN  TOWN_ID  TRACT_ID  \
# 2655      916            Washington St @ Lake St  BOSTON       35       202
# 2656      975           Washington St @ Brock St  BOSTON       35       201
# 2789      974          Washington St @ Foster St  BOSTON       35       202
# 2790      917          Washington St @ Foster St  BOSTON       35       202
# 2793      918  Washington St @ Chestnut Hill Ave  BOSTON       35       402
# 2794      973          Washington St @ Market St  BOSTON       35       202
# 3612      977       Washington St @ Montfern Ave  BOSTON       35       201
# 3617      914     Washington St opp Montfern Ave  BOSTON       35       201
# 3630      913          Washington St @ Breck Ave  BOSTON       35       302
# 3631     9780             Washington St @ Oak Sq  BOSTON       35       302
# 3632      912         Tremont St @ Washington St  BOSTON       35       301
# ...

# %%
stops_df.dtypes
# Out:
# STOP_ID             int64
# STOP_NAME          object
# TOWN               object
# TOWN_ID             int64
# TRACT_ID            int64
# income              int64
# income_level        int64
# route_ids          object
# ridership          object
# revenues           object
# revenue_annual    float64
# dtype: object

# %%
test = "Here is a string without a comma"
test.split(',')
# Out:
# ['Here is a string without a comma']

# %%
seasonal_ridership = pd.read_csv('./data/ridership_by_season.csv')

# %%
seasonal_ridership
# Out:
#        ObjectId\tmode\tseason\troute_id\troute_name\troute_variant\tstop_sequence\tdirection_id\tday_type_id\tday_type_name\ttime_period_id\ttime_period_name\tstop_name\tstop_id\taverage_ons\taverage_offs\taverage_load\tnum_trips
# 0       1\t3\tFall 2019\t1\t1\t1-_-0\t1\t0\tday_type_0...
# 1       2\t3\tFall 2019\t1\t1\t1-_-0\t2\t0\tday_type_0...
# 2       3\t3\tFall 2019\t1\t1\t1-_-0\t3\t0\tday_type_0...
# 3       4\t3\tFall 2019\t1\t1\t1-_-0\t4\t0\tday_type_0...
# 4       5\t3\tFall 2019\t1\t1\t1-_-0\t5\t0\tday_type_0...
# ...                                                   ...
# 529873  529874\t3\tFall 2016\t99\t99\t99-8-1\t38\t1\td...
# 529874  529875\t3\tFall 2016\t99\t99\t99-8-1\t39\t1\td...
# 529875  529876\t3\tFall 2016\t99\t99\t99-8-1\t40\t1\td...
# 529876  529877\t3\tFall 2016\t99\t99\t99-8-1\t41\t1\td...
# 529877  529878\t3\tFall 2016\t99\t99\t99-8-1\t42\t1\td...
#
# [529878 rows x 1 columns]

# %%
ridership_df = pd.read_csv('./data/Line,_and_Stop.csv', low_memory=False)

# %%
ridership_df
# Out:
#              FID     season route_id route_variant  direction_id  \
# 0              1  Fall 2016        1         1-_-0             0
# 1              2  Fall 2016        1         1-_-0             0
# 2              3  Fall 2016        1         1-_-0             0
# 3              4  Fall 2016        1         1-_-0             0
# 4              5  Fall 2016        1         1-_-0             0
# ...          ...        ...      ...           ...           ...
# 3451727  3451728  Fall 2019       99        99-8-1             1
# 3451728  3451729  Fall 2019       99        99-8-1             1
# 3451729  3451730  Fall 2019       99        99-8-1             1
# 3451730  3451731  Fall 2019       99        99-8-1             1
# 3451731  3451732  Fall 2019       99        99-8-1             1
#
#         trip_start_time  day_type_id day_type_name  \
# 0              04:37:00  day_type_01       weekday
# 1              04:37:00  day_type_01       weekday
# ...

# %%
ridership_df.season.unique()
# Out:
# array(['Fall 2016', 'Fall 2017', 'Fall 2018', 'Fall 2019'], dtype=object)

# %%
ridership_df.loc[(ridership_df['stop_id'] == 1) & (ridership_df['season'] == 'Fall 2019')]
# Out:
#              FID     season route_id route_variant  direction_id  \
# 2588482  2588483  Fall 2019        1         1-_-0             0
# 2588507  2588508  Fall 2019        1         1-_-0             0
# 2588579  2588580  Fall 2019        1         1-_-0             0
# 2588610  2588611  Fall 2019        1         1-_-0             0
# 2588677  2588678  Fall 2019        1         1-_-0             0
# ...          ...        ...      ...           ...           ...
# 3360818  3360819  Fall 2019        8         8-9-1             1
# 3360882  3360883  Fall 2019        8         8-9-1             1
# 3360971  3360972  Fall 2019        8         8-9-1             1
# 3361002  3361003  Fall 2019        8         8-9-1             1
# 3361118  3361119  Fall 2019        8         8-9-1             1
#
#         trip_start_time  day_type_id day_type_name  \
# 2588482        04:55:00  day_type_02      saturday
# 2588507        05:06:00  day_type_01       weekday
# ...

# %%
ridership_df.loc[(ridership_df['route_id'] == '57A')]
# Out:
# Empty DataFrame
# Columns: [FID, season, route_id, route_variant, direction_id, trip_start_time, day_type_id, day_type_name, stop_name, stop_id, stop_sequence, boardings, alightings, load_, sample_size]
# Index: []

# %%
ridership_df.route_id.unique()
# Out:
# array(['1', '10', '100', '101', '104', '105', '106', '108', '109', '11',
#        '110', '111', '112', '114', '116', '117', '119', '120', '121',
#        '131', '132', '134', '136', '137', '14', '15', '16', '17', '170',
#        '171', '18', '19', '201', '202', '21', '210', '211', '212', '214',
#        '215', '216', '217', '22', '220', '221', '222', '225', '23', '230',
#        '236', '238', '24', '240', '245', '26', '27', '28', '29', '30',
#        '31', '32', '325', '326', '33', '34', '34E', '35', '350', '351',
#        '352', '354', '36', '37', '38', '39', '4', '40', '41', '411', '42',
#        '424', '426', '428', '429', '43', '430', '434', '435', '436',
#        '439', '44', '441', '442', '448', '449', '45', '450', '451', '455',
#        '456', '459', '465', '47', '5', '50', '501', '502', '503', '504',
#        '505', '51', '52', '55', '553', '554', '556', '558', '57', '57A',
#        '59', '60', '62', '64', '65', '66', '67', '68', '69', '7', '70',
# ...

# %%
# load only rows for Fall 2019
ridership_df = ridership_df[ridership_df.season == 'Fall 2019']
ridership_df
# Out:
#              FID     season route_id route_variant  direction_id  \
# 2588455  2588456  Fall 2019        1         1-_-0             0
# 2588459  2588460  Fall 2019        1         1-_-0             0
# 2588462  2588463  Fall 2019        1         1-_-0             0
# 2588466  2588467  Fall 2019        1         1-_-0             0
# 2588467  2588468  Fall 2019        1         1-_-0             0
# ...          ...        ...      ...           ...           ...
# 3451727  3451728  Fall 2019       99        99-8-1             1
# 3451728  3451729  Fall 2019       99        99-8-1             1
# 3451729  3451730  Fall 2019       99        99-8-1             1
# 3451730  3451731  Fall 2019       99        99-8-1             1
# 3451731  3451732  Fall 2019       99        99-8-1             1
#
#         trip_start_time  day_type_id day_type_name  \
# 2588455        04:37:00  day_type_01       weekday
# 2588459        04:52:00  day_type_01       weekday
# ...

# %%
print(ridership_df.route_id.unique())
# Out:
# <StringArray>
# [  '1',  '10', '100', '101', '104', '105', '106', '108', '109',  '11',
#  ...
#    '9',  '90',  '91',  '92',  '93',  '94',  '95',  '96',  '97',  '99']
# Length: 165, dtype: string

# %%
ridership_df.dtypes
# Out:
# FID                  int64
# season              object
# route_id            object
# route_variant       object
# direction_id         int64
# trip_start_time     object
# day_type_id         object
# day_type_name       object
# stop_name           object
# stop_id              int64
# stop_sequence        int64
# boardings          float64
# alightings         float64
# load_              float64
# sample_size          int64
# dtype: object

# %%
ridership_df['route_id'] = ridership_df['route_id'].astype("string")
# Out:
# <ipython-input-42-c0b8248ffbb5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ridership_df['route_id'] = ridership_df['route_id'].astype("string")

# %%
ridership_df[ridership_df.route_id == '1']
# Out:
#              FID     season route_id route_variant  direction_id  \
# 2588455  2588456  Fall 2019        1         1-_-0             0
# 2588459  2588460  Fall 2019        1         1-_-0             0
# 2588462  2588463  Fall 2019        1         1-_-0             0
# 2588466  2588467  Fall 2019        1         1-_-0             0
# 2588467  2588468  Fall 2019        1         1-_-0             0
# ...          ...        ...      ...           ...           ...
# 2605115  2605116  Fall 2019        1         1-_-1             1
# 2605116  2605117  Fall 2019        1         1-_-1             1
# 2605117  2605118  Fall 2019        1         1-_-1             1
# 2605118  2605119  Fall 2019        1         1-_-1             1
# 2605119  2605120  Fall 2019        1         1-_-1             1
#
#         trip_start_time  day_type_id day_type_name  \
# 2588455        04:37:00  day_type_01       weekday
# 2588459        04:52:00  day_type_01       weekday
# ...

# %%
ridership_df[ridership_df.route_id == '57A']
# Out:
# Empty DataFrame
# Columns: [FID, season, route_id, route_variant, direction_id, trip_start_time, day_type_id, day_type_name, stop_name, stop_id, stop_sequence, boardings, alightings, load_, sample_size]
# Index: []

# %%
ridership_df.dtypes
# Out:
# FID                  int64
# season              object
# route_id            string
# route_variant       object
# direction_id         int64
# trip_start_time     object
# day_type_id         object
# day_type_name       object
# stop_name           object
# stop_id              int64
# stop_sequence        int64
# boardings          float64
# alightings         float64
# load_              float64
# sample_size          int64
# dtype: object

# %%
routes_with_fare = pd.read_csv('./output/routes_with_fare.csv')

# %%
routes_with_fare
# Out:
#                              route_id  agency_id      route_short_name  \
# 0                                 Red          1                   NaN
# 1                            Mattapan          1                   NaN
# 2                              Orange          1                   NaN
# 3                             Green-B          1                     B
# 4                             Green-C          1                     C
# ..                                ...        ...                   ...
# 236          Shuttle-KenmoreReservoir          1  Green Line D Shuttle
# 237    Shuttle-NewtonHighlandsKenmore          1  Green Line D Shuttle
# 238  Shuttle-NewtonHighlandsRiverside          1  Green Line D Shuttle
# 239        Shuttle-OakGroveWellington          1   Orange Line Shuttle
# 240        Shuttle-ReservoirRiverside          1  Green Line D Shuttle
#
#                   route_long_name            route_desc  route_type  \
# ...

# %%
routes_with_fare.dropna()
# Out:
#     route_id  agency_id route_short_name  \
# 142      195          1              195
#
#                                        route_long_name        route_desc  \
# 142  Lemuel Shattuck Hospital - Park Street & Tremo...  Supplemental Bus
#
#      route_type                           route_url route_color  \
# 142           3  https://www.mbta.com/schedules/195      FFC72C
#
#     route_text_color  route_sort_order route_fare_class   line_id  \
# 142                0             51950        Local Bus  line-195
#
#      listed_route  fare  reduced_fare
# 142           1.0   1.7          0.85

# %%
rwf = routes_with_fare[routes_with_fare['fare'].notna()]

# %%
rwf
# Out:
#                              route_id  agency_id      route_short_name  \
# 11                                751          1                   SL4
# 12                                749          1                   SL5
# 29                                747          1                   CT2
# 30                                708          1                   CT3
# 31                                  1          1                     1
# ..                                ...        ...                   ...
# 236          Shuttle-KenmoreReservoir          1  Green Line D Shuttle
# 237    Shuttle-NewtonHighlandsKenmore          1  Green Line D Shuttle
# 238  Shuttle-NewtonHighlandsRiverside          1  Green Line D Shuttle
# 239        Shuttle-OakGroveWellington          1   Orange Line Shuttle
# 240        Shuttle-ReservoirRiverside          1  Green Line D Shuttle
#
#                                      route_long_name            route_desc  \
# ...

# %%
rwf.route_id.unique()
# Out:
# array(['751', '749', '747', '708', '1', '4', '7', '8', '9', '10', '11',
#        '14', '15', '16', '17', '18', '19', '21', '22', '23', '24', '2427',
#        '26', '27', '28', '29', '30', '31', '32', '3233', '33', '34',
#        '34E', '35', '36', '37', '38', '39', '40', '4050', '41', '42',
#        '43', '44', '45', '47', '50', '51', '52', '55', '57', '57A', '59',
#        '60', '61', '62', '627', '64', '65', '66', '67', '68', '69', '70',
#        '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '83',
#        '84', '85', '86', '87', '88', '89', '8993', '90', '91', '92', '93',
#        '94', '95', '96', '97', '99', '100', '101', '104', '105', '106',
#        '108', '109', '110', '111', '112', '114', '116', '116117', '117',
#        '119', '120', '121', '131', '132', '134', '136', '137', '170',
#        '171', '195', '201', '202', '210', '211', '212', '214', '214216',
#        '215', '216', '217', '220', '221', '222', '225', '226', '230',
# ...

# %%
rwf['ridership'] = ""
# Out:
# <ipython-input-19-ef04794c1c73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwf['ridership'] = ""

# %%
rwf
# Out:
#                              route_id  agency_id      route_short_name  \
# 11                                751          1                   SL4
# 12                                749          1                   SL5
# 29                                747          1                   CT2
# 30                                708          1                   CT3
# 31                                  1          1                     1
# ..                                ...        ...                   ...
# 236          Shuttle-KenmoreReservoir          1  Green Line D Shuttle
# 237    Shuttle-NewtonHighlandsKenmore          1  Green Line D Shuttle
# 238  Shuttle-NewtonHighlandsRiverside          1  Green Line D Shuttle
# 239        Shuttle-OakGroveWellington          1   Orange Line Shuttle
# 240        Shuttle-ReservoirRiverside          1  Green Line D Shuttle
#
#                                      route_long_name            route_desc  \
# ...

# %%
new_rwf = rwf[~rwf.route_id.str.contains("Shuttle")]

# %%
new_rwf
# Out:
#     route_id  agency_id    route_short_name  \
# 11       751          1                 SL4
# 12       749          1                 SL5
# 29       747          1                 CT2
# 30       708          1                 CT3
# 31         1          1                   1
# ..       ...        ...                 ...
# 197      712          1                 712
# 198      713          1                 713
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 11                      Nubian Station - South Station               Key Bus
# 12                       Nubian Station - Temple Place               Key Bus
# 29           Sullivan Square Station - Ruggles Station             Local Bus
# 30     Beth Israel Deaconess Hospital - Andrew Station             Local Bus
# ...

# %%
new_rwf.route_id.unique()
# Out:
# array(['751', '749', '747', '708', '1', '4', '7', '8', '9', '10', '11',
#        '14', '15', '16', '17', '18', '19', '21', '22', '23', '24', '2427',
#        '26', '27', '28', '29', '30', '31', '32', '3233', '33', '34',
#        '34E', '35', '36', '37', '38', '39', '40', '4050', '41', '42',
#        '43', '44', '45', '47', '50', '51', '52', '55', '57', '57A', '59',
#        '60', '61', '62', '627', '64', '65', '66', '67', '68', '69', '70',
#        '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '83',
#        '84', '85', '86', '87', '88', '89', '8993', '90', '91', '92', '93',
#        '94', '95', '96', '97', '99', '100', '101', '104', '105', '106',
#        '108', '109', '110', '111', '112', '114', '116', '116117', '117',
#        '119', '120', '121', '131', '132', '134', '136', '137', '170',
#        '171', '195', '201', '202', '210', '211', '212', '214', '214216',
#        '215', '216', '217', '220', '221', '222', '225', '226', '230',
# ...

# %%
new_rwf.loc[(new_rwf['route_id'] == '116117')]
# Out:
#     route_id  agency_id route_short_name  \
# 130   116117          1          116/117
#
#                            route_long_name        route_desc  route_type  \
# 130  Wonderland Station - Maverick Station  Supplemental Bus           3
#
#     route_url route_color route_text_color  route_sort_order route_fare_class  \
# 130       NaN      FFC72C                0             51161        Local Bus
#
#             line_id  listed_route  fare  reduced_fare ridership
# 130  line-114116117           1.0   1.7          0.85

# %%
array(['1', '10', '100', '101', '104', '105', '106', '108', '109', '11',
       '110', '111', '112', '114', '116', '117', '119', '120', '121',
       '131', '132', '134', '136', '137', '14', '15', '16', '17', '170',
       '171', '18', '19', '201', '202', '21', '210', '211', '212', '214',
       '215', '216', '217', '22', '220', '221', '222', '225', '23', '230',
       '236', '238', '24', '240', '245', '26', '27', '28', '29', '30',
       '31', '32', '325', '326', '33', '34', '34E', '35', '350', '351',
       '352', '354', '36', '37', '38', '39', '4', '40', '41', '411', '42',
       '424', '426', '428', '429', '43', '430', '434', '435', '436',
       '439', '44', '441', '442', '448', '449', '45', '450', '451', '455',
       '456', '459', '465', '47', '5', '50', '501', '502', '503', '504',
       '505', '51', '52', '55', '553', '554', '556', '558', '57', '57A',
       '59', '60', '62', '64', '65', '66', '67', '68', '69', '7', '70',
       '701', '708', '70A', '71', '72', '73', '74', '741', '742', '746',
       '747', '749', '75', '751', '76', '77', '78', '79', '8', '80', '83',
       '84', '85', '86', '87', '88', '89', '9', '90', '91', '92', '93',
       '94', '95', '96', '97', '99', '712', '713', '743', '725'],
      dtype=object)

# %%
# rwf has the names of the routes, one row per route
# ridership_df has multiple rows per route

for idx, row in new_rwf.iterrows(): # looping through every route
    route_id = str(row['route_id'])
    weekday_ons = sum(ridership_df[(ridership_df.route_id==route_id) & (ridership_df.day_type_name=='weekday')].boardings) * 5
    saturday_ons = sum(ridership_df[(ridership_df.route_id==route_id) & (ridership_df.day_type_name=='saturday')].boardings)
    sunday_ons = sum(ridership_df[(ridership_df.route_id==route_id) & (ridership_df.day_type_name=='sunday')].boardings)
    week_ons = weekday_ons+saturday_ons+sunday_ons
    year_ons = week_ons * 52
    year_ons = "{:.1f}".format(year_ons)
    new_rwf.at[idx, 'ridership'] =  year_ons

# %%
ridership_df.dtypes
# Out:
# FID                  int64
# season              object
# route_id            object
# route_variant       object
# direction_id         int64
# trip_start_time     object
# day_type_id         object
# day_type_name       object
# stop_name           object
# stop_id              int64
# stop_sequence        int64
# boardings          float64
# alightings         float64
# load_              float64
# sample_size          int64
# dtype: object

# %%
new_rwf
# Out:
#     route_id  agency_id    route_short_name  \
# 11       751          1                 SL4
# 12       749          1                 SL5
# 29       747          1                 CT2
# 30       708          1                 CT3
# 31         1          1                   1
# ..       ...        ...                 ...
# 197      712          1                 712
# 198      713          1                 713
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 11                      Nubian Station - South Station               Key Bus
# 12                       Nubian Station - Temple Place               Key Bus
# 29           Sullivan Square Station - Ruggles Station             Local Bus
# 30     Beth Israel Deaconess Hospital - Andrew Station             Local Bus
# ...

# %%
new_rwf.loc[(new_rwf['ridership'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [route_id, agency_id, route_short_name, route_long_name, route_desc, route_type, route_url, route_color, route_text_color, route_sort_order, route_fare_class, line_id, listed_route, fare, reduced_fare, ridership]
# Index: []

# %%
new_rwf.dtypes
# Out:
# route_id             object
# agency_id             int64
# route_short_name     object
# route_long_name      object
# route_desc           object
# route_type            int64
# route_url            object
# route_color          object
# route_text_color     object
# route_sort_order      int64
# route_fare_class     object
# line_id              object
# listed_route        float64
# fare                float64
# reduced_fare        float64
# ridership            object
# dtype: object

# %%
# convert column "a" of a DataFrame
new_rwf['ridership'] = pd.to_numeric(new_rwf['ridership'])
# Out:
# <ipython-input-32-e9ce0a0e5c59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_rwf['ridership'] = pd.to_numeric(new_rwf['ridership'])

# %%
new_rwf.dtypes
# Out:
# route_id             object
# agency_id             int64
# route_short_name     object
# route_long_name      object
# route_desc           object
# route_type            int64
# route_url            object
# route_color          object
# route_text_color     object
# route_sort_order      int64
# route_fare_class     object
# line_id              object
# listed_route        float64
# fare                float64
# reduced_fare        float64
# ridership           float64
# dtype: object

# %%
new_rwf.loc[(new_rwf['ridership'] == 0.0)]
# Out:
#     route_id  agency_id    route_short_name  \
# 48      2427          1               24/27
# 56      3233          1               32/33
# 66      4050          1               40/50
# 78       57A          1                 57A
# 81        61          1                  61
# 83       627          1               62/76
# 108     8993          1               89/93
# 130   116117          1             116/117
# 142      195          1                 195
# 149   214216          1             214/216
# 157      226          1                 226
# 180   441442          1             441/442
# 196      710          1                 710
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 48   Wakefield Avenue & Truman Parkway - Mattapan S...             Local Bus
# ...

# %%
ridership_df.dtypes
# Out:
# FID                  int64
# season              object
# route_id            string
# route_variant       object
# direction_id         int64
# trip_start_time     object
# day_type_id         object
# day_type_name       object
# stop_name           object
# stop_id              int64
# stop_sequence        int64
# boardings          float64
# alightings         float64
# load_              float64
# sample_size          int64
# dtype: object

# %% [markdown]
# # Rerunning after encountering errors where certain routes weren't being recognized and ridership was being set to 0.0
# Even though something like that wouldn't be possible unless a bus was seasonal and thus wasn't running in the fall? Just checked and I'm pretty sure they don't

# %%
# rwf has the names of the routes, one row per route
# ridership_df has multiple rows per route

for idx, row in new_rwf.iterrows(): # looping through every route
    route_id = str(row['route_id'])
    weekday_ons = sum(ridership_df[(ridership_df.route_id==route_id) & (ridership_df.day_type_name=='weekday')].boardings) * 5
    saturday_ons = sum(ridership_df[(ridership_df.route_id==route_id) & (ridership_df.day_type_name=='saturday')].boardings)
    sunday_ons = sum(ridership_df[(ridership_df.route_id==route_id) & (ridership_df.day_type_name=='sunday')].boardings)
    week_ons = weekday_ons+saturday_ons+sunday_ons
    year_ons = week_ons * 52
    year_ons = "{:.1f}".format(year_ons)
    new_rwf.at[idx, 'ridership'] =  year_ons

# %%
new_rwf
# Out:
#     route_id  agency_id    route_short_name  \
# 11       751          1                 SL4
# 12       749          1                 SL5
# 29       747          1                 CT2
# 30       708          1                 CT3
# 31         1          1                   1
# ..       ...        ...                 ...
# 197      712          1                 712
# 198      713          1                 713
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 11                      Nubian Station - South Station               Key Bus
# 12                       Nubian Station - Temple Place               Key Bus
# 29           Sullivan Square Station - Ruggles Station             Local Bus
# 30     Beth Israel Deaconess Hospital - Andrew Station             Local Bus
# ...

# %%
# convert column "a" of a DataFrame
new_rwf['ridership'] = pd.to_numeric(new_rwf['ridership'])
# Out:
# <ipython-input-47-e9ce0a0e5c59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_rwf['ridership'] = pd.to_numeric(new_rwf['ridership'])

# %%
new_rwf.loc[(new_rwf['ridership'] == 0.0)]
# Out:
#     route_id  agency_id    route_short_name  \
# 48      2427          1               24/27
# 56      3233          1               32/33
# 66      4050          1               40/50
# 78       57A          1                 57A
# 81        61          1                  61
# 83       627          1               62/76
# 108     8993          1               89/93
# 130   116117          1             116/117
# 142      195          1                 195
# 149   214216          1             214/216
# 157      226          1                 226
# 180   441442          1             441/442
# 196      710          1                 710
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 48   Wakefield Avenue & Truman Parkway - Mattapan S...             Local Bus
# ...

# %%
missing_ridership = new_rwf.loc[(new_rwf['ridership'] == 0.0)]

# %%
missing_ridership
# Out:
#     route_id  agency_id    route_short_name  \
# 48      2427          1               24/27
# 56      3233          1               32/33
# 66      4050          1               40/50
# 78       57A          1                 57A
# 81        61          1                  61
# 83       627          1               62/76
# 108     8993          1               89/93
# 130   116117          1             116/117
# 142      195          1                 195
# 149   214216          1             214/216
# 157      226          1                 226
# 180   441442          1             441/442
# 196      710          1                 710
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 48   Wakefield Avenue & Truman Parkway - Mattapan S...             Local Bus
# ...

# %%
missing_ridership['In full_ridership_df'] = False
# Out:
# <ipython-input-64-266384e96da0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_ridership['In full_ridership_df'] = False

# %%
missing_ridership
# Out:
#     route_id  agency_id    route_short_name  \
# 48      2427          1               24/27
# 56      3233          1               32/33
# 66      4050          1               40/50
# 78       57A          1                 57A
# 81        61          1                  61
# 83       627          1               62/76
# 108     8993          1               89/93
# 130   116117          1             116/117
# 142      195          1                 195
# 149   214216          1             214/216
# 157      226          1                 226
# 180   441442          1             441/442
# 196      710          1                 710
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 48   Wakefield Avenue & Truman Parkway - Mattapan S...             Local Bus
# ...

# %%
full_ridership_df = pd.read_csv('./data/Line,_and_Stop.csv', low_memory=False)

# %%
full_ridership_df
# Out:
#              FID     season route_id route_variant  direction_id  \
# 0              1  Fall 2016        1         1-_-0             0
# 1              2  Fall 2016        1         1-_-0             0
# 2              3  Fall 2016        1         1-_-0             0
# 3              4  Fall 2016        1         1-_-0             0
# 4              5  Fall 2016        1         1-_-0             0
# ...          ...        ...      ...           ...           ...
# 3451727  3451728  Fall 2019       99        99-8-1             1
# 3451728  3451729  Fall 2019       99        99-8-1             1
# 3451729  3451730  Fall 2019       99        99-8-1             1
# 3451730  3451731  Fall 2019       99        99-8-1             1
# 3451731  3451732  Fall 2019       99        99-8-1             1
#
#         trip_start_time  day_type_id day_type_name  \
# 0              04:37:00  day_type_01       weekday
# 1              04:37:00  day_type_01       weekday
# ...

# %%
full_unique_routes = full_ridership_df.route_id.unique()

# %%
full_unique_routes
# Out:
# array(['1', '10', '100', '101', '104', '105', '106', '108', '109', '11',
#        '110', '111', '112', '114', '116', '117', '119', '120', '121',
#        '131', '132', '134', '136', '137', '14', '15', '16', '17', '170',
#        '171', '18', '19', '201', '202', '21', '210', '211', '212', '214',
#        '215', '216', '217', '22', '220', '221', '222', '225', '23', '230',
#        '236', '238', '24', '240', '245', '26', '27', '28', '29', '30',
#        '31', '32', '325', '326', '33', '34', '34E', '35', '350', '351',
#        '352', '354', '36', '37', '38', '39', '4', '40', '41', '411', '42',
#        '424', '426', '428', '429', '43', '430', '434', '435', '436',
#        '439', '44', '441', '442', '448', '449', '45', '450', '451', '455',
#        '456', '459', '465', '47', '5', '50', '501', '502', '503', '504',
#        '505', '51', '52', '55', '553', '554', '556', '558', '57', '57A',
#        '59', '60', '62', '64', '65', '66', '67', '68', '69', '7', '70',
# ...

# %%
for idx, row in missing_ridership.iterrows(): # looping through every route
    route_id = row['route_id']
    if route_id in full_unique_routes:
        missing_ridership.at[idx, 'In full_ridership_df'] = True

# %%
missing_ridership
# Out:
#     route_id  agency_id    route_short_name  \
# 48      2427          1               24/27
# 56      3233          1               32/33
# 66      4050          1               40/50
# 78       57A          1                 57A
# 81        61          1                  61
# 83       627          1               62/76
# 108     8993          1               89/93
# 130   116117          1             116/117
# 142      195          1                 195
# 149   214216          1             214/216
# 157      226          1                 226
# 180   441442          1             441/442
# 196      710          1                 710
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 48   Wakefield Avenue & Truman Parkway - Mattapan S...             Local Bus
# ...

# %%
missing_ridership.shape
# Out:
# (16, 18)

# %%
new_rwf.shape
# Out:
# (175, 17)

# %%
missing_ridership.shape[0]/new_rwf.shape[0]*100
# Out:
# 9.142857142857142

# %%
new_rwf
# Out:
#     route_id  agency_id    route_short_name  \
# 11       751          1                 SL4
# 12       749          1                 SL5
# 29       747          1                 CT2
# 30       708          1                 CT3
# 31         1          1                   1
# ..       ...        ...                 ...
# 197      712          1                 712
# 198      713          1                 713
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 11                      Nubian Station - South Station               Key Bus
# 12                       Nubian Station - Temple Place               Key Bus
# 29           Sullivan Square Station - Ruggles Station             Local Bus
# 30     Beth Israel Deaconess Hospital - Andrew Station             Local Bus
# ...

# %%
new_rwf['revenues'] = ""
# Out:
# <ipython-input-57-2dd59bc8dbcb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_rwf['revenues'] = ""

# %%
new_rwf
# Out:
#     route_id  agency_id    route_short_name  \
# 11       751          1                 SL4
# 12       749          1                 SL5
# 29       747          1                 CT2
# 30       708          1                 CT3
# 31         1          1                   1
# ..       ...        ...                 ...
# 197      712          1                 712
# 198      713          1                 713
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 11                      Nubian Station - South Station               Key Bus
# 12                       Nubian Station - Temple Place               Key Bus
# 29           Sullivan Square Station - Ruggles Station             Local Bus
# 30     Beth Israel Deaconess Hospital - Andrew Station             Local Bus
# ...

# %%
new_rwf.dtypes
# Out:
# route_id             object
# agency_id             int64
# route_short_name     object
# route_long_name      object
# route_desc           object
# route_type            int64
# route_url            object
# route_color          object
# route_text_color     object
# route_sort_order      int64
# route_fare_class     object
# line_id              object
# listed_route        float64
# fare                float64
# reduced_fare        float64
# ridership           float64
# revenues             object
# dtype: object

# %%
for idx, row in new_rwf.iterrows(): # looping through every route
    new_rwf.at[idx, 'revenues'] =  row['fare']*row['ridership']

# %%
new_rwf
# Out:
#     route_id  agency_id    route_short_name  \
# 11       751          1                 SL4
# 12       749          1                 SL5
# 29       747          1                 CT2
# 30       708          1                 CT3
# 31         1          1                   1
# ..       ...        ...                 ...
# 197      712          1                 712
# 198      713          1                 713
# 199      714          1                 714
# 200      716          1                 716
# 201      602          1  Green Line Shuttle
#
#                                        route_long_name            route_desc  \
# 11                      Nubian Station - South Station               Key Bus
# 12                       Nubian Station - Temple Place               Key Bus
# 29           Sullivan Square Station - Ruggles Station             Local Bus
# 30     Beth Israel Deaconess Hospital - Andrew Station             Local Bus
# ...

# %%
total_revenue = new_rwf['revenues'].sum()
print(total_revenue) # 207,485,001
# Out:
# 207485001.13000003
