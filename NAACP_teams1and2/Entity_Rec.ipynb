# %%
import pandas as pd
import spacy
import csv
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

# %%
list_name = []
def Entity_Rec(file_name):
    #input is file name
    nlp = spacy.load("en_core_web_sm")
    with open(file_name,encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            text = row['Article Content']
            doc = nlp(text)
            for ent in doc.ents: 
                if(ent.label_ == "PERSON"):
                    list_name.append(ent.text)
                    #print(ent.text, ent.label_)
Entity_Rec('wgbh_data_2018.csv')

# %%
def Entity_stat(input_list):
    Frequencies_stat=Counter(input_list)
    return Frequencies_stat
Entity_stat(list_name)
# Out:
# Counter({'Frank McClelland': 1,
#          'Moncef Meddeb': 1,
#          'McClelland.': 2,
#          'Julia Child': 1,
#          'Henry Kissinger': 1,
#          'Mick Jagger': 1,
#          'David Ortiz': 6,
#          'Bill Belichick': 8,
#          'McLelland': 1,
#          'Judie': 5,
#          'Amanda Beland': 5,
#          'Jon Meacham': 1,
#          'Lawrence O’Donnell': 2,
#          'Caitlin Moran': 1,
#          'Tom Papa': 1,
#          'Richard Blanco': 12,
#          'Harvard Historian': 1,
#          'Nancy Koehn': 18,
#          'George Washington': 1,
#          'Charlie Baker': 131,
#          'Baker': 238,
#          'Joe Kirylo': 3,
#          'Karen Spilka': 13,
#          'Robert DeLeo': 8,
#          'Bruce Tarr': 4,
#          'Brendan Moss': 3,
#          'John Buonopane': 5,
#          'Galen Mook': 3,
#          'Judie Yuill': 2,
#          'Yuill': 25,
#          'Mook': 3,
#          'Paul Dudley': 1,
#          'Auburn Dale': 1,
# ...

# %%
def Word_Cloud(input_list):
    #convert list to string and generate
    #convert list to string and generate
    word_could_dict=Counter(input_list)
    wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.savefig("WOW"+".png", bbox_inches='tight')
    plt.show()
    plt.close()
Word_Cloud(list_name)
