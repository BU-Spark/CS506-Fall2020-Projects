# %% [markdown]
# ### Certified Business Directory
# This directory is designed for members of the public and city of boston employees to be able to quickly search for a specific certified business. There are five different category: Minority Business Enterprise(MBE), Women Business Enterprise(WBE), Small Business Enterprise(SBE), Small Local Business Enterprise(SLBE).
# In our project, we analysis small business and restaurants in boston. So we will filter boston samll business and restaurants.

# %%
import pandas as pd
import numpy as np
filename = '../Dataset/Boston_Certified_Businesses/Certified_Business_dic.csv'
field_selected =['company_name','small_local_cert','year_established', 
                'business_area_1', 'business_area_2','business_area_3', 'address']
df = pd.read_csv(filename, usecols= field_selected)
df.head()
# Out:
#                  company_name small_local_cert  \
# 0          212/Harakawa, Inc.              NaN
# 1                3 South, LLC              SBE
# 2  617 Home Improvement, Inc.              SBE
# 3        813 Consultants, LLC             SLBE
# 4           84 Lumber Company              NaN
#
#                                   address  year_established  \
# 0     236 W 27th Street New York NY 10001            1990.0
# 1  3175 Conway Drive Baton Rouge LA 70809            2011.0
# 2        20 Boston Street Malden MA 02148            2017.0
# 3    10 Coniston Road Roslindale MA 02131            2015.0
# 4     1019 Route 519 Eighty Four PA 15330            1956.0
#
#                                      business_area_1  \
# 0  AD - Advertising/Audovisual Graphic Design/Mar...
# 1                               SA - Safety Products
# 2                                     CA - Carpentry
# 3  OS - Office Services (Clerical Support, Employ...
# 4                                     SU - Suppliers
#
#                                    business_area_2 business_area_3
# 0                                              NaN             NaN
# 1                      TA - Training (see also ED)  SU - Suppliers
# 2  FL - Floor Contractors (Carpet, Tile, Linoleum)             NaN
# 3               EM - Employement (see also OS, TR)             NaN
# 4                                              NaN             NaN

# %%
df.shape
# Out:
# (688, 7)

# %%
# find the years for small business enterprise certified
SBE_year = np.array([np_data[i,2] for i ,c in enumerate(np_data[:,1]) if c == 'SBE' or c == 'SLBE'])

# years 
x = [1980,1990, 1995, 2000,2005, 2010,2015,2020]

number_certified =[]
number_certified_SBE=[]
for i in x:
  number_certified.append(len(np.where(np_data[:,2]<=i)[0]))
  number_certified_SBE.append(len(np.where(SBE_year<=i)[0]))

df = pd.DataFrame({'number certified SBE and SLBE': number_certified_SBE, 
                    'Number of Certified Enterprise': number_certified, }, 
                    index = x)
ax = df.plot.bar()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
